# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import GroupKFold
from lightgbm import LGBMClassifier
from sklearn.metrics import roc_auc_score
import matplotlib.pyplot as plt
import lightgbm as lgb
import seaborn as sns
import pandas as pd
import numpy as np

# Load the data
df = pd.read_csv('public_data.csv')

# Create more sophisticated features
def create_features(df):
    # Time-based features
    df['hour_sin'] = np.sin(2 * np.pi * df['hour']/24)
    df['hour_cos'] = np.cos(2 * np.pi * df['hour']/24)
    df['minute_sin'] = np.sin(2 * np.pi * df['minute']/60)
    df['minute_cos'] = np.cos(2 * np.pi * df['minute']/60)

    # Rolling statistics for solar and load
    df['rolling_solar_mean'] = df.groupby('periodID')['solar_becsult_dayahead'].transform(
        lambda x: x.rolling(window=12, min_periods=1).mean())
    df['rolling_load_mean'] = df.groupby('periodID')['rendszerterheles_terv'].transform(
        lambda x: x.rolling(window=12, min_periods=1).mean())

    # Lag features
    df['solar_lag1'] = df.groupby('periodID')['solar_becsult_dayahead'].shift(1)
    df['load_lag1'] = df.groupby('periodID')['rendszerterheles_terv'].shift(1)

    # Additional aggregations
    stat_day = df.groupby(['season', 'weekday', 'hour', 'day_in_period'], as_index=False).agg({
        'target_flag': ['mean', 'std']
    })
    stat_day.columns = ['season', 'weekday', 'hour', 'day_in_period', 'target_day_mean', 'target_day_std']
    df = df.merge(stat_day, on=['season', 'weekday', 'hour', 'day_in_period'], how='left')

    # Interactions
    df['solar_load_ratio'] = df['solar_becsult_dayahead'] / (df['rendszerterheles_terv'] + 1)
    df['weekend'] = df['weekday'].isin([5, 6]).astype(int)

    return df

# Create features
df = create_features(df)

# Original groupby operation
stat = df.groupby(['season','weekday','hour'],as_index=False).agg({
    'target_flag':'mean'
})
stat = stat.rename(columns={"target_flag":"alike_target_avg"})
df = df.merge(stat,on=['season','weekday','hour'],how='left')

# Filter first 4 days
df_filtered = df[df['day_in_period'] < 4]

# Fill NaN values
df_filtered = df_filtered.fillna(method='ffill').fillna(method='bfill')

# Define features
features = [
    'hour_sin', 'hour_cos', 'minute_sin', 'minute_cos',
    'holiday', 'weekday', 'weekend',
    'solar_becsult_dayahead', 'rendszerterheles_terv',
    'alike_target_avg', 'target_day_mean', 'target_day_std',
    'rolling_solar_mean', 'rolling_load_mean',
    'solar_lag1', 'load_lag1',
    'solar_load_ratio'
]

# Get period IDs and create folds
period_ids = df_filtered['periodID'].unique()
np.random.seed(42)
period_ids = np.random.permutation(period_ids)
fold_size = len(period_ids) // 3
folds = [
    period_ids[:fold_size],
    period_ids[fold_size:2*fold_size],
    period_ids[2*fold_size:]
]

# Perform cross validation
results = []
for fold_idx in range(3):
    test_periods = folds[fold_idx]
    train_periods = np.concatenate([folds[i] for i in range(3) if i != fold_idx])

    # Split data
    X_train = df_filtered[df_filtered['periodID'].isin(train_periods)][features]
    y_train = df_filtered[df_filtered['periodID'].isin(train_periods)]['target_flag']

    X_test = df_filtered[df_filtered['periodID'].isin(test_periods)][features]
    y_test = df_filtered[df_filtered['periodID'].isin(test_periods)]['target_flag']

    # Scale features
    scaler = StandardScaler()
    X_train_scaled = scaler.fit_transform(X_train)
    X_test_scaled = scaler.transform(X_test)

    # Train model - try both RandomForest and LightGBM
    rf_model = RandomForestClassifier(
        n_estimators=200,
        max_depth=10,
        min_samples_split=5,
        min_samples_leaf=2,
        random_state=42,
        n_jobs=-1
    )

    lgb_model = LGBMClassifier(
        n_estimators=200,
        learning_rate=0.05,
        num_leaves=31,
        random_state=42,
        n_jobs=-1
    )

    # Train both models
    rf_model.fit(X_train_scaled, y_train)
    lgb_model.fit(X_train_scaled, y_train)

    # Get predictions
    rf_pred = rf_model.predict_proba(X_test_scaled)[:, 1]
    roc_auc_rf = roc_auc_score(y_test, rf_pred)
    lgb_pred = lgb_model.predict_proba(X_test_scaled)[:, 1]
    roc_auc_lgb = roc_auc_score(y_test, lgb_pred)

    # Ensemble predictions (average of both models)
    y_pred_proba = (rf_pred + lgb_pred) / 2

    roc_auc = roc_auc_score(y_test, y_pred_proba)

    results.append({
        'fold': fold_idx + 1,
        'roc_auc': roc_auc,
        'roc_auc_rf': roc_auc_rf,
        'roc_auc_lgb': roc_auc_lgb,
        'test_periods': len(test_periods),
        'train_periods': len(train_periods)
    })

# Display results
results_df = pd.DataFrame(results)
print("\nResults for each fold:")
print(results_df)
print("\nAverage ROC AUC score:", results_df['roc_auc'].mean())
print("Standard deviation:", results_df['roc_auc'].std())

# Feature importance analysis
feature_importance = pd.DataFrame({
    'feature': features,
    'rf_importance': rf_model.feature_importances_,
    'lgb_importance': lgb_model.feature_importances_
})
print("\nTop 10 most important features:")
print(feature_importance.sort_values('rf_importance', ascending=False).head(10))

test_data = df[df['day_in_period'] == 4]
X_submission = test_data[features]
X_submission_scaled = scaler.transform(X_submission)

# Get predictions from both models
rf_pred = rf_model.predict_proba(X_submission_scaled)[:, 1] #0.63567
lgb_pred = lgb_model.predict_proba(X_submission_scaled)[:, 1] #0.60441

# Ensemble predictions
final_predictions = (rf_pred + lgb_pred) / 2 #0.64951

# Create submission DataFrame
submission = pd.DataFrame({
    'rowID': test_data['rowID'],
    'target_flag': final_predictions
})

# Save predictions
submission.to_csv('submission.csv', index=False)

# %%
df = pd.read_csv("_data/public_data.csv")
print(df.head())

# %%
# 0.64093------------------------------------------------------------------------------
from sklearn.ensemble import RandomForestClassifier
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import GroupKFold
from lightgbm import LGBMClassifier
from sklearn.metrics import roc_auc_score
from imblearn.over_sampling import SMOTE
import pandas as pd
import numpy as np

# Load the data
df = pd.read_csv('public_data.csv')

# Create more sophisticated features
def create_features(df):
    # Time-based features
    df['hour_sin'] = np.sin(2 * np.pi * df['hour']/24)
    df['hour_cos'] = np.cos(2 * np.pi * df['hour']/24)
    df['minute_sin'] = np.sin(2 * np.pi * df['minute']/60)
    df['minute_cos'] = np.cos(2 * np.pi * df['minute']/60)
    df['day_of_week_sin'] = np.sin(2 * np.pi * df['weekday']/7)
    df['day_of_week_cos'] = np.cos(2 * np.pi * df['weekday']/7)

    # Rolling statistics for solar and load
    for window in [6, 12, 24]:
        df[f'rolling_solar_mean_{window}'] = df.groupby('periodID')['solar_becsult_dayahead'].transform(
            lambda x: x.rolling(window=window, min_periods=1).mean())
        df[f'rolling_load_mean_{window}'] = df.groupby('periodID')['rendszerterheles_terv'].transform(
            lambda x: x.rolling(window=window, min_periods=1).mean())

    # Lag features
    for lag in [1, 3, 6]:
        df[f'solar_lag_{lag}'] = df.groupby('periodID')['solar_becsult_dayahead'].shift(lag)
        df[f'load_lag_{lag}'] = df.groupby('periodID')['rendszerterheles_terv'].shift(lag)

    # Additional aggregations
    stat_day = df.groupby(['season', 'weekday', 'hour'], as_index=False).agg({
        'target_flag': ['mean', 'std']
    })
    stat_day.columns = ['season', 'weekday', 'hour', 'target_day_mean', 'target_day_std']
    df = df.merge(stat_day, on=['season', 'weekday', 'hour'], how='left')

    # Interactions
    df['solar_load_ratio'] = df['solar_becsult_dayahead'] / (df['rendszerterheles_terv'] + 1)
    df['weekend'] = df['weekday'].isin([5, 6]).astype(int)

    return df

# Create features
df = create_features(df)

# Original groupby operation
stat = df.groupby(['season','weekday','hour'],as_index=False).agg({
    'target_flag':'mean'
})
stat = stat.rename(columns={"target_flag":"alike_target_avg"})
df = df.merge(stat,on=['season','weekday','hour'],how='left')

# Filter first 4 days
df_filtered = df[df['day_in_period'] < 4]

# Fill NaN values
df_filtered = df_filtered.ffill().bfill()

# Define features
features = [
    'hour_sin', 'hour_cos', 'minute_sin', 'minute_cos',
    'day_of_week_sin', 'day_of_week_cos',
    'holyday', 'weekday', 'weekend',
    'solar_becsult_dayahead', 'rendszerterheles_terv',
    'alike_target_avg', 'target_day_mean', 'target_day_std',
    'rolling_solar_mean_6', 'rolling_solar_mean_12', 'rolling_solar_mean_24',
    'rolling_load_mean_6', 'rolling_load_mean_12', 'rolling_load_mean_24',
    'solar_lag_1', 'solar_lag_3', 'solar_lag_6',
    'load_lag_1', 'load_lag_3', 'load_lag_6',
    'solar_load_ratio'
]

# Use GroupKFold for time series data
n_splits = 5
gkf = GroupKFold(n_splits=n_splits)

# Perform cross validation
results = []
for fold, (train_index, val_index) in enumerate(gkf.split(df_filtered, groups=df_filtered['periodID'])):
    X_train = df_filtered.iloc[train_index][features]
    y_train = df_filtered.iloc[train_index]['target_flag']

    X_val = df_filtered.iloc[val_index][features]
    y_val = df_filtered.iloc[val_index]['target_flag']

    # Scale features
    scaler = StandardScaler()
    X_train_scaled = scaler.fit_transform(X_train)
    X_val_scaled = scaler.transform(X_val)

    # Apply SMOTE for handling class imbalance
    smote = SMOTE(random_state=42)
    X_train_resampled, y_train_resampled = smote.fit_resample(X_train_scaled, y_train)

    # Train models with fixed parameters
    rf_model = RandomForestClassifier(
        n_estimators=200,
        max_depth=10,
        min_samples_split=5,
        min_samples_leaf=2,
        random_state=42,
        n_jobs=-1
    )
    rf_model.fit(X_train_resampled, y_train_resampled)

    lgb_model = LGBMClassifier(
        n_estimators=200,
        learning_rate=0.05,
        num_leaves=31,
        max_depth=10,
        random_state=42,
        n_jobs=-1
    )
    lgb_model.fit(X_train_resampled, y_train_resampled)

    # Get predictions
    rf_pred = rf_model.predict_proba(X_val_scaled)[:, 1]
    roc_auc_rf = roc_auc_score(y_val, rf_pred)
    lgb_pred = lgb_model.predict_proba(X_val_scaled)[:, 1]
    roc_auc_lgb = roc_auc_score(y_val, lgb_pred)

    # Weighted ensemble predictions
    y_pred_proba = 0.6 * rf_pred + 0.4 * lgb_pred

    roc_auc = roc_auc_score(y_val, y_pred_proba)

    results.append({
        'fold': fold + 1,
        'roc_auc': roc_auc,
        'roc_auc_rf': roc_auc_rf,
        'roc_auc_lgb': roc_auc_lgb,
        'val_samples': len(val_index),
        'train_samples': len(train_index)
    })

# Display results
results_df = pd.DataFrame(results)
print("\nResults for each fold:")
print(results_df)
print("\nAverage ROC AUC score:", results_df['roc_auc'].mean())
print("Standard deviation:", results_df['roc_auc'].std())

# Feature importance analysis
feature_importance = pd.DataFrame({
    'feature': features,
    'rf_importance': rf_model.feature_importances_,
    'lgb_importance': lgb_model.feature_importances_
})
print("\nTop 10 most important features:")
print(feature_importance.sort_values('rf_importance', ascending=False).head(10))

# Prepare submission data
test_data = df[df['day_in_period'] == 4]
X_submission = test_data[features]
X_submission_scaled = scaler.transform(X_submission)

# Get predictions from both models
rf_pred = rf_model.predict_proba(X_submission_scaled)[:, 1]
lgb_pred = lgb_model.predict_proba(X_submission_scaled)[:, 1]

# Ensemble predictions
final_predictions = 0.6 * rf_pred + 0.4 * lgb_pred

# Create submission DataFrame
submission = pd.DataFrame({
    'rowID': test_data['rowID'],
    'target_flag': final_predictions
})

# Save predictions
submission.to_csv('bruh5.csv', index=False)
# Out:
# [LightGBM] [Info] Number of positive: 38094, number of negative: 38094
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.004171 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 6349
# [LightGBM] [Info] Number of data points in the train set: 76188, number of used features: 27
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=0.000000
# [LightGBM] [Info] Number of positive: 37207, number of negative: 37207
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.006588 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 6094
# [LightGBM] [Info] Number of data points in the train set: 74414, number of used features: 27
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=0.000000
# [LightGBM] [Info] Number of positive: 37476, number of negative: 37476
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.006412 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 6249
# [LightGBM] [Info] Number of data points in the train set: 74952, number of used features: 27
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=0.000000
# [LightGBM] [Info] Number of positive: 38477, number of negative: 38477
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.004909 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 6349
# [LightGBM] [Info] Number of data points in the train set: 76954, number of used features: 27
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=0.000000
# [LightGBM] [Info] Number of positive: 37854, number of negative: 37854
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.004419 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 5988
# [LightGBM] [Info] Number of data points in the train set: 75708, number of used features: 27
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=0.000000
#
# Results for each fold:
#    fold   roc_auc  roc_auc_rf  roc_auc_lgb  val_samples  train_samples
# 0     1  0.707056    0.699036     0.711937        14592          57216
# 1     2  0.746365    0.738083     0.751434        14592          57216
# 2     3  0.707964    0.698470     0.713267        14208          57600
# 3     4  0.725356    0.718508     0.728301        14208          57600
# 4     5  0.695287    0.689249     0.697705        14208          57600
#
# Average ROC AUC score: 0.716405668886331
# Standard deviation: 0.019889434705122416
#
# Top 10 most important features:
#                    feature  rf_importance  lgb_importance
# 11        alike_target_avg       0.273095             992
# 12         target_day_mean       0.265545               0
# 13          target_day_std       0.160807             548
# 19    rolling_load_mean_24       0.022076             517
# 10   rendszerterheles_terv       0.019509             323
# 9   solar_becsult_dayahead       0.019058             206
# 23              load_lag_1       0.017346             106
# 1                 hour_cos       0.017272             446
# 0                 hour_sin       0.017205             631
# 20             solar_lag_1       0.017078              74

# %%
# 0.64014 --------------------------------------------------------------------------------------
from catboost import CatBoostClassifier
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import TimeSeriesSplit
from lightgbm import LGBMClassifier
from xgboost import XGBClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import roc_auc_score
from imblearn.over_sampling import SMOTE
from bayes_opt import BayesianOptimization
import pandas as pd
import numpy as np

# Load the data
df = pd.read_csv('public_data.csv')

# Convert periodID to datetime
df['periodID'] = pd.to_datetime(df['periodID'])

# Create more sophisticated features
def create_features(df):
    # Existing features
    df['hour_sin'] = np.sin(2 * np.pi * df['hour']/24)
    df['hour_cos'] = np.cos(2 * np.pi * df['hour']/24)
    df['day_of_week_sin'] = np.sin(2 * np.pi * df['weekday']/7)
    df['day_of_week_cos'] = np.cos(2 * np.pi * df['weekday']/7)

    # Rolling statistics for solar and load
    for window in [12, 24, 48]:
        df[f'rolling_solar_mean_{window}'] = df.groupby('periodID')['solar_becsult_dayahead'].transform(
            lambda x: x.rolling(window=window, min_periods=1).mean())
        df[f'rolling_load_mean_{window}'] = df.groupby('periodID')['rendszerterheles_terv'].transform(
            lambda x: x.rolling(window=window, min_periods=1).mean())
        df[f'rolling_solar_std_{window}'] = df.groupby('periodID')['solar_becsult_dayahead'].transform(
            lambda x: x.rolling(window=window, min_periods=1).std())
        df[f'rolling_load_std_{window}'] = df.groupby('periodID')['rendszerterheles_terv'].transform(
            lambda x: x.rolling(window=window, min_periods=1).std())

    # Lag features
    for lag in [1, 12, 24]:
        df[f'solar_lag_{lag}'] = df.groupby('periodID')['solar_becsult_dayahead'].shift(lag)
        df[f'load_lag_{lag}'] = df.groupby('periodID')['rendszerterheles_terv'].shift(lag)

    # Additional aggregations
    stat_day = df.groupby(['season', 'weekday', 'hour'], as_index=False).agg({
        'target_flag': ['mean', 'std']
    })
    stat_day.columns = ['season', 'weekday', 'hour', 'target_day_mean', 'target_day_std']
    df = df.merge(stat_day, on=['season', 'weekday', 'hour'], how='left')

    # Interactions
    df['solar_load_ratio'] = df['solar_becsult_dayahead'] / (df['rendszerterheles_terv'] + 1)
    df['weekend'] = df['weekday'].isin([5, 6]).astype(int)
    df['solar_load_interaction'] = df['solar_becsult_dayahead'] * df['rendszerterheles_terv']

    # Time-based features
    df['month'] = df['periodID'].dt.month
    df['day_of_month'] = df['periodID'].dt.day

    return df

# Create features
df = create_features(df)

# Original groupby operation
stat = df.groupby(['season','weekday','hour'],as_index=False).agg({
    'target_flag':'mean'
})
stat = stat.rename(columns={"target_flag":"alike_target_avg"})
df = df.merge(stat,on=['season','weekday','hour'],how='left')

# Filter first 4 days
df_filtered = df[df['day_in_period'] < 4]

# Fill NaN values
df_filtered = df_filtered.ffill().bfill()

# Define features
features = [
    'hour_sin', 'hour_cos', 'day_of_week_sin', 'day_of_week_cos',
    'holyday', 'weekend', 'solar_becsult_dayahead', 'rendszerterheles_terv',
    'alike_target_avg', 'target_day_mean', 'target_day_std',
    'rolling_solar_mean_24', 'rolling_load_mean_24',
    'rolling_solar_std_24', 'rolling_load_std_24',
    'solar_lag_1', 'load_lag_1', 'solar_load_ratio',
    'rolling_solar_mean_12', 'rolling_load_mean_12',
    'rolling_solar_mean_48', 'rolling_load_mean_48',
    'solar_load_interaction', 'month', 'day_of_month'
]

# Use TimeSeriesSplit for time series data
tscv = TimeSeriesSplit(n_splits=5)

def optimize_lgbm(num_leaves, feature_fraction, bagging_fraction, max_depth, min_child_samples, min_child_weight):
    params = {
        'objective': 'binary',
        'metric': 'auc',
        'num_leaves': int(num_leaves),
        'feature_fraction': max(min(feature_fraction, 1), 0),
        'bagging_fraction': max(min(bagging_fraction, 1), 0),
        'max_depth': int(max_depth),
        'min_child_samples': int(min_child_samples),
        'min_child_weight': min_child_weight
    }
    cv_scores = []
    for train_index, val_index in tscv.split(df_filtered):
        X_train, X_val = df_filtered.iloc[train_index][features], df_filtered.iloc[val_index][features]
        y_train, y_val = df_filtered.iloc[train_index]['target_flag'], df_filtered.iloc[val_index]['target_flag']

        model = LGBMClassifier(**params)
        model.fit(X_train, y_train)
        preds = model.predict_proba(X_val)[:, 1]
        cv_scores.append(roc_auc_score(y_val, preds))
    return np.mean(cv_scores)

# Bayesian optimization for LightGBM
lgbm_bo = BayesianOptimization(
    optimize_lgbm,
    {
        'num_leaves': (20, 100),
        'feature_fraction': (0.1, 1.0),
        'bagging_fraction': (0.1, 1.0),
        'max_depth': (5, 15),
        'min_child_samples': (1, 50),
        'min_child_weight': (1e-5, 1e-1)
    }
)
lgbm_bo.maximize(n_iter=20)

# Get best parameters
best_lgbm_params = {
    'num_leaves': int(lgbm_bo.max['params']['num_leaves']),
    'feature_fraction': max(min(lgbm_bo.max['params']['feature_fraction'], 1), 0),
    'bagging_fraction': max(min(lgbm_bo.max['params']['bagging_fraction'], 1), 0),
    'max_depth': int(lgbm_bo.max['params']['max_depth']),
    'min_child_samples': int(lgbm_bo.max['params']['min_child_samples']),
    'min_child_weight': lgbm_bo.max['params']['min_child_weight']
}

results = []
for fold, (train_index, val_index) in enumerate(tscv.split(df_filtered)):
    X_train = df_filtered.iloc[train_index][features]
    y_train = df_filtered.iloc[train_index]['target_flag']

    X_val = df_filtered.iloc[val_index][features]
    y_val = df_filtered.iloc[val_index]['target_flag']

    # Scale features
    scaler = StandardScaler()
    X_train_scaled = scaler.fit_transform(X_train)
    X_val_scaled = scaler.transform(X_val)

    # Calculate class weights
    class_weights = dict(zip(np.unique(y_train),
                             len(y_train) / (len(np.unique(y_train)) * np.bincount(y_train))))

    # Train models
    cat_model = CatBoostClassifier(iterations=300, learning_rate=0.05, depth=6, l2_leaf_reg=3,
                                   random_seed=42, verbose=0, class_weights=class_weights)
    cat_model.fit(X_train_scaled, y_train)

    lgb_model = LGBMClassifier(**best_lgbm_params, n_estimators=300, random_state=42, n_jobs=-1)
    lgb_model.set_params(**{'class_weight': class_weights})
    lgb_model.fit(X_train_scaled, y_train)

    xgb_model = XGBClassifier(n_estimators=300, learning_rate=0.05, max_depth=6, random_state=42,
                              n_jobs=-1, scale_pos_weight=class_weights[1]/class_weights[0])
    xgb_model.fit(X_train_scaled, y_train)

    # Get predictions
    cat_pred = cat_model.predict_proba(X_val_scaled)[:, 1]
    lgb_pred = lgb_model.predict_proba(X_val_scaled)[:, 1]
    xgb_pred = xgb_model.predict_proba(X_val_scaled)[:, 1]

    # Stack predictions
    stacked_features = np.column_stack((cat_pred, lgb_pred, xgb_pred))
    meta_model = LogisticRegression(class_weight=class_weights)
    meta_model.fit(stacked_features, y_val)

    final_pred = meta_model.predict_proba(stacked_features)[:, 1]

    roc_auc = roc_auc_score(y_val, final_pred)

    results.append({
        'fold': fold + 1,
        'roc_auc': roc_auc,
        'val_samples': len(val_index),
        'train_samples': len(train_index)
    })

# Display results
results_df = pd.DataFrame(results)
print("\nResults for each fold:")
print(results_df)
print("\nAverage ROC AUC score:", results_df['roc_auc'].mean())
print("Standard deviation:", results_df['roc_auc'].std())

# Prepare submission data
test_data = df[df['day_in_period'] == 4]
X_submission = test_data[features]
X_submission_scaled = scaler.transform(X_submission)

# Get predictions from all models
cat_pred = cat_model.predict_proba(X_submission_scaled)[:, 1]
lgb_pred = lgb_model.predict_proba(X_submission_scaled)[:, 1]
xgb_pred = xgb_model.predict_proba(X_submission_scaled)[:, 1]

# Stack predictions
stacked_features = np.column_stack((cat_pred, lgb_pred, xgb_pred))
final_predictions = meta_model.predict_proba(stacked_features)[:, 1]

# Create submission DataFrame
submission = pd.DataFrame({
    'rowID': test_data['rowID'],
    'target_flag': final_predictions
})

# Save predictions
submission.to_csv('bruh8.csv', index=False)
# Out:
# |   iter    |  target   | baggin... | featur... | max_depth | min_ch... | min_ch... | num_le... |
# -------------------------------------------------------------------------------------------------
# [LightGBM] [Warning] feature_fraction is set=0.6809214852288481, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.6809214852288481
# [LightGBM] [Warning] bagging_fraction is set=0.7160945442747497, subsample=1.0 will be ignored. Current value: bagging_fraction=0.7160945442747497
# [LightGBM] [Warning] feature_fraction is set=0.6809214852288481, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.6809214852288481
# [LightGBM] [Warning] bagging_fraction is set=0.7160945442747497, subsample=1.0 will be ignored. Current value: bagging_fraction=0.7160945442747497
# [LightGBM] [Info] Number of positive: 6343, number of negative: 5625
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000727 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 3860
# [LightGBM] [Info] Number of data points in the train set: 11968, number of used features: 23
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.529997 -> initscore=0.120131
# [LightGBM] [Info] Start training from score 0.120131
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] feature_fraction is set=0.6809214852288481, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.6809214852288481
# [LightGBM] [Warning] bagging_fraction is set=0.7160945442747497, subsample=1.0 will be ignored. Current value: bagging_fraction=0.7160945442747497
# [LightGBM] [Warning] feature_fraction is set=0.6809214852288481, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.6809214852288481
# [LightGBM] [Warning] bagging_fraction is set=0.7160945442747497, subsample=1.0 will be ignored. Current value: bagging_fraction=0.7160945442747497
# [LightGBM] [Warning] feature_fraction is set=0.6809214852288481, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.6809214852288481
# [LightGBM] [Warning] bagging_fraction is set=0.7160945442747497, subsample=1.0 will be ignored. Current value: bagging_fraction=0.7160945442747497
# [LightGBM] [Info] Number of positive: 12611, number of negative: 11325
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.001595 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 3895
# [LightGBM] [Info] Number of data points in the train set: 23936, number of used features: 23
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.526863 -> initscore=0.107557
# [LightGBM] [Info] Start training from score 0.107557
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] feature_fraction is set=0.6809214852288481, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.6809214852288481
# [LightGBM] [Warning] bagging_fraction is set=0.7160945442747497, subsample=1.0 will be ignored. Current value: bagging_fraction=0.7160945442747497
# [LightGBM] [Warning] feature_fraction is set=0.6809214852288481, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.6809214852288481
# [LightGBM] [Warning] bagging_fraction is set=0.7160945442747497, subsample=1.0 will be ignored. Current value: bagging_fraction=0.7160945442747497
# [LightGBM] [Warning] feature_fraction is set=0.6809214852288481, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.6809214852288481
# [LightGBM] [Warning] bagging_fraction is set=0.7160945442747497, subsample=1.0 will be ignored. Current value: bagging_fraction=0.7160945442747497
# [LightGBM] [Info] Number of positive: 21326, number of negative: 14578
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.001421 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 3925
# [LightGBM] [Info] Number of data points in the train set: 35904, number of used features: 23
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.593973 -> initscore=0.380413
# [LightGBM] [Info] Start training from score 0.380413
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] feature_fraction is set=0.6809214852288481, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.6809214852288481
# [LightGBM] [Warning] bagging_fraction is set=0.7160945442747497, subsample=1.0 will be ignored. Current value: bagging_fraction=0.7160945442747497
# [LightGBM] [Warning] feature_fraction is set=0.6809214852288481, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.6809214852288481
# [LightGBM] [Warning] bagging_fraction is set=0.7160945442747497, subsample=1.0 will be ignored. Current value: bagging_fraction=0.7160945442747497
# [LightGBM] [Warning] feature_fraction is set=0.6809214852288481, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.6809214852288481
# [LightGBM] [Warning] bagging_fraction is set=0.7160945442747497, subsample=1.0 will be ignored. Current value: bagging_fraction=0.7160945442747497
# [LightGBM] [Info] Number of positive: 31172, number of negative: 16700
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.004614 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 3961
# [LightGBM] [Info] Number of data points in the train set: 47872, number of used features: 23
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.651153 -> initscore=0.624112
# [LightGBM] [Info] Start training from score 0.624112
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] feature_fraction is set=0.6809214852288481, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.6809214852288481
# [LightGBM] [Warning] bagging_fraction is set=0.7160945442747497, subsample=1.0 will be ignored. Current value: bagging_fraction=0.7160945442747497
# [LightGBM] [Warning] feature_fraction is set=0.6809214852288481, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.6809214852288481
# [LightGBM] [Warning] bagging_fraction is set=0.7160945442747497, subsample=1.0 will be ignored. Current value: bagging_fraction=0.7160945442747497
# [LightGBM] [Warning] feature_fraction is set=0.6809214852288481, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.6809214852288481
# [LightGBM] [Warning] bagging_fraction is set=0.7160945442747497, subsample=1.0 will be ignored. Current value: bagging_fraction=0.7160945442747497
# [LightGBM] [Info] Number of positive: 39370, number of negative: 20470
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.002525 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 3961
# [LightGBM] [Info] Number of data points in the train set: 59840, number of used features: 23
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.657921 -> initscore=0.654044
# [LightGBM] [Info] Start training from score 0.654044
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] feature_fraction is set=0.6809214852288481, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.6809214852288481
# [LightGBM] [Warning] bagging_fraction is set=0.7160945442747497, subsample=1.0 will be ignored. Current value: bagging_fraction=0.7160945442747497
# | 1         | 0.6464    | 0.7161    | 0.6809    | 12.4      | 43.59     | 0.02558   | 82.18     |
# [LightGBM] [Warning] feature_fraction is set=0.960932094713209, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.960932094713209
# [LightGBM] [Warning] bagging_fraction is set=0.8554549268451178, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8554549268451178
# [LightGBM] [Warning] feature_fraction is set=0.960932094713209, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.960932094713209
# [LightGBM] [Warning] bagging_fraction is set=0.8554549268451178, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8554549268451178
# [LightGBM] [Info] Number of positive: 6343, number of negative: 5625
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000641 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 3860
# [LightGBM] [Info] Number of data points in the train set: 11968, number of used features: 23
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.529997 -> initscore=0.120131
# [LightGBM] [Info] Start training from score 0.120131
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] feature_fraction is set=0.960932094713209, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.960932094713209
# [LightGBM] [Warning] bagging_fraction is set=0.8554549268451178, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8554549268451178
# [LightGBM] [Warning] feature_fraction is set=0.960932094713209, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.960932094713209
# [LightGBM] [Warning] bagging_fraction is set=0.8554549268451178, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8554549268451178
# [LightGBM] [Warning] feature_fraction is set=0.960932094713209, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.960932094713209
# [LightGBM] [Warning] bagging_fraction is set=0.8554549268451178, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8554549268451178
# [LightGBM] [Info] Number of positive: 12611, number of negative: 11325
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.001695 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 3895
# [LightGBM] [Info] Number of data points in the train set: 23936, number of used features: 23
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.526863 -> initscore=0.107557
# [LightGBM] [Info] Start training from score 0.107557
# [LightGBM] [Warning] feature_fraction is set=0.960932094713209, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.960932094713209
# [LightGBM] [Warning] bagging_fraction is set=0.8554549268451178, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8554549268451178
# [LightGBM] [Warning] feature_fraction is set=0.960932094713209, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.960932094713209
# [LightGBM] [Warning] bagging_fraction is set=0.8554549268451178, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8554549268451178
# [LightGBM] [Warning] feature_fraction is set=0.960932094713209, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.960932094713209
# [LightGBM] [Warning] bagging_fraction is set=0.8554549268451178, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8554549268451178
# [LightGBM] [Info] Number of positive: 21326, number of negative: 14578
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.002449 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 3925
# [LightGBM] [Info] Number of data points in the train set: 35904, number of used features: 23
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.593973 -> initscore=0.380413
# [LightGBM] [Info] Start training from score 0.380413
# [LightGBM] [Warning] feature_fraction is set=0.960932094713209, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.960932094713209
# [LightGBM] [Warning] bagging_fraction is set=0.8554549268451178, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8554549268451178
# [LightGBM] [Warning] feature_fraction is set=0.960932094713209, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.960932094713209
# [LightGBM] [Warning] bagging_fraction is set=0.8554549268451178, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8554549268451178
# [LightGBM] [Warning] feature_fraction is set=0.960932094713209, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.960932094713209
# [LightGBM] [Warning] bagging_fraction is set=0.8554549268451178, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8554549268451178
# [LightGBM] [Info] Number of positive: 31172, number of negative: 16700
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001146 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 3961
# [LightGBM] [Info] Number of data points in the train set: 47872, number of used features: 23
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.651153 -> initscore=0.624112
# [LightGBM] [Info] Start training from score 0.624112
# [LightGBM] [Warning] feature_fraction is set=0.960932094713209, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.960932094713209
# [LightGBM] [Warning] bagging_fraction is set=0.8554549268451178, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8554549268451178
# [LightGBM] [Warning] feature_fraction is set=0.960932094713209, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.960932094713209
# [LightGBM] [Warning] bagging_fraction is set=0.8554549268451178, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8554549268451178
# [LightGBM] [Warning] feature_fraction is set=0.960932094713209, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.960932094713209
# [LightGBM] [Warning] bagging_fraction is set=0.8554549268451178, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8554549268451178
# [LightGBM] [Info] Number of positive: 39370, number of negative: 20470
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.002607 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 3961
# [LightGBM] [Info] Number of data points in the train set: 59840, number of used features: 23
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.657921 -> initscore=0.654044
# [LightGBM] [Info] Start training from score 0.654044
# [LightGBM] [Warning] feature_fraction is set=0.960932094713209, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.960932094713209
# [LightGBM] [Warning] bagging_fraction is set=0.8554549268451178, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8554549268451178
# | 2         | 0.649     | 0.8555    | 0.9609    | 10.36     | 17.06     | 0.00626   | 48.41     |
# [LightGBM] [Warning] feature_fraction is set=0.11055706910473426, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.11055706910473426
# [LightGBM] [Warning] bagging_fraction is set=0.20799246916217334, subsample=1.0 will be ignored. Current value: bagging_fraction=0.20799246916217334
# [LightGBM] [Warning] feature_fraction is set=0.11055706910473426, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.11055706910473426
# [LightGBM] [Warning] bagging_fraction is set=0.20799246916217334, subsample=1.0 will be ignored. Current value: bagging_fraction=0.20799246916217334
# [LightGBM] [Info] Number of positive: 6343, number of negative: 5625
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000224 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 3860
# [LightGBM] [Info] Number of data points in the train set: 11968, number of used features: 23
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.529997 -> initscore=0.120131
# [LightGBM] [Info] Start training from score 0.120131
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] feature_fraction is set=0.11055706910473426, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.11055706910473426
# [LightGBM] [Warning] bagging_fraction is set=0.20799246916217334, subsample=1.0 will be ignored. Current value: bagging_fraction=0.20799246916217334
# [LightGBM] [Warning] feature_fraction is set=0.11055706910473426, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.11055706910473426
# [LightGBM] [Warning] bagging_fraction is set=0.20799246916217334, subsample=1.0 will be ignored. Current value: bagging_fraction=0.20799246916217334
# [LightGBM] [Warning] feature_fraction is set=0.11055706910473426, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.11055706910473426
# [LightGBM] [Warning] bagging_fraction is set=0.20799246916217334, subsample=1.0 will be ignored. Current value: bagging_fraction=0.20799246916217334
# [LightGBM] [Info] Number of positive: 12611, number of negative: 11325
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000393 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 3895
# [LightGBM] [Info] Number of data points in the train set: 23936, number of used features: 23
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.526863 -> initscore=0.107557
# [LightGBM] [Info] Start training from score 0.107557
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] feature_fraction is set=0.11055706910473426, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.11055706910473426
# [LightGBM] [Warning] bagging_fraction is set=0.20799246916217334, subsample=1.0 will be ignored. Current value: bagging_fraction=0.20799246916217334
# [LightGBM] [Warning] feature_fraction is set=0.11055706910473426, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.11055706910473426
# [LightGBM] [Warning] bagging_fraction is set=0.20799246916217334, subsample=1.0 will be ignored. Current value: bagging_fraction=0.20799246916217334
# [LightGBM] [Warning] feature_fraction is set=0.11055706910473426, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.11055706910473426
# [LightGBM] [Warning] bagging_fraction is set=0.20799246916217334, subsample=1.0 will be ignored. Current value: bagging_fraction=0.20799246916217334
# [LightGBM] [Info] Number of positive: 21326, number of negative: 14578
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000705 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 3925
# [LightGBM] [Info] Number of data points in the train set: 35904, number of used features: 23
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.593973 -> initscore=0.380413
# [LightGBM] [Info] Start training from score 0.380413
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] feature_fraction is set=0.11055706910473426, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.11055706910473426
# [LightGBM] [Warning] bagging_fraction is set=0.20799246916217334, subsample=1.0 will be ignored. Current value: bagging_fraction=0.20799246916217334
# [LightGBM] [Warning] feature_fraction is set=0.11055706910473426, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.11055706910473426
# [LightGBM] [Warning] bagging_fraction is set=0.20799246916217334, subsample=1.0 will be ignored. Current value: bagging_fraction=0.20799246916217334
# [LightGBM] [Warning] feature_fraction is set=0.11055706910473426, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.11055706910473426
# [LightGBM] [Warning] bagging_fraction is set=0.20799246916217334, subsample=1.0 will be ignored. Current value: bagging_fraction=0.20799246916217334
# [LightGBM] [Info] Number of positive: 31172, number of negative: 16700
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.001835 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 3961
# [LightGBM] [Info] Number of data points in the train set: 47872, number of used features: 23
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.651153 -> initscore=0.624112
# [LightGBM] [Info] Start training from score 0.624112
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# ...
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] feature_fraction is set=0.3701211382557533, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.3701211382557533
# [LightGBM] [Warning] bagging_fraction is set=0.10458258496263938, subsample=1.0 will be ignored. Current value: bagging_fraction=0.10458258496263938
#
# Results for each fold:
#    fold   roc_auc  val_samples  train_samples
# 0     1  0.651316        11968          11968
# 1     2  0.676419        11968          23936
# 2     3  0.653409        11968          35904
# 3     4  0.654232        11968          47872
# 4     5  0.701571        11968          59840
#
# Average ROC AUC score: 0.6673894635835599
# Standard deviation: 0.02166120585272101
# [LightGBM] [Warning] feature_fraction is set=0.3701211382557533, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.3701211382557533
# [LightGBM] [Warning] bagging_fraction is set=0.10458258496263938, subsample=1.0 will be ignored. Current value: bagging_fraction=0.10458258496263938

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import TimeSeriesSplit
from sklearn.metrics import roc_auc_score
from sklearn.feature_selection import SelectFromModel
from catboost import CatBoostClassifier
from lightgbm import LGBMClassifier
from xgboost import XGBClassifier
from sklearn.ensemble import RandomForestClassifier, StackingClassifier
from sklearn.linear_model import LogisticRegression

# Load the data
df = pd.read_csv('public_data.csv')

# Convert periodID to datetime
df['periodID'] = pd.to_datetime(df['periodID'])

def create_features(df):
    # Time-based features
    df['hour_sin'] = np.sin(2 * np.pi * df['hour']/24)
    df['hour_cos'] = np.cos(2 * np.pi * df['hour']/24)
    df['day_of_week_sin'] = np.sin(2 * np.pi * df['weekday']/7)
    df['day_of_week_cos'] = np.cos(2 * np.pi * df['weekday']/7)
    df['month_sin'] = np.sin(2 * np.pi * df['periodID'].dt.month/12)
    df['month_cos'] = np.cos(2 * np.pi * df['periodID'].dt.month/12)

    # Rolling statistics for solar and load
    for window in [12, 24, 48, 72, 168]:
        df[f'rolling_solar_mean_{window}'] = df.groupby('periodID')['solar_becsult_dayahead'].transform(
            lambda x: x.ewm(span=window, min_periods=1).mean())
        df[f'rolling_load_mean_{window}'] = df.groupby('periodID')['rendszerterheles_terv'].transform(
            lambda x: x.ewm(span=window, min_periods=1).mean())
        df[f'rolling_solar_std_{window}'] = df.groupby('periodID')['solar_becsult_dayahead'].transform(
            lambda x: x.rolling(window=window, min_periods=1).std())
        df[f'rolling_load_std_{window}'] = df.groupby('periodID')['rendszerterheles_terv'].transform(
            lambda x: x.rolling(window=window, min_periods=1).std())

    # Lag features and differences
    for lag in [1, 24, 48, 168]:
        df[f'solar_lag_{lag}'] = df.groupby('periodID')['solar_becsult_dayahead'].shift(lag)
        df[f'load_lag_{lag}'] = df.groupby('periodID')['rendszerterheles_terv'].shift(lag)
        df[f'solar_diff_{lag}'] = df['solar_becsult_dayahead'] - df[f'solar_lag_{lag}']
        df[f'load_diff_{lag}'] = df['rendszerterheles_terv'] - df[f'load_lag_{lag}']

    # Additional aggregations
    stat_day = df.groupby(['season', 'weekday', 'hour'], as_index=False).agg({
        'target_flag': ['mean', 'std']
    })
    stat_day.columns = ['season', 'weekday', 'hour', 'target_day_mean', 'target_day_std']
    df = df.merge(stat_day, on=['season', 'weekday', 'hour'], how='left')

    # Interactions
    df['solar_load_ratio'] = df['solar_becsult_dayahead'] / (df['rendszerterheles_terv'] + 1)
    df['weekend'] = df['weekday'].isin([5, 6]).astype(int)
    df['solar_load_interaction'] = df['solar_becsult_dayahead'] * df['rendszerterheles_terv']

    # Time-based features
    df['day_of_year'] = df['periodID'].dt.dayofyear
    df['week_of_year'] = df['periodID'].dt.isocalendar().week
    df['is_weekend'] = df['weekday'].isin([5, 6]).astype(int)

    return df

# Create features
df = create_features(df)

# Original groupby operation
stat = df.groupby(['season','weekday','hour'],as_index=False).agg({
    'target_flag':'mean'
})
stat = stat.rename(columns={"target_flag":"alike_target_avg"})
df = df.merge(stat,on=['season','weekday','hour'],how='left')

# Filter first 4 days
df_filtered = df[df['day_in_period'] < 4]

# Fill NaN values
df_filtered = df_filtered.ffill().bfill()

# Define features
features = [
    'hour_sin', 'hour_cos', 'day_of_week_sin', 'day_of_week_cos', 'month_sin', 'month_cos',
    'holyday', 'weekend', 'is_weekend', 'solar_becsult_dayahead', 'rendszerterheles_terv',
    'alike_target_avg', 'target_day_mean', 'target_day_std',
    'rolling_solar_mean_24', 'rolling_load_mean_24',
    'rolling_solar_std_24', 'rolling_load_std_24',
    'solar_lag_1', 'load_lag_1', 'solar_load_ratio',
    'rolling_solar_mean_12', 'rolling_load_mean_12',
    'rolling_solar_mean_48', 'rolling_load_mean_48',
    'rolling_solar_mean_72', 'rolling_load_mean_72',
    'rolling_solar_mean_168', 'rolling_load_mean_168',
    'solar_load_interaction', 'day_of_year', 'week_of_year',
    'solar_diff_24', 'load_diff_24', 'solar_diff_168', 'load_diff_168'
]

# Use TimeSeriesSplit for time series data
tscv = TimeSeriesSplit(n_splits=5)

# Perform cross validation
results = []
feature_importance_list = []

for fold, (train_index, val_index) in enumerate(tscv.split(df_filtered)):
    X_train = df_filtered.iloc[train_index][features]
    y_train = df_filtered.iloc[train_index]['target_flag']

    X_val = df_filtered.iloc[val_index][features]
    y_val = df_filtered.iloc[val_index]['target_flag']

    # Scale features
    scaler = StandardScaler()
    X_train_scaled = scaler.fit_transform(X_train)
    X_val_scaled = scaler.transform(X_val)

    # Feature selection
    selector = SelectFromModel(estimator=LGBMClassifier(n_estimators=100, random_state=42), max_features=30)
    X_train_selected = selector.fit_transform(X_train_scaled, y_train)
    X_val_selected = selector.transform(X_val_scaled)

    # Calculate class weights
    class_weights = dict(zip(np.unique(y_train),
                             len(y_train) / (len(np.unique(y_train)) * np.bincount(y_train))))

    # Define base models
    cat_model = CatBoostClassifier(iterations=500, learning_rate=0.03, depth=6, l2_leaf_reg=3,
                                   random_seed=42, verbose=0, class_weights=class_weights)
    lgb_model = LGBMClassifier(n_estimators=500, learning_rate=0.03, num_leaves=31,
                               random_state=42, class_weight=class_weights)
    xgb_model = XGBClassifier(n_estimators=500, learning_rate=0.03, max_depth=6, random_state=42,
                              scale_pos_weight=class_weights[1]/class_weights[0])
    rf_model = RandomForestClassifier(n_estimators=500, max_depth=10, random_state=42,
                                      class_weight=class_weights)

    # Create stacking ensemble
    stacking_model = StackingClassifier(
        estimators=[('cat', cat_model), ('lgb', lgb_model), ('xgb', xgb_model), ('rf', rf_model)],
        final_estimator=LogisticRegression(class_weight=class_weights),
        cv=3
    )

    # Fit stacking model
    stacking_model.fit(X_train_selected, y_train)

    # Make predictions
    y_pred = stacking_model.predict_proba(X_val_selected)[:, 1]

    roc_auc = roc_auc_score(y_val, y_pred)

    results.append({
        'fold': fold + 1,
        'roc_auc': roc_auc,
        'val_samples': len(val_index),
        'train_samples': len(train_index)
    })

    # Collect feature importance (using LightGBM as an example)
    feature_importance_list.append(pd.DataFrame({
        'feature': selector.get_feature_names_out(features),
        'importance': stacking_model.named_estimators_['lgb'].feature_importances_
    }))

# Display results
results_df = pd.DataFrame(results)
print("\nResults for each fold:")
print(results_df)
print("\nAverage ROC AUC score:", results_df['roc_auc'].mean())
print("Standard deviation:", results_df['roc_auc'].std())

# Display feature importance
feature_importance = pd.concat(feature_importance_list, ignore_index=True)
mean_feature_importance = feature_importance.groupby('feature').mean().sort_values('importance', ascending=False)
print("\nTop 15 most important features:")
print(mean_feature_importance.head(15))

# Prepare submission data
test_data = df[df['day_in_period'] == 4]
X_submission = test_data[features]
X_submission_scaled = scaler.transform(X_submission)
X_submission_selected = selector.transform(X_submission_scaled)

final_predictions = stacking_model.predict_proba(X_submission_selected)[:, 1]

submission = pd.DataFrame({
    'rowID': test_data['rowID'],
    'target_flag': final_predictions
})

submission.to_csv('submission.csv', index=False)
# Out:
# [LightGBM] [Info] Number of positive: 6343, number of negative: 5625
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.002055 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 5970
# [LightGBM] [Info] Number of data points in the train set: 11968, number of used features: 32
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.529997 -> initscore=0.120131
# [LightGBM] [Info] Start training from score 0.120131
# c:\Users\ajanko_adm\AppData\Local\miniconda3\envs\machineL\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but SelectFromModel was fitted with feature names
#   warnings.warn(
# c:\Users\ajanko_adm\AppData\Local\miniconda3\envs\machineL\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but SelectFromModel was fitted with feature names
#   warnings.warn(
# [LightGBM] [Info] Number of positive: 6343, number of negative: 5625
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000616 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 3655
# [LightGBM] [Info] Number of data points in the train set: 11968, number of used features: 15
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=-0.000000
# [LightGBM] [Info] Start training from score -0.000000
# [LightGBM] [Info] Number of positive: 4228, number of negative: 3750
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000411 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 3655
# [LightGBM] [Info] Number of data points in the train set: 7978, number of used features: 15
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.499961 -> initscore=-0.000158
# [LightGBM] [Info] Start training from score -0.000158
# [LightGBM] [Info] Number of positive: 4229, number of negative: 3750
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000367 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 3655
# [LightGBM] [Info] Number of data points in the train set: 7979, number of used features: 15
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500020 -> initscore=0.000079
# [LightGBM] [Info] Start training from score 0.000079
# [LightGBM] [Info] Number of positive: 4229, number of negative: 3750
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000401 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 3655
# [LightGBM] [Info] Number of data points in the train set: 7979, number of used features: 15
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500020 -> initscore=0.000079
# [LightGBM] [Info] Start training from score 0.000079
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[16], line 159
#     150     results.append({
#     151         'fold': fold + 1,
#     152         'roc_auc': roc_auc,
#     153         'val_samples': len(val_index),
#     154         'train_samples': len(train_index)
#     155     })
#     157     # Collect feature importance (using LightGBM as an example)
#     158     feature_importance_list.append(pd.DataFrame({
# --> 159         'feature': selector.get_feature_names_out(features),
#     160         'importance': stacking_model.named_estimators_['lgb'].feature_importances_
#     161     }))
#     163 # Display results
#     164 results_df = pd.DataFrame(results)
#
# File c:\Users\ajanko_adm\AppData\Local\miniconda3\envs\machineL\Lib\site-packages\sklearn\feature_selection\_base.py:189, in SelectorMixin.get_feature_names_out(self, input_features)
#     169 """Mask feature names according to selected features.
#     170
#     171 Parameters
#    (...)
#     186     Transformed feature names.
#     187 """
#     188 check_is_fitted(self)
# --> 189 input_features = _check_feature_names_in(self, input_features)
#     190 return input_features[self.get_support()]
#
# File c:\Users\ajanko_adm\AppData\Local\miniconda3\envs\machineL\Lib\site-packages\sklearn\utils\validation.py:2330, in _check_feature_names_in(estimator, input_features, generate_names)
#    2326 input_features = np.asarray(input_features, dtype=object)
#    2327 if feature_names_in_ is not None and not np.array_equal(
#    2328     feature_names_in_, input_features
#    2329 ):
# -> 2330     raise ValueError("input_features is not equal to feature_names_in_")
#    2332 if n_features_in_ is not None and len(input_features) != n_features_in_:
#    2333     raise ValueError(
#    2334         "input_features should have length equal to number of "
#    2335         f"features ({n_features_in_}), got {len(input_features)}"
#    2336     )
#
# ValueError: input_features is not equal to feature_names_in_

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import GroupKFold
from sklearn.metrics import roc_auc_score
from sklearn.preprocessing import StandardScaler
from lightgbm import LGBMClassifier
import xgboost as xgb

# Load the data
df = pd.read_csv('public_data.csv')

def create_features(df):
    # Time-based features
    df['hour_sin'] = np.sin(2 * np.pi * df['hour']/24)
    df['hour_cos'] = np.cos(2 * np.pi * df['hour']/24)
    df['minute_sin'] = np.sin(2 * np.pi * df['minute']/60)
    df['minute_cos'] = np.cos(2 * np.pi * df['minute']/60)

    # Enhanced rolling statistics with multiple windows
    for window in [4, 8, 12]:
        df[f'rolling_solar_mean_{window}'] = df.groupby('periodID')['solar_becsult_dayahead'].transform(
            lambda x: x.rolling(window=window, min_periods=1).mean())
        df[f'rolling_load_mean_{window}'] = df.groupby('periodID')['rendszerterheles_terv'].transform(
            lambda x: x.rolling(window=window, min_periods=1).mean())

    # Multiple lag features
    for lag in [1, 2]:
        df[f'solar_lag_{lag}'] = df.groupby('periodID')['solar_becsult_dayahead'].shift(lag)
        df[f'load_lag_{lag}'] = df.groupby('periodID')['rendszerterheles_terv'].shift(lag)

    # Target encoding with smoothing to reduce overfitting
    def smooth_target_mean(group, alpha=5):
        """Smoothed target encoding with regularization"""
        counts = group.size
        means = group.mean()
        global_mean = means.mean()
        return (means * counts + global_mean * alpha) / (counts + alpha)

    # Target encoding by different groups with smoothing
    for group_cols in [
        ['season', 'hour'],
        ['weekday', 'hour'],
        ['season', 'weekday']
    ]:
        name = '_'.join(group_cols)
        agg = df.groupby(group_cols)['target_flag'].agg(['mean', 'std']).reset_index()
        agg['smoothed_mean'] = smooth_target_mean(agg['mean'])
        df[f'target_mean_{name}'] = df[group_cols].merge(
            agg[group_cols + ['smoothed_mean']],
            on=group_cols,
            how='left'
        )['smoothed_mean']

        if agg['std'].notna().any():  # Only add std if it exists
            df[f'target_std_{name}'] = df[group_cols].merge(
                agg[group_cols + ['std']],
                on=group_cols,
                how='left'
            )['std']

    # Core features and interactions
    df['solar_load_ratio'] = df['solar_becsult_dayahead'] / (df['rendszerterheles_terv'] + 1)
    df['weekend'] = df['weekday'].isin([5, 6]).astype(int)

    # New interaction features
    df['solar_hour'] = df['solar_becsult_dayahead'] * np.sin(2 * np.pi * df['hour']/24)
    df['load_hour'] = df['rendszerterheles_terv'] * np.sin(2 * np.pi * df['hour']/24)
    df['solar_season'] = df['solar_becsult_dayahead'] * df['season']
    df['load_season'] = df['rendszerterheles_terv'] * df['season']

    return df

df = create_features(df)

# Filter first 4 days
df_filtered = df[df['day_in_period'] < 4]

# Fill NaN values
df_filtered = df_filtered.fillna(method='ffill').fillna(method='bfill')

# Define features with new additions
features = [
    # Base time features
    'hour_sin', 'hour_cos', 'minute_sin', 'minute_cos',
    'holyday', 'weekday', 'weekend',

    # Core predictors
    'solar_becsult_dayahead', 'rendszerterheles_terv',

    # Rolling means with different windows
    'rolling_solar_mean_4', 'rolling_solar_mean_8', 'rolling_solar_mean_12',
    'rolling_load_mean_4', 'rolling_load_mean_8', 'rolling_load_mean_12',

    # Lags
    'solar_lag_1', 'solar_lag_2',
    'load_lag_1', 'load_lag_2',

    # Target encodings (smoothed)
    'target_mean_season_hour', 'target_std_season_hour',
    'target_mean_weekday_hour', 'target_std_weekday_hour',
    'target_mean_season_weekday', 'target_std_season_weekday',

    # Interactions
    'solar_load_ratio', 'solar_hour', 'load_hour',
    'solar_season', 'load_season'
]

# Rest of the data preparation
period_ids = df_filtered['periodID'].unique()
np.random.seed(42)
period_ids = np.random.permutation(period_ids)
fold_size = len(period_ids) // 3
folds = [period_ids[:fold_size],
         period_ids[fold_size:2*fold_size],
         period_ids[2*fold_size:]]

results = []
for fold_idx in range(3):
    test_periods = folds[fold_idx]
    train_periods = np.concatenate([folds[i] for i in range(3) if i != fold_idx])

    X_train = df_filtered[df_filtered['periodID'].isin(train_periods)][features]
    y_train = df_filtered[df_filtered['periodID'].isin(train_periods)]['target_flag']
    X_test = df_filtered[df_filtered['periodID'].isin(test_periods)][features]
    y_test = df_filtered[df_filtered['periodID'].isin(test_periods)]['target_flag']

    scaler = StandardScaler()
    X_train_scaled = scaler.fit_transform(X_train)
    X_test_scaled = scaler.transform(X_test)

    # XGBoost with balanced parameters
    xgb_model = xgb.XGBClassifier(
        n_estimators=150,
        learning_rate=0.07,
        max_depth=5,
        min_child_weight=2,
        gamma=0.1,
        subsample=0.85,
        colsample_bytree=0.85,
        colsample_bylevel=0.85,  # Added level-wise column sampling
        reg_alpha=0.1,
        reg_lambda=1.0,
        random_state=42,
        n_jobs=-1,
        use_label_encoder=False,
        eval_metric='logloss'
    )

    # LightGBM with balanced a faszomat
    lgb_model = LGBMClassifier(
        n_estimators=150,
        learning_rate=0.05,
        num_leaves=25,
        max_depth=6,
        min_child_samples=20,
        subsample=0.85,
        colsample_bytree=0.85,
        reg_alpha=0.1,
        reg_lambda=1.0,
        random_state=42,
        n_jobs=-1
    )

    # Train with early stopping
    eval_set_xgb = [(X_train_scaled, y_train)]
    eval_set_lgb = [(X_train_scaled, y_train)]

    xgb_model.fit(X_train_scaled, y_train,
                 eval_set=eval_set_xgb)

    lgb_model.fit(X_train_scaled, y_train,
                 eval_set=eval_set_lgb)

    # Predictions
    xgb_pred = xgb_model.predict_proba(X_test_scaled)[:, 1]
    roc_auc_xgb = roc_auc_score(y_test, xgb_pred)
    lgb_pred = lgb_model.predict_proba(X_test_scaled)[:, 1]
    roc_auc_lgb = roc_auc_score(y_test, lgb_pred)

    # Weighted ensemble (slightly favoring LightGBM)
    y_pred_proba = 0.45 * xgb_pred + 0.55 * lgb_pred
    roc_auc = roc_auc_score(y_test, y_pred_proba)

    results.append({
        'fold': fold_idx + 1,
        'roc_auc': roc_auc,
        'roc_auc_xgb': roc_auc_xgb,
        'roc_auc_lgb': roc_auc_lgb,
        'test_periods': len(test_periods),
        'train_periods': len(train_periods)
    })

# Results display
results_df = pd.DataFrame(results)
print("\nResults for each fold:")
print(results_df)
print("\nAverage ROC AUC score:", results_df['roc_auc'].mean())
print("Standard deviation:", results_df['roc_auc'].std())

# Feature importance
feature_importance = pd.DataFrame({
    'feature': features,
    'xgb_importance': xgb_model.feature_importances_,
    'lgb_importance': lgb_model.feature_importances_
})
print("\nTop 10 most important features:")
print(feature_importance.sort_values('xgb_importance', ascending=False).head(10))

# Submission predictions
test_data = df[df['day_in_period'] == 4]
X_submission = test_data[features]
X_submission_scaled = scaler.transform(X_submission)

xgb_pred = xgb_model.predict_proba(X_submission_scaled)[:, 1]
lgb_pred = lgb_model.predict_proba(X_submission_scaled)[:, 1]
final_predictions = 0.45 * xgb_pred + 0.55 * lgb_pred

submission = pd.DataFrame({
    'rowID': test_data['rowID'],
    'target_flag': final_predictions
})

submission.to_csv('submission.csv', index=False)
# Out:
# C:\Users\ajanko_adm\AppData\Local\Temp\ipykernel_32552\2491390362.py:79: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df_filtered = df_filtered.fillna(method='ffill').fillna(method='bfill')
# [0]	validation_0-logloss:0.62765
# [1]	validation_0-logloss:0.62224
# [2]	validation_0-logloss:0.61715
# [3]	validation_0-logloss:0.61262
# [4]	validation_0-logloss:0.60872
# [5]	validation_0-logloss:0.60524
# [6]	validation_0-logloss:0.60194
# [7]	validation_0-logloss:0.59898
# [8]	validation_0-logloss:0.59653
# [9]	validation_0-logloss:0.59403
# [10]	validation_0-logloss:0.59163
# [11]	validation_0-logloss:0.58959
# [12]	validation_0-logloss:0.58755
# [13]	validation_0-logloss:0.58576
# [14]	validation_0-logloss:0.58411
# [15]	validation_0-logloss:0.58274
# [16]	validation_0-logloss:0.58137
# [17]	validation_0-logloss:0.58015
# [18]	validation_0-logloss:0.57889
# [19]	validation_0-logloss:0.57782
# [20]	validation_0-logloss:0.57665
# [21]	validation_0-logloss:0.57543
# [22]	validation_0-logloss:0.57441
# [23]	validation_0-logloss:0.57337
# [24]	validation_0-logloss:0.57266
# [25]	validation_0-logloss:0.57194
# [26]	validation_0-logloss:0.57105
# [27]	validation_0-logloss:0.57009
# c:\Users\ajanko_adm\AppData\Local\miniconda3\envs\machineL\Lib\site-packages\xgboost\core.py:158: UserWarning: [01:50:59] WARNING: C:\b\abs_90_bwj_86a\croot\xgboost-split_1724073762025\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [28]	validation_0-logloss:0.56909
# [29]	validation_0-logloss:0.56849
# [30]	validation_0-logloss:0.56783
# [31]	validation_0-logloss:0.56714
# [32]	validation_0-logloss:0.56640
# [33]	validation_0-logloss:0.56566
# [34]	validation_0-logloss:0.56513
# [35]	validation_0-logloss:0.56454
# [36]	validation_0-logloss:0.56363
# [37]	validation_0-logloss:0.56300
# [38]	validation_0-logloss:0.56240
# [39]	validation_0-logloss:0.56189
# [40]	validation_0-logloss:0.56141
# [41]	validation_0-logloss:0.56099
# [42]	validation_0-logloss:0.56012
# [43]	validation_0-logloss:0.55962
# [44]	validation_0-logloss:0.55884
# [45]	validation_0-logloss:0.55831
# [46]	validation_0-logloss:0.55771
# [47]	validation_0-logloss:0.55687
# [48]	validation_0-logloss:0.55652
# [49]	validation_0-logloss:0.55604
# [50]	validation_0-logloss:0.55547
# [51]	validation_0-logloss:0.55499
# [52]	validation_0-logloss:0.55443
# [53]	validation_0-logloss:0.55406
# [54]	validation_0-logloss:0.55372
# [55]	validation_0-logloss:0.55325
# [56]	validation_0-logloss:0.55265
# [57]	validation_0-logloss:0.55194
# [58]	validation_0-logloss:0.55161
# [59]	validation_0-logloss:0.55135
# [60]	validation_0-logloss:0.55082
# [61]	validation_0-logloss:0.55039
# [62]	validation_0-logloss:0.54982
# [63]	validation_0-logloss:0.54938
# [64]	validation_0-logloss:0.54913
# [65]	validation_0-logloss:0.54855
# [66]	validation_0-logloss:0.54770
# [67]	validation_0-logloss:0.54728
# [68]	validation_0-logloss:0.54677
# [69]	validation_0-logloss:0.54609
# [70]	validation_0-logloss:0.54573
# [71]	validation_0-logloss:0.54535
# [72]	validation_0-logloss:0.54486
# [73]	validation_0-logloss:0.54462
# [74]	validation_0-logloss:0.54421
# [75]	validation_0-logloss:0.54357
# [76]	validation_0-logloss:0.54334
# [77]	validation_0-logloss:0.54290
# [78]	validation_0-logloss:0.54236
# [79]	validation_0-logloss:0.54218
# [80]	validation_0-logloss:0.54169
# [81]	validation_0-logloss:0.54116
# [82]	validation_0-logloss:0.54068
# [83]	validation_0-logloss:0.54035
# [84]	validation_0-logloss:0.53995
# [85]	validation_0-logloss:0.53969
# [86]	validation_0-logloss:0.53947
# [87]	validation_0-logloss:0.53934
# [88]	validation_0-logloss:0.53905
# [89]	validation_0-logloss:0.53875
# [90]	validation_0-logloss:0.53833
# [91]	validation_0-logloss:0.53811
# [92]	validation_0-logloss:0.53785
# [93]	validation_0-logloss:0.53737
# [94]	validation_0-logloss:0.53702
# [95]	validation_0-logloss:0.53657
# [96]	validation_0-logloss:0.53641
# [97]	validation_0-logloss:0.53622
# [98]	validation_0-logloss:0.53587
# [99]	validation_0-logloss:0.53546
# [100]	validation_0-logloss:0.53527
# [101]	validation_0-logloss:0.53510
# [102]	validation_0-logloss:0.53491
# [103]	validation_0-logloss:0.53455
# [104]	validation_0-logloss:0.53427
# [105]	validation_0-logloss:0.53416
# [106]	validation_0-logloss:0.53408
# [107]	validation_0-logloss:0.53379
# [108]	validation_0-logloss:0.53332
# [109]	validation_0-logloss:0.53294
# [110]	validation_0-logloss:0.53272
# [111]	validation_0-logloss:0.53239
# [112]	validation_0-logloss:0.53220
# [113]	validation_0-logloss:0.53199
# [114]	validation_0-logloss:0.53184
# [115]	validation_0-logloss:0.53141
# [116]	validation_0-logloss:0.53115
# [117]	validation_0-logloss:0.53079
# [118]	validation_0-logloss:0.53053
# [119]	validation_0-logloss:0.53027
# [120]	validation_0-logloss:0.52982
# [121]	validation_0-logloss:0.52962
# [122]	validation_0-logloss:0.52929
# [123]	validation_0-logloss:0.52899
# [124]	validation_0-logloss:0.52863
# [125]	validation_0-logloss:0.52823
# [126]	validation_0-logloss:0.52760
# [127]	validation_0-logloss:0.52732
# [128]	validation_0-logloss:0.52691
# [129]	validation_0-logloss:0.52660
# [130]	validation_0-logloss:0.52630
# [131]	validation_0-logloss:0.52604
# [132]	validation_0-logloss:0.52581
# [133]	validation_0-logloss:0.52557
# [134]	validation_0-logloss:0.52545
# [135]	validation_0-logloss:0.52503
# [136]	validation_0-logloss:0.52473
# [137]	validation_0-logloss:0.52444
# [138]	validation_0-logloss:0.52415
# [139]	validation_0-logloss:0.52386
# [140]	validation_0-logloss:0.52338
# [141]	validation_0-logloss:0.52311
# [142]	validation_0-logloss:0.52272
# [143]	validation_0-logloss:0.52236
# [144]	validation_0-logloss:0.52212
# [145]	validation_0-logloss:0.52200
# [146]	validation_0-logloss:0.52169
# [147]	validation_0-logloss:0.52146
# [148]	validation_0-logloss:0.52125
# [149]	validation_0-logloss:0.52102
# [LightGBM] [Info] Number of positive: 32190, number of negative: 15810
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.004233 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 4884
# [LightGBM] [Info] Number of data points in the train set: 48000, number of used features: 27
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.670625 -> initscore=0.711013
# [LightGBM] [Info] Start training from score 0.711013
# [0]	validation_0-logloss:0.63829
# [1]	validation_0-logloss:0.63271
# [2]	validation_0-logloss:0.62767
# [3]	validation_0-logloss:0.62321
# [4]	validation_0-logloss:0.61921
# [5]	validation_0-logloss:0.61579
# [6]	validation_0-logloss:0.61254
# [7]	validation_0-logloss:0.60970
# [8]	validation_0-logloss:0.60711
# [9]	validation_0-logloss:0.60477
# [10]	validation_0-logloss:0.60263
# [11]	validation_0-logloss:0.60066
# [12]	validation_0-logloss:0.59892
# [13]	validation_0-logloss:0.59717
# [14]	validation_0-logloss:0.59556
# [15]	validation_0-logloss:0.59410
# [16]	validation_0-logloss:0.59276
# [17]	validation_0-logloss:0.59163
# [18]	validation_0-logloss:0.59049
# [19]	validation_0-logloss:0.58958
# [20]	validation_0-logloss:0.58857
# [21]	validation_0-logloss:0.58761
# [22]	validation_0-logloss:0.58681
# [23]	validation_0-logloss:0.58604
# [24]	validation_0-logloss:0.58522
# [25]	validation_0-logloss:0.58451
# c:\Users\ajanko_adm\AppData\Local\miniconda3\envs\machineL\Lib\site-packages\xgboost\core.py:158: UserWarning: [01:51:01] WARNING: C:\b\abs_90_bwj_86a\croot\xgboost-split_1724073762025\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [26]	validation_0-logloss:0.58380
# [27]	validation_0-logloss:0.58312
# [28]	validation_0-logloss:0.58256
# [29]	validation_0-logloss:0.58197
# [30]	validation_0-logloss:0.58146
# [31]	validation_0-logloss:0.58019
# [32]	validation_0-logloss:0.57905
# [33]	validation_0-logloss:0.57839
# [34]	validation_0-logloss:0.57765
# [35]	validation_0-logloss:0.57694
# [36]	validation_0-logloss:0.57646
# [37]	validation_0-logloss:0.57587
# [38]	validation_0-logloss:0.57480
# [39]	validation_0-logloss:0.57430
# [40]	validation_0-logloss:0.57362
# [41]	validation_0-logloss:0.57255
# [42]	validation_0-logloss:0.57191
# [43]	validation_0-logloss:0.57121
# [44]	validation_0-logloss:0.57065
# [45]	validation_0-logloss:0.57004
# [46]	validation_0-logloss:0.56969
# [47]	validation_0-logloss:0.56901
# [48]	validation_0-logloss:0.56869
# [49]	validation_0-logloss:0.56811
# [50]	validation_0-logloss:0.56782
# [51]	validation_0-logloss:0.56727
# [52]	validation_0-logloss:0.56679
# [53]	validation_0-logloss:0.56647
# [54]	validation_0-logloss:0.56629
# [55]	validation_0-logloss:0.56605
# [56]	validation_0-logloss:0.56548
# [57]	validation_0-logloss:0.56496
# [58]	validation_0-logloss:0.56452
# [59]	validation_0-logloss:0.56423
# [60]	validation_0-logloss:0.56393
# [61]	validation_0-logloss:0.56358
# [62]	validation_0-logloss:0.56319
# [63]	validation_0-logloss:0.56249
# [64]	validation_0-logloss:0.56202
# [65]	validation_0-logloss:0.56184
# [66]	validation_0-logloss:0.56155
# [67]	validation_0-logloss:0.56111
# [68]	validation_0-logloss:0.56083
# [69]	validation_0-logloss:0.56023
# [70]	validation_0-logloss:0.55962
# [71]	validation_0-logloss:0.55922
# [72]	validation_0-logloss:0.55870
# [73]	validation_0-logloss:0.55840
# [74]	validation_0-logloss:0.55809
# [75]	validation_0-logloss:0.55769
# [76]	validation_0-logloss:0.55731
# [77]	validation_0-logloss:0.55713
# [78]	validation_0-logloss:0.55684
# [79]	validation_0-logloss:0.55645
# [80]	validation_0-logloss:0.55624
# [81]	validation_0-logloss:0.55559
# [82]	validation_0-logloss:0.55519
# [83]	validation_0-logloss:0.55471
# [84]	validation_0-logloss:0.55434
# [85]	validation_0-logloss:0.55361
# [86]	validation_0-logloss:0.55325
# [87]	validation_0-logloss:0.55288
# [88]	validation_0-logloss:0.55252
# [89]	validation_0-logloss:0.55202
# [90]	validation_0-logloss:0.55159
# [91]	validation_0-logloss:0.55141
# [92]	validation_0-logloss:0.55102
# [93]	validation_0-logloss:0.55084
# [94]	validation_0-logloss:0.55049
# [95]	validation_0-logloss:0.55037
# [96]	validation_0-logloss:0.55011
# [97]	validation_0-logloss:0.54992
# [98]	validation_0-logloss:0.54960
# [99]	validation_0-logloss:0.54927
# [100]	validation_0-logloss:0.54905
# [101]	validation_0-logloss:0.54864
# [102]	validation_0-logloss:0.54799
# [103]	validation_0-logloss:0.54763
# [104]	validation_0-logloss:0.54713
# [105]	validation_0-logloss:0.54677
# [106]	validation_0-logloss:0.54657
# [107]	validation_0-logloss:0.54617
# [108]	validation_0-logloss:0.54601
# [109]	validation_0-logloss:0.54562
# [110]	validation_0-logloss:0.54530
# [111]	validation_0-logloss:0.54515
# [112]	validation_0-logloss:0.54481
# [113]	validation_0-logloss:0.54438
# [114]	validation_0-logloss:0.54410
# [115]	validation_0-logloss:0.54370
# [116]	validation_0-logloss:0.54345
# [117]	validation_0-logloss:0.54312
# [118]	validation_0-logloss:0.54297
# [119]	validation_0-logloss:0.54284
# [120]	validation_0-logloss:0.54227
# [121]	validation_0-logloss:0.54203
# [122]	validation_0-logloss:0.54177
# [123]	validation_0-logloss:0.54147
# [124]	validation_0-logloss:0.54116
# [125]	validation_0-logloss:0.54094
# [126]	validation_0-logloss:0.54065
# [127]	validation_0-logloss:0.54045
# [128]	validation_0-logloss:0.54004
# [129]	validation_0-logloss:0.53968
# [130]	validation_0-logloss:0.53942
# [131]	validation_0-logloss:0.53908
# [132]	validation_0-logloss:0.53879
# [133]	validation_0-logloss:0.53854
# [134]	validation_0-logloss:0.53824
# [135]	validation_0-logloss:0.53817
# [136]	validation_0-logloss:0.53785
# [137]	validation_0-logloss:0.53756
# [138]	validation_0-logloss:0.53735
# [139]	validation_0-logloss:0.53714
# [140]	validation_0-logloss:0.53705
# [141]	validation_0-logloss:0.53690
# [142]	validation_0-logloss:0.53679
# [143]	validation_0-logloss:0.53666
# [144]	validation_0-logloss:0.53632
# [145]	validation_0-logloss:0.53593
# [146]	validation_0-logloss:0.53537
# [147]	validation_0-logloss:0.53504
# [148]	validation_0-logloss:0.53481
# [149]	validation_0-logloss:0.53442
# [LightGBM] [Info] Number of positive: 31397, number of negative: 16603
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.002659 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 4878
# [LightGBM] [Info] Number of data points in the train set: 48000, number of used features: 27
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.654104 -> initscore=0.637129
# [LightGBM] [Info] Start training from score 0.637129
# [0]	validation_0-logloss:0.64080
# [1]	validation_0-logloss:0.63510
# [2]	validation_0-logloss:0.63015
# [3]	validation_0-logloss:0.62578
# [4]	validation_0-logloss:0.62186
# [5]	validation_0-logloss:0.61825
# [6]	validation_0-logloss:0.61507
# [7]	validation_0-logloss:0.61225
# [8]	validation_0-logloss:0.60958
# [9]	validation_0-logloss:0.60719
# [10]	validation_0-logloss:0.60483
# [11]	validation_0-logloss:0.60288
# [12]	validation_0-logloss:0.60088
# [13]	validation_0-logloss:0.59928
# [14]	validation_0-logloss:0.59771
# [15]	validation_0-logloss:0.59630
# [16]	validation_0-logloss:0.59489
# [17]	validation_0-logloss:0.59378
# [18]	validation_0-logloss:0.59274
# [19]	validation_0-logloss:0.59186
# [20]	validation_0-logloss:0.59074
# [21]	validation_0-logloss:0.58919
# [22]	validation_0-logloss:0.58844
# [23]	validation_0-logloss:0.58764
# [24]	validation_0-logloss:0.58655
# c:\Users\ajanko_adm\AppData\Local\miniconda3\envs\machineL\Lib\site-packages\xgboost\core.py:158: UserWarning: [01:51:02] WARNING: C:\b\abs_90_bwj_86a\croot\xgboost-split_1724073762025\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [25]	validation_0-logloss:0.58582
# [26]	validation_0-logloss:0.58489
# [27]	validation_0-logloss:0.58389
# [28]	validation_0-logloss:0.58291
# [29]	validation_0-logloss:0.58234
# [30]	validation_0-logloss:0.58187
# [31]	validation_0-logloss:0.58116
# [32]	validation_0-logloss:0.58009
# [33]	validation_0-logloss:0.57948
# [34]	validation_0-logloss:0.57871
# [35]	validation_0-logloss:0.57775
# [36]	validation_0-logloss:0.57713
# [37]	validation_0-logloss:0.57651
# [38]	validation_0-logloss:0.57613
# [39]	validation_0-logloss:0.57547
# [40]	validation_0-logloss:0.57510
# [41]	validation_0-logloss:0.57435
# [42]	validation_0-logloss:0.57401
# [43]	validation_0-logloss:0.57364
# [44]	validation_0-logloss:0.57320
# [45]	validation_0-logloss:0.57268
# [46]	validation_0-logloss:0.57211
# [47]	validation_0-logloss:0.57179
# [48]	validation_0-logloss:0.57096
# [49]	validation_0-logloss:0.57040
# [50]	validation_0-logloss:0.57006
# [51]	validation_0-logloss:0.56934
# [52]	validation_0-logloss:0.56889
# [53]	validation_0-logloss:0.56861
# [54]	validation_0-logloss:0.56820
# [55]	validation_0-logloss:0.56786
# [56]	validation_0-logloss:0.56752
# [57]	validation_0-logloss:0.56709
# [58]	validation_0-logloss:0.56660
# [59]	validation_0-logloss:0.56623
# [60]	validation_0-logloss:0.56554
# [61]	validation_0-logloss:0.56521
# [62]	validation_0-logloss:0.56480
# [63]	validation_0-logloss:0.56453
# [64]	validation_0-logloss:0.56430
# [65]	validation_0-logloss:0.56401
# [66]	validation_0-logloss:0.56351
# [67]	validation_0-logloss:0.56309
# [68]	validation_0-logloss:0.56266
# [69]	validation_0-logloss:0.56217
# [70]	validation_0-logloss:0.56182
# [71]	validation_0-logloss:0.56158
# [72]	validation_0-logloss:0.56131
# [73]	validation_0-logloss:0.56114
# [74]	validation_0-logloss:0.56076
# [75]	validation_0-logloss:0.56034
# [76]	validation_0-logloss:0.56007
# [77]	validation_0-logloss:0.55980
# [78]	validation_0-logloss:0.55960
# [79]	validation_0-logloss:0.55935
# [80]	validation_0-logloss:0.55914
# [81]	validation_0-logloss:0.55877
# [82]	validation_0-logloss:0.55801
# [83]	validation_0-logloss:0.55786
# [84]	validation_0-logloss:0.55764
# [85]	validation_0-logloss:0.55742
# [86]	validation_0-logloss:0.55701
# [87]	validation_0-logloss:0.55669
# [88]	validation_0-logloss:0.55631
# [89]	validation_0-logloss:0.55569
# [90]	validation_0-logloss:0.55540
# [91]	validation_0-logloss:0.55520
# [92]	validation_0-logloss:0.55444
# [93]	validation_0-logloss:0.55414
# [94]	validation_0-logloss:0.55375
# [95]	validation_0-logloss:0.55352
# [96]	validation_0-logloss:0.55298
# [97]	validation_0-logloss:0.55277
# [98]	validation_0-logloss:0.55228
# [99]	validation_0-logloss:0.55203
# [100]	validation_0-logloss:0.55176
# [101]	validation_0-logloss:0.55151
# [102]	validation_0-logloss:0.55132
# [103]	validation_0-logloss:0.55091
# [104]	validation_0-logloss:0.55065
# [105]	validation_0-logloss:0.55054
# [106]	validation_0-logloss:0.55027
# [107]	validation_0-logloss:0.55006
# [108]	validation_0-logloss:0.54988
# [109]	validation_0-logloss:0.54972
# [110]	validation_0-logloss:0.54944
# [111]	validation_0-logloss:0.54933
# [112]	validation_0-logloss:0.54901
# [113]	validation_0-logloss:0.54875
# [114]	validation_0-logloss:0.54858
# [115]	validation_0-logloss:0.54844
# [116]	validation_0-logloss:0.54824
# [117]	validation_0-logloss:0.54788
# [118]	validation_0-logloss:0.54775
# [119]	validation_0-logloss:0.54715
# [120]	validation_0-logloss:0.54691
# [121]	validation_0-logloss:0.54645
# [122]	validation_0-logloss:0.54614
# [123]	validation_0-logloss:0.54593
# [124]	validation_0-logloss:0.54551
# [125]	validation_0-logloss:0.54529
# [126]	validation_0-logloss:0.54487
# [127]	validation_0-logloss:0.54470
# [128]	validation_0-logloss:0.54445
# [129]	validation_0-logloss:0.54424
# [130]	validation_0-logloss:0.54396
# [131]	validation_0-logloss:0.54379
# [132]	validation_0-logloss:0.54364
# [133]	validation_0-logloss:0.54341
# [134]	validation_0-logloss:0.54326
# [135]	validation_0-logloss:0.54309
# [136]	validation_0-logloss:0.54272
# [137]	validation_0-logloss:0.54228
# [138]	validation_0-logloss:0.54208
# [139]	validation_0-logloss:0.54174
# [140]	validation_0-logloss:0.54137
# [141]	validation_0-logloss:0.54122
# [142]	validation_0-logloss:0.54088
# [143]	validation_0-logloss:0.54044
# [144]	validation_0-logloss:0.54006
# [145]	validation_0-logloss:0.53957
# [146]	validation_0-logloss:0.53919
# [147]	validation_0-logloss:0.53906
# [148]	validation_0-logloss:0.53880
# [149]	validation_0-logloss:0.53864
# [LightGBM] [Info] Number of positive: 30967, number of negative: 16649
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.003398 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 4878
# [LightGBM] [Info] Number of data points in the train set: 47616, number of used features: 27
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.650349 -> initscore=0.620572
# [LightGBM] [Info] Start training from score 0.620572
#
# Results for each fold:
#    fold   roc_auc  roc_auc_xgb  roc_auc_lgb  test_periods  train_periods
# 0     1  0.672244     0.670056     0.672286            62            125
# 1     2  0.687058     0.685534     0.686589            62            125
# 2     3  0.686577     0.686672     0.684966            63            124
#
# Average ROC AUC score: 0.6819595402592481
# Standard deviation: 0.008417200649419842
#
# Top 10 most important features:
#                       feature  xgb_importance  lgb_importance
# 20     target_std_season_hour        0.182227             262
# 24  target_std_season_weekday        0.062918             378
# 3                  minute_cos        0.044529             128
# 22    target_std_weekday_hour        0.039508             237
# 26                 solar_hour        0.038742             243
# 1                    hour_cos        0.038552              57
# 2                  minute_sin        0.035265              74
# 29                load_season        0.034476             375
# 27                  load_hour        0.033460             247
# 11      rolling_solar_mean_12        0.031074             141

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import GroupKFold
from sklearn.metrics import roc_auc_score
from sklearn.preprocessing import StandardScaler
from lightgbm import LGBMClassifier
import xgboost as xgb

# Load the data
df = pd.read_csv('public_data.csv')

def create_features(df):
    # Time-based features
    df['hour_sin'] = np.sin(2 * np.pi * df['hour']/24)
    df['hour_cos'] = np.cos(2 * np.pi * df['hour']/24)
    df['minute_sin'] = np.sin(2 * np.pi * df['minute']/60)
    df['minute_cos'] = np.cos(2 * np.pi * df['minute']/60)

    # Enhanced rolling statistics with multiple windows
    for window in [4, 8, 12]:
        # Mean
        df[f'rolling_solar_mean_{window}'] = df.groupby('periodID')['solar_becsult_dayahead'].transform(
            lambda x: x.rolling(window=window, min_periods=1).mean())
        df[f'rolling_load_mean_{window}'] = df.groupby('periodID')['rendszerterheles_terv'].transform(
            lambda x: x.rolling(window=window, min_periods=1).mean())

        # New: Standard deviation
        df[f'rolling_solar_std_{window}'] = df.groupby('periodID')['solar_becsult_dayahead'].transform(
            lambda x: x.rolling(window=window, min_periods=1).std())
        df[f'rolling_load_std_{window}'] = df.groupby('periodID')['rendszerterheles_terv'].transform(
            lambda x: x.rolling(window=window, min_periods=1).std())

    # Multiple lag features
    for lag in [1, 2]:
        # Basic lags
        df[f'solar_lag_{lag}'] = df.groupby('periodID')['solar_becsult_dayahead'].shift(lag)
        df[f'load_lag_{lag}'] = df.groupby('periodID')['rendszerterheles_terv'].shift(lag)

        # New: Lag differences and ratios
        df[f'solar_lag_diff_{lag}'] = df['solar_becsult_dayahead'] - df[f'solar_lag_{lag}']
        df[f'load_lag_diff_{lag}'] = df['rendszerterheles_terv'] - df[f'load_lag_{lag}']
        df[f'solar_lag_ratio_{lag}'] = df['solar_becsult_dayahead'] / (df[f'solar_lag_{lag}'] + 1)
        df[f'load_lag_ratio_{lag}'] = df['rendszerterheles_terv'] / (df[f'load_lag_{lag}'] + 1)

    # Target encoding with smoothing to reduce overfitting
    def smooth_target_mean(group, alpha=5):
        counts = group.size
        means = group.mean()
        global_mean = means.mean()
        return (means * counts + global_mean * alpha) / (counts + alpha)

    # Target encoding by different groups with smoothing
    for group_cols in [
        ['season', 'hour'],
        ['weekday', 'hour'],
        ['season', 'weekday']
    ]:
        name = '_'.join(group_cols)
        agg = df.groupby(group_cols)['target_flag'].agg(['mean', 'std']).reset_index()
        agg['smoothed_mean'] = smooth_target_mean(agg['mean'])
        df[f'target_mean_{name}'] = df[group_cols].merge(
            agg[group_cols + ['smoothed_mean']],
            on=group_cols,
            how='left'
        )['smoothed_mean']

        if agg['std'].notna().any():
            df[f'target_std_{name}'] = df[group_cols].merge(
                agg[group_cols + ['std']],
                on=group_cols,
                how='left'
            )['std']

    # Core features and interactions
    df['solar_load_ratio'] = df['solar_becsult_dayahead'] / (df['rendszerterheles_terv'] + 1)
    df['weekend'] = df['weekday'].isin([5, 6]).astype(int)

    # Interaction features
    df['solar_hour'] = df['solar_becsult_dayahead'] * np.sin(2 * np.pi * df['hour']/24)
    df['load_hour'] = df['rendszerterheles_terv'] * np.sin(2 * np.pi * df['hour']/24)
    df['solar_season'] = df['solar_becsult_dayahead'] * df['season']
    df['load_season'] = df['rendszerterheles_terv'] * df['season']

    return df

df = create_features(df)

# Filter first 4 days
df_filtered = df[df['day_in_period'] < 4]

# Fill NaN values
df_filtered = df_filtered.fillna(method='ffill').fillna(method='bfill')

# Define features with new additions
features = [
    # Base time features
    'hour_sin', 'hour_cos', 'minute_sin', 'minute_cos',
    'holyday', 'weekday', 'weekend',

    # Core predictors
    'solar_becsult_dayahead', 'rendszerterheles_terv',

    # Rolling means with different windows
    'rolling_solar_mean_4', 'rolling_solar_mean_8', 'rolling_solar_mean_12',
    'rolling_load_mean_4', 'rolling_load_mean_8', 'rolling_load_mean_12',

    # New: Rolling standard deviations
    'rolling_solar_std_4', 'rolling_solar_std_8', 'rolling_solar_std_12',
    'rolling_load_std_4', 'rolling_load_std_8', 'rolling_load_std_12',

    # Lags and new lag features
    'solar_lag_1', 'solar_lag_2',
    'load_lag_1', 'load_lag_2',
    'solar_lag_diff_1', 'solar_lag_diff_2',
    'load_lag_diff_1', 'load_lag_diff_2',
    'solar_lag_ratio_1', 'solar_lag_ratio_2',
    'load_lag_ratio_1', 'load_lag_ratio_2',

    # Target encodings (smoothed)
    'target_mean_season_hour', 'target_std_season_hour',
    'target_mean_weekday_hour', 'target_std_weekday_hour',
    'target_mean_season_weekday', 'target_std_season_weekday',

    # Interactions
    'solar_load_ratio', 'solar_hour', 'load_hour',
    'solar_season', 'load_season'
]

# Rest of the data preparation
period_ids = df_filtered['periodID'].unique()
np.random.seed(42)
period_ids = np.random.permutation(period_ids)
fold_size = len(period_ids) // 3
folds = [period_ids[:fold_size],
         period_ids[fold_size:2*fold_size],
         period_ids[2*fold_size:]]

results = []
for fold_idx in range(3):
    test_periods = folds[fold_idx]
    train_periods = np.concatenate([folds[i] for i in range(3) if i != fold_idx])

    X_train = df_filtered[df_filtered['periodID'].isin(train_periods)][features]
    y_train = df_filtered[df_filtered['periodID'].isin(train_periods)]['target_flag']
    X_test = df_filtered[df_filtered['periodID'].isin(test_periods)][features]
    y_test = df_filtered[df_filtered['periodID'].isin(test_periods)]['target_flag']

    scaler = StandardScaler()
    X_train_scaled = scaler.fit_transform(X_train)
    X_test_scaled = scaler.transform(X_test)

    # Using our best performing parameters
    xgb_model = xgb.XGBClassifier(
        n_estimators=150,
        learning_rate=0.07,
        max_depth=5,
        min_child_weight=2,
        gamma=0.1,
        subsample=0.85,
        colsample_bytree=0.85,
        colsample_bylevel=0.85,
        reg_alpha=0.1,
        reg_lambda=1.0,
        random_state=42,
        n_jobs=-1,
        use_label_encoder=False,
        eval_metric='logloss'
    )

    lgb_model = LGBMClassifier(
        n_estimators=150,
        learning_rate=0.05,
        num_leaves=25,
        max_depth=6,
        min_child_samples=20,
        subsample=0.85,
        colsample_bytree=0.85,
        reg_alpha=0.1,
        reg_lambda=1.0,
        random_state=42,
        n_jobs=-1
    )

    # Train with early stopping
    eval_set_xgb = [(X_train_scaled, y_train)]
    eval_set_lgb = [(X_train_scaled, y_train)]

    xgb_model.fit(X_train_scaled, y_train,
                 eval_set=eval_set_xgb)

    lgb_model.fit(X_train_scaled, y_train,
                 eval_set=eval_set_lgb)

    # Predictions
    xgb_pred = xgb_model.predict_proba(X_test_scaled)[:, 1]
    roc_auc_xgb = roc_auc_score(y_test, xgb_pred)
    lgb_pred = lgb_model.predict_proba(X_test_scaled)[:, 1]
    roc_auc_lgb = roc_auc_score(y_test, lgb_pred)

    # Using our best ensemble weights
    y_pred_proba = 0.45 * xgb_pred + 0.55 * lgb_pred
    roc_auc = roc_auc_score(y_test, y_pred_proba)

    results.append({
        'fold': fold_idx + 1,
        'roc_auc': roc_auc,
        'roc_auc_xgb': roc_auc_xgb,
        'roc_auc_lgb': roc_auc_lgb,
        'test_periods': len(test_periods),
        'train_periods': len(train_periods)
    })

# Results display
results_df = pd.DataFrame(results)
print("\nResults for each fold:")
print(results_df)
print("\nAverage ROC AUC score:", results_df['roc_auc'].mean())
print("Standard deviation:", results_df['roc_auc'].std())

# Feature importance
feature_importance = pd.DataFrame({
    'feature': features,
    'xgb_importance': xgb_model.feature_importances_,
    'lgb_importance': lgb_model.feature_importances_
})
print("\nTop 10 most important features:")
print(feature_importance.sort_values('xgb_importance', ascending=False).head(10))

# Submission predictions
test_data = df[df['day_in_period'] == 4]
X_submission = test_data[features]
X_submission_scaled = scaler.transform(X_submission)

xgb_pred = xgb_model.predict_proba(X_submission_scaled)[:, 1]
lgb_pred = lgb_model.predict_proba(X_submission_scaled)[:, 1]
final_predictions = 0.45 * xgb_pred + 0.55 * lgb_pred

submission = pd.DataFrame({
    'rowID': test_data['rowID'],
    'target_flag': final_predictions
})

submission.to_csv('brh14.csv', index=False)
# Out:
# C:\Users\ajanko_adm\AppData\Local\Temp\ipykernel_32552\741176904.py:92: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df_filtered = df_filtered.fillna(method='ffill').fillna(method='bfill')
# [0]	validation_0-logloss:0.62752
# [1]	validation_0-logloss:0.62204
# [2]	validation_0-logloss:0.61702
# [3]	validation_0-logloss:0.61263
# [4]	validation_0-logloss:0.60848
# [5]	validation_0-logloss:0.60494
# [6]	validation_0-logloss:0.60177
# [7]	validation_0-logloss:0.59876
# [8]	validation_0-logloss:0.59607
# [9]	validation_0-logloss:0.59362
# [10]	validation_0-logloss:0.59143
# [11]	validation_0-logloss:0.58941
# [12]	validation_0-logloss:0.58740
# [13]	validation_0-logloss:0.58568
# [14]	validation_0-logloss:0.58409
# [15]	validation_0-logloss:0.58238
# [16]	validation_0-logloss:0.58086
# [17]	validation_0-logloss:0.57957
# [18]	validation_0-logloss:0.57824
# [19]	validation_0-logloss:0.57692
# [20]	validation_0-logloss:0.57577
# [21]	validation_0-logloss:0.57469
# [22]	validation_0-logloss:0.57320
# [23]	validation_0-logloss:0.57229
# [24]	validation_0-logloss:0.57141
# c:\Users\ajanko_adm\AppData\Local\miniconda3\envs\machineL\Lib\site-packages\xgboost\core.py:158: UserWarning: [02:03:25] WARNING: C:\b\abs_90_bwj_86a\croot\xgboost-split_1724073762025\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [25]	validation_0-logloss:0.57034
# [26]	validation_0-logloss:0.56950
# [27]	validation_0-logloss:0.56882
# [28]	validation_0-logloss:0.56815
# [29]	validation_0-logloss:0.56720
# [30]	validation_0-logloss:0.56605
# [31]	validation_0-logloss:0.56520
# [32]	validation_0-logloss:0.56436
# [33]	validation_0-logloss:0.56346
# [34]	validation_0-logloss:0.56288
# [35]	validation_0-logloss:0.56222
# [36]	validation_0-logloss:0.56159
# [37]	validation_0-logloss:0.56095
# [38]	validation_0-logloss:0.56030
# [39]	validation_0-logloss:0.55928
# [40]	validation_0-logloss:0.55872
# [41]	validation_0-logloss:0.55808
# [42]	validation_0-logloss:0.55770
# [43]	validation_0-logloss:0.55705
# [44]	validation_0-logloss:0.55661
# [45]	validation_0-logloss:0.55572
# [46]	validation_0-logloss:0.55516
# [47]	validation_0-logloss:0.55453
# [48]	validation_0-logloss:0.55421
# [49]	validation_0-logloss:0.55389
# [50]	validation_0-logloss:0.55312
# [51]	validation_0-logloss:0.55266
# [52]	validation_0-logloss:0.55196
# [53]	validation_0-logloss:0.55146
# [54]	validation_0-logloss:0.55093
# [55]	validation_0-logloss:0.55018
# [56]	validation_0-logloss:0.54974
# [57]	validation_0-logloss:0.54920
# [58]	validation_0-logloss:0.54884
# [59]	validation_0-logloss:0.54839
# [60]	validation_0-logloss:0.54779
# [61]	validation_0-logloss:0.54744
# [62]	validation_0-logloss:0.54711
# [63]	validation_0-logloss:0.54681
# [64]	validation_0-logloss:0.54637
# [65]	validation_0-logloss:0.54600
# [66]	validation_0-logloss:0.54514
# [67]	validation_0-logloss:0.54456
# [68]	validation_0-logloss:0.54423
# [69]	validation_0-logloss:0.54399
# [70]	validation_0-logloss:0.54369
# [71]	validation_0-logloss:0.54344
# [72]	validation_0-logloss:0.54281
# [73]	validation_0-logloss:0.54250
# [74]	validation_0-logloss:0.54204
# [75]	validation_0-logloss:0.54162
# [76]	validation_0-logloss:0.54110
# [77]	validation_0-logloss:0.54066
# [78]	validation_0-logloss:0.54014
# [79]	validation_0-logloss:0.53991
# [80]	validation_0-logloss:0.53935
# [81]	validation_0-logloss:0.53878
# [82]	validation_0-logloss:0.53852
# [83]	validation_0-logloss:0.53826
# [84]	validation_0-logloss:0.53765
# [85]	validation_0-logloss:0.53738
# [86]	validation_0-logloss:0.53724
# [87]	validation_0-logloss:0.53699
# [88]	validation_0-logloss:0.53658
# [89]	validation_0-logloss:0.53637
# [90]	validation_0-logloss:0.53602
# [91]	validation_0-logloss:0.53585
# [92]	validation_0-logloss:0.53542
# [93]	validation_0-logloss:0.53496
# [94]	validation_0-logloss:0.53456
# [95]	validation_0-logloss:0.53409
# [96]	validation_0-logloss:0.53379
# [97]	validation_0-logloss:0.53348
# [98]	validation_0-logloss:0.53320
# [99]	validation_0-logloss:0.53300
# [100]	validation_0-logloss:0.53277
# [101]	validation_0-logloss:0.53262
# [102]	validation_0-logloss:0.53228
# [103]	validation_0-logloss:0.53193
# [104]	validation_0-logloss:0.53141
# [105]	validation_0-logloss:0.53124
# [106]	validation_0-logloss:0.53102
# [107]	validation_0-logloss:0.53056
# [108]	validation_0-logloss:0.53017
# [109]	validation_0-logloss:0.52973
# [110]	validation_0-logloss:0.52948
# [111]	validation_0-logloss:0.52921
# [112]	validation_0-logloss:0.52884
# [113]	validation_0-logloss:0.52868
# [114]	validation_0-logloss:0.52856
# [115]	validation_0-logloss:0.52793
# [116]	validation_0-logloss:0.52772
# [117]	validation_0-logloss:0.52742
# [118]	validation_0-logloss:0.52705
# [119]	validation_0-logloss:0.52675
# [120]	validation_0-logloss:0.52653
# [121]	validation_0-logloss:0.52631
# [122]	validation_0-logloss:0.52615
# [123]	validation_0-logloss:0.52578
# [124]	validation_0-logloss:0.52540
# [125]	validation_0-logloss:0.52489
# [126]	validation_0-logloss:0.52463
# [127]	validation_0-logloss:0.52440
# [128]	validation_0-logloss:0.52388
# [129]	validation_0-logloss:0.52359
# [130]	validation_0-logloss:0.52329
# [131]	validation_0-logloss:0.52305
# [132]	validation_0-logloss:0.52265
# [133]	validation_0-logloss:0.52226
# [134]	validation_0-logloss:0.52207
# [135]	validation_0-logloss:0.52184
# [136]	validation_0-logloss:0.52160
# [137]	validation_0-logloss:0.52122
# [138]	validation_0-logloss:0.52098
# [139]	validation_0-logloss:0.52075
# [140]	validation_0-logloss:0.52032
# [141]	validation_0-logloss:0.52010
# [142]	validation_0-logloss:0.51980
# [143]	validation_0-logloss:0.51964
# [144]	validation_0-logloss:0.51929
# [145]	validation_0-logloss:0.51919
# [146]	validation_0-logloss:0.51885
# [147]	validation_0-logloss:0.51845
# [148]	validation_0-logloss:0.51808
# [149]	validation_0-logloss:0.51791
# [LightGBM] [Info] Number of positive: 32190, number of negative: 15810
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001845 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 8454
# [LightGBM] [Info] Number of data points in the train set: 48000, number of used features: 41
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.670625 -> initscore=0.711013
# [LightGBM] [Info] Start training from score 0.711013
# [0]	validation_0-logloss:0.63827
# [1]	validation_0-logloss:0.63256
# [2]	validation_0-logloss:0.62745
# [3]	validation_0-logloss:0.62277
# [4]	validation_0-logloss:0.61867
# [5]	validation_0-logloss:0.61536
# [6]	validation_0-logloss:0.61214
# [7]	validation_0-logloss:0.60925
# [8]	validation_0-logloss:0.60656
# [9]	validation_0-logloss:0.60412
# [10]	validation_0-logloss:0.60186
# [11]	validation_0-logloss:0.59980
# [12]	validation_0-logloss:0.59795
# [13]	validation_0-logloss:0.59641
# [14]	validation_0-logloss:0.59483
# [15]	validation_0-logloss:0.59310
# [16]	validation_0-logloss:0.59160
# [17]	validation_0-logloss:0.59004
# [18]	validation_0-logloss:0.58866
# [19]	validation_0-logloss:0.58762
# [20]	validation_0-logloss:0.58653
# [21]	validation_0-logloss:0.58578
# [22]	validation_0-logloss:0.58493
# [23]	validation_0-logloss:0.58393
# c:\Users\ajanko_adm\AppData\Local\miniconda3\envs\machineL\Lib\site-packages\xgboost\core.py:158: UserWarning: [02:03:27] WARNING: C:\b\abs_90_bwj_86a\croot\xgboost-split_1724073762025\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [24]	validation_0-logloss:0.58291
# [25]	validation_0-logloss:0.58211
# [26]	validation_0-logloss:0.58140
# [27]	validation_0-logloss:0.58063
# [28]	validation_0-logloss:0.57975
# [29]	validation_0-logloss:0.57881
# [30]	validation_0-logloss:0.57818
# [31]	validation_0-logloss:0.57753
# [32]	validation_0-logloss:0.57684
# [33]	validation_0-logloss:0.57610
# [34]	validation_0-logloss:0.57555
# [35]	validation_0-logloss:0.57486
# [36]	validation_0-logloss:0.57393
# [37]	validation_0-logloss:0.57335
# [38]	validation_0-logloss:0.57291
# [39]	validation_0-logloss:0.57224
# [40]	validation_0-logloss:0.57170
# [41]	validation_0-logloss:0.57125
# [42]	validation_0-logloss:0.57043
# [43]	validation_0-logloss:0.56941
# [44]	validation_0-logloss:0.56856
# [45]	validation_0-logloss:0.56799
# [46]	validation_0-logloss:0.56765
# [47]	validation_0-logloss:0.56697
# [48]	validation_0-logloss:0.56646
# [49]	validation_0-logloss:0.56596
# [50]	validation_0-logloss:0.56570
# [51]	validation_0-logloss:0.56515
# [52]	validation_0-logloss:0.56484
# [53]	validation_0-logloss:0.56451
# [54]	validation_0-logloss:0.56417
# [55]	validation_0-logloss:0.56370
# [56]	validation_0-logloss:0.56316
# [57]	validation_0-logloss:0.56298
# [58]	validation_0-logloss:0.56256
# [59]	validation_0-logloss:0.56159
# [60]	validation_0-logloss:0.56140
# [61]	validation_0-logloss:0.56070
# [62]	validation_0-logloss:0.56049
# [63]	validation_0-logloss:0.56000
# [64]	validation_0-logloss:0.55941
# [65]	validation_0-logloss:0.55916
# [66]	validation_0-logloss:0.55852
# [67]	validation_0-logloss:0.55822
# [68]	validation_0-logloss:0.55789
# [69]	validation_0-logloss:0.55736
# [70]	validation_0-logloss:0.55678
# [71]	validation_0-logloss:0.55645
# [72]	validation_0-logloss:0.55612
# [73]	validation_0-logloss:0.55570
# [74]	validation_0-logloss:0.55494
# [75]	validation_0-logloss:0.55451
# [76]	validation_0-logloss:0.55413
# [77]	validation_0-logloss:0.55375
# [78]	validation_0-logloss:0.55350
# [79]	validation_0-logloss:0.55330
# [80]	validation_0-logloss:0.55307
# [81]	validation_0-logloss:0.55238
# [82]	validation_0-logloss:0.55204
# [83]	validation_0-logloss:0.55168
# [84]	validation_0-logloss:0.55122
# [85]	validation_0-logloss:0.55101
# [86]	validation_0-logloss:0.55053
# [87]	validation_0-logloss:0.55029
# [88]	validation_0-logloss:0.54984
# [89]	validation_0-logloss:0.54933
# [90]	validation_0-logloss:0.54892
# [91]	validation_0-logloss:0.54858
# [92]	validation_0-logloss:0.54840
# [93]	validation_0-logloss:0.54810
# [94]	validation_0-logloss:0.54769
# [95]	validation_0-logloss:0.54758
# [96]	validation_0-logloss:0.54714
# [97]	validation_0-logloss:0.54688
# [98]	validation_0-logloss:0.54653
# [99]	validation_0-logloss:0.54627
# [100]	validation_0-logloss:0.54596
# [101]	validation_0-logloss:0.54565
# [102]	validation_0-logloss:0.54554
# [103]	validation_0-logloss:0.54526
# [104]	validation_0-logloss:0.54510
# [105]	validation_0-logloss:0.54480
# [106]	validation_0-logloss:0.54452
# [107]	validation_0-logloss:0.54425
# [108]	validation_0-logloss:0.54391
# [109]	validation_0-logloss:0.54364
# [110]	validation_0-logloss:0.54337
# [111]	validation_0-logloss:0.54316
# [112]	validation_0-logloss:0.54295
# [113]	validation_0-logloss:0.54264
# [114]	validation_0-logloss:0.54247
# [115]	validation_0-logloss:0.54215
# [116]	validation_0-logloss:0.54187
# [117]	validation_0-logloss:0.54137
# [118]	validation_0-logloss:0.54111
# [119]	validation_0-logloss:0.54085
# [120]	validation_0-logloss:0.54036
# [121]	validation_0-logloss:0.54005
# [122]	validation_0-logloss:0.53971
# [123]	validation_0-logloss:0.53962
# [124]	validation_0-logloss:0.53938
# [125]	validation_0-logloss:0.53919
# [126]	validation_0-logloss:0.53898
# [127]	validation_0-logloss:0.53875
# [128]	validation_0-logloss:0.53843
# [129]	validation_0-logloss:0.53802
# [130]	validation_0-logloss:0.53773
# [131]	validation_0-logloss:0.53757
# [132]	validation_0-logloss:0.53711
# [133]	validation_0-logloss:0.53676
# [134]	validation_0-logloss:0.53660
# [135]	validation_0-logloss:0.53646
# [136]	validation_0-logloss:0.53614
# [137]	validation_0-logloss:0.53599
# [138]	validation_0-logloss:0.53549
# [139]	validation_0-logloss:0.53508
# [140]	validation_0-logloss:0.53482
# [141]	validation_0-logloss:0.53453
# [142]	validation_0-logloss:0.53410
# [143]	validation_0-logloss:0.53371
# [144]	validation_0-logloss:0.53335
# [145]	validation_0-logloss:0.53305
# [146]	validation_0-logloss:0.53263
# [147]	validation_0-logloss:0.53227
# [148]	validation_0-logloss:0.53200
# [149]	validation_0-logloss:0.53166
# [LightGBM] [Info] Number of positive: 31397, number of negative: 16603
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.004194 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 8448
# [LightGBM] [Info] Number of data points in the train set: 48000, number of used features: 41
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.654104 -> initscore=0.637129
# [LightGBM] [Info] Start training from score 0.637129
# [0]	validation_0-logloss:0.64077
# [1]	validation_0-logloss:0.63501
# [2]	validation_0-logloss:0.63000
# [3]	validation_0-logloss:0.62561
# [4]	validation_0-logloss:0.62160
# [5]	validation_0-logloss:0.61813
# [6]	validation_0-logloss:0.61467
# [7]	validation_0-logloss:0.61176
# [8]	validation_0-logloss:0.60900
# [9]	validation_0-logloss:0.60657
# [10]	validation_0-logloss:0.60441
# [11]	validation_0-logloss:0.60231
# [12]	validation_0-logloss:0.60043
# [13]	validation_0-logloss:0.59869
# [14]	validation_0-logloss:0.59727
# [15]	validation_0-logloss:0.59564
# [16]	validation_0-logloss:0.59410
# [17]	validation_0-logloss:0.59271
# [18]	validation_0-logloss:0.59161
# [19]	validation_0-logloss:0.59032
# c:\Users\ajanko_adm\AppData\Local\miniconda3\envs\machineL\Lib\site-packages\xgboost\core.py:158: UserWarning: [02:03:30] WARNING: C:\b\abs_90_bwj_86a\croot\xgboost-split_1724073762025\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [20]	validation_0-logloss:0.58870
# [21]	validation_0-logloss:0.58751
# [22]	validation_0-logloss:0.58624
# [23]	validation_0-logloss:0.58506
# [24]	validation_0-logloss:0.58401
# [25]	validation_0-logloss:0.58315
# [26]	validation_0-logloss:0.58233
# [27]	validation_0-logloss:0.58158
# [28]	validation_0-logloss:0.58056
# [29]	validation_0-logloss:0.57975
# [30]	validation_0-logloss:0.57918
# [31]	validation_0-logloss:0.57848
# [32]	validation_0-logloss:0.57774
# [33]	validation_0-logloss:0.57693
# [34]	validation_0-logloss:0.57642
# [35]	validation_0-logloss:0.57580
# [36]	validation_0-logloss:0.57527
# [37]	validation_0-logloss:0.57471
# [38]	validation_0-logloss:0.57429
# [39]	validation_0-logloss:0.57353
# [40]	validation_0-logloss:0.57300
# [41]	validation_0-logloss:0.57257
# [42]	validation_0-logloss:0.57187
# [43]	validation_0-logloss:0.57130
# [44]	validation_0-logloss:0.57078
# [45]	validation_0-logloss:0.57033
# [46]	validation_0-logloss:0.56981
# [47]	validation_0-logloss:0.56933
# [48]	validation_0-logloss:0.56883
# [49]	validation_0-logloss:0.56807
# [50]	validation_0-logloss:0.56752
# [51]	validation_0-logloss:0.56700
# [52]	validation_0-logloss:0.56599
# [53]	validation_0-logloss:0.56564
# [54]	validation_0-logloss:0.56528
# [55]	validation_0-logloss:0.56476
# [56]	validation_0-logloss:0.56428
# [57]	validation_0-logloss:0.56389
# [58]	validation_0-logloss:0.56361
# [59]	validation_0-logloss:0.56319
# [60]	validation_0-logloss:0.56297
# [61]	validation_0-logloss:0.56241
# [62]	validation_0-logloss:0.56191
# [63]	validation_0-logloss:0.56129
# [64]	validation_0-logloss:0.56097
# [65]	validation_0-logloss:0.56044
# [66]	validation_0-logloss:0.56018
# [67]	validation_0-logloss:0.55990
# [68]	validation_0-logloss:0.55950
# [69]	validation_0-logloss:0.55908
# [70]	validation_0-logloss:0.55871
# [71]	validation_0-logloss:0.55847
# [72]	validation_0-logloss:0.55813
# [73]	validation_0-logloss:0.55771
# [74]	validation_0-logloss:0.55745
# [75]	validation_0-logloss:0.55703
# [76]	validation_0-logloss:0.55638
# [77]	validation_0-logloss:0.55587
# [78]	validation_0-logloss:0.55553
# [79]	validation_0-logloss:0.55540
# [80]	validation_0-logloss:0.55496
# [81]	validation_0-logloss:0.55452
# [82]	validation_0-logloss:0.55411
# [83]	validation_0-logloss:0.55349
# [84]	validation_0-logloss:0.55322
# [85]	validation_0-logloss:0.55263
# [86]	validation_0-logloss:0.55228
# [87]	validation_0-logloss:0.55190
# [88]	validation_0-logloss:0.55162
# [89]	validation_0-logloss:0.55133
# [90]	validation_0-logloss:0.55096
# [91]	validation_0-logloss:0.55048
# [92]	validation_0-logloss:0.55004
# [93]	validation_0-logloss:0.54975
# [94]	validation_0-logloss:0.54936
# [95]	validation_0-logloss:0.54919
# [96]	validation_0-logloss:0.54879
# [97]	validation_0-logloss:0.54847
# [98]	validation_0-logloss:0.54812
# [99]	validation_0-logloss:0.54768
# [100]	validation_0-logloss:0.54744
# [101]	validation_0-logloss:0.54701
# [102]	validation_0-logloss:0.54661
# [103]	validation_0-logloss:0.54617
# [104]	validation_0-logloss:0.54588
# [105]	validation_0-logloss:0.54544
# [106]	validation_0-logloss:0.54504
# [107]	validation_0-logloss:0.54476
# [108]	validation_0-logloss:0.54451
# [109]	validation_0-logloss:0.54437
# [110]	validation_0-logloss:0.54395
# [111]	validation_0-logloss:0.54378
# [112]	validation_0-logloss:0.54321
# [113]	validation_0-logloss:0.54293
# [114]	validation_0-logloss:0.54271
# [115]	validation_0-logloss:0.54247
# [116]	validation_0-logloss:0.54230
# [117]	validation_0-logloss:0.54182
# [118]	validation_0-logloss:0.54149
# [119]	validation_0-logloss:0.54122
# [120]	validation_0-logloss:0.54094
# [121]	validation_0-logloss:0.54079
# [122]	validation_0-logloss:0.54027
# [123]	validation_0-logloss:0.53984
# [124]	validation_0-logloss:0.53957
# [125]	validation_0-logloss:0.53914
# [126]	validation_0-logloss:0.53886
# [127]	validation_0-logloss:0.53867
# [128]	validation_0-logloss:0.53837
# [129]	validation_0-logloss:0.53824
# [130]	validation_0-logloss:0.53777
# [131]	validation_0-logloss:0.53731
# [132]	validation_0-logloss:0.53709
# [133]	validation_0-logloss:0.53695
# [134]	validation_0-logloss:0.53683
# [135]	validation_0-logloss:0.53646
# [136]	validation_0-logloss:0.53613
# [137]	validation_0-logloss:0.53597
# [138]	validation_0-logloss:0.53572
# [139]	validation_0-logloss:0.53526
# [140]	validation_0-logloss:0.53499
# [141]	validation_0-logloss:0.53473
# [142]	validation_0-logloss:0.53442
# [143]	validation_0-logloss:0.53404
# [144]	validation_0-logloss:0.53378
# [145]	validation_0-logloss:0.53348
# [146]	validation_0-logloss:0.53307
# [147]	validation_0-logloss:0.53271
# [148]	validation_0-logloss:0.53247
# [149]	validation_0-logloss:0.53234
# [LightGBM] [Info] Number of positive: 30967, number of negative: 16649
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.003995 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 8448
# [LightGBM] [Info] Number of data points in the train set: 47616, number of used features: 41
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.650349 -> initscore=0.620572
# [LightGBM] [Info] Start training from score 0.620572
#
# Results for each fold:
#    fold   roc_auc  roc_auc_xgb  roc_auc_lgb  test_periods  train_periods
# 0     1  0.679107     0.677426     0.678494            62            125
# 1     2  0.692019     0.690829     0.691200            62            125
# 2     3  0.689864     0.688574     0.689165            63            124
#
# Average ROC AUC score: 0.6869965019975229
# Standard deviation: 0.006916715384532172
#
# Top 10 most important features:
#                       feature  xgb_importance  lgb_importance
# 34     target_std_season_hour        0.145988             195
# 38  target_std_season_weekday        0.051328             297
# 32           load_lag_ratio_2        0.032738              80
# 3                  minute_cos        0.031349             164
# 36    target_std_weekday_hour        0.030190             206
# 2                  minute_sin        0.029258              68
# 4                     holyday        0.027141              23
# 31           load_lag_ratio_1        0.026693              73
# 7      solar_becsult_dayahead        0.025300              81
# 8       rendszerterheles_terv        0.023775             114

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import GroupKFold
from sklearn.metrics import roc_auc_score
from sklearn.preprocessing import StandardScaler
from lightgbm import LGBMClassifier
import xgboost as xgb

# Load the data
df = pd.read_csv('public_data.csv')

def create_features(df):
    # Time-based features
    df['hour_sin'] = np.sin(2 * np.pi * df['hour']/24)
    df['hour_cos'] = np.cos(2 * np.pi * df['hour']/24)
    df['minute_sin'] = np.sin(2 * np.pi * df['minute']/60)
    df['minute_cos'] = np.cos(2 * np.pi * df['minute']/60)

    # Enhanced rolling statistics with multiple windows
    for window in [4, 8, 12]:
        # Mean
        df[f'rolling_solar_mean_{window}'] = df.groupby('periodID')['solar_becsult_dayahead'].transform(
            lambda x: x.rolling(window=window, min_periods=1).mean())
        df[f'rolling_load_mean_{window}'] = df.groupby('periodID')['rendszerterheles_terv'].transform(
            lambda x: x.rolling(window=window, min_periods=1).mean())

        # Standard deviation
        df[f'rolling_solar_std_{window}'] = df.groupby('periodID')['solar_becsult_dayahead'].transform(
            lambda x: x.rolling(window=window, min_periods=1).std())
        df[f'rolling_load_std_{window}'] = df.groupby('periodID')['rendszerterheles_terv'].transform(
            lambda x: x.rolling(window=window, min_periods=1).std())

    # NEW: Exponential moving averages
    for alpha in [0.3, 0.5, 0.7]:
        df[f'solar_ema_{alpha}'] = df.groupby('periodID')['solar_becsult_dayahead'].transform(
            lambda x: x.ewm(alpha=alpha, adjust=False).mean())
        df[f'load_ema_{alpha}'] = df.groupby('periodID')['rendszerterheles_terv'].transform(
            lambda x: x.ewm(alpha=alpha, adjust=False).mean())

    # Multiple lag features
    for lag in [1, 2]:
        # Basic lags
        df[f'solar_lag_{lag}'] = df.groupby('periodID')['solar_becsult_dayahead'].shift(lag)
        df[f'load_lag_{lag}'] = df.groupby('periodID')['rendszerterheles_terv'].shift(lag)

        # Lag differences and ratios
        df[f'solar_lag_diff_{lag}'] = df['solar_becsult_dayahead'] - df[f'solar_lag_{lag}']
        df[f'load_lag_diff_{lag}'] = df['rendszerterheles_terv'] - df[f'load_lag_{lag}']
        df[f'solar_lag_ratio_{lag}'] = df['solar_becsult_dayahead'] / (df[f'solar_lag_{lag}'] + 1)
        df[f'load_lag_ratio_{lag}'] = df['rendszerterheles_terv'] / (df[f'load_lag_{lag}'] + 1)

    # Target encoding with smoothing
    def smooth_target_mean(group, alpha=5):
        counts = group.size
        means = group.mean()
        global_mean = means.mean()
        return (means * counts + global_mean * alpha) / (counts + alpha)

    for group_cols in [
        ['season', 'hour'],
        ['weekday', 'hour'],
        ['season', 'weekday']
    ]:
        name = '_'.join(group_cols)
        agg = df.groupby(group_cols)['target_flag'].agg(['mean', 'std']).reset_index()
        agg['smoothed_mean'] = smooth_target_mean(agg['mean'])
        df[f'target_mean_{name}'] = df[group_cols].merge(
            agg[group_cols + ['smoothed_mean']],
            on=group_cols,
            how='left'
        )['smoothed_mean']

        if agg['std'].notna().any():
            df[f'target_std_{name}'] = df[group_cols].merge(
                agg[group_cols + ['std']],
                on=group_cols,
                how='left'
            )['std']

    # Core features and interactions
    df['solar_load_ratio'] = df['solar_becsult_dayahead'] / (df['rendszerterheles_terv'] + 1)
    df['weekend'] = df['weekday'].isin([5, 6]).astype(int)

    # Basic Interactions
    df['solar_hour'] = df['solar_becsult_dayahead'] * np.sin(2 * np.pi * df['hour']/24)
    df['load_hour'] = df['rendszerterheles_terv'] * np.sin(2 * np.pi * df['hour']/24)
    df['solar_season'] = df['solar_becsult_dayahead'] * df['season']
    df['load_season'] = df['rendszerterheles_terv'] * df['season']

    # NEW: Cross-features between lag ratios and time
    df['load_ratio_hour'] = df['load_lag_ratio_1'] * df['hour_sin']
    df['solar_ratio_hour'] = df['solar_lag_ratio_1'] * df['hour_sin']
    df['load_ratio_season'] = df['load_lag_ratio_1'] * df['season']
    df['solar_ratio_season'] = df['solar_lag_ratio_1'] * df['season']

    return df

df = create_features(df)

# Filter first 4 days
df_filtered = df[df['day_in_period'] < 4]

# Fill NaN values
df_filtered = df_filtered.fillna(method='ffill').fillna(method='bfill')

# Define features including new ones
features = [
    # Base time features
    'hour_sin', 'hour_cos', 'minute_sin', 'minute_cos',
    'holyday', 'weekday', 'weekend',

    # Core predictors
    'solar_becsult_dayahead', 'rendszerterheles_terv',

    # Rolling means and std
    'rolling_solar_mean_4', 'rolling_solar_mean_8', 'rolling_solar_mean_12',
    'rolling_load_mean_4', 'rolling_load_mean_8', 'rolling_load_mean_12',
    'rolling_solar_std_4', 'rolling_solar_std_8', 'rolling_solar_std_12',
    'rolling_load_std_4', 'rolling_load_std_8', 'rolling_load_std_12',

    # NEW: EMAs
    'solar_ema_0.3', 'solar_ema_0.5', 'solar_ema_0.7',
    'load_ema_0.3', 'load_ema_0.5', 'load_ema_0.7',

    # Lags and lag features
    'solar_lag_1', 'solar_lag_2',
    'load_lag_1', 'load_lag_2',
    'solar_lag_diff_1', 'solar_lag_diff_2',
    'load_lag_diff_1', 'load_lag_diff_2',
    'solar_lag_ratio_1', 'solar_lag_ratio_2',
    'load_lag_ratio_1', 'load_lag_ratio_2',

    # Target encodings
    'target_mean_season_hour', 'target_std_season_hour',
    'target_mean_weekday_hour', 'target_std_weekday_hour',
    'target_mean_season_weekday', 'target_std_season_weekday',

    # Interactions
    'solar_load_ratio', 'solar_hour', 'load_hour',
    'solar_season', 'load_season',

    # NEW: Cross-features
    'load_ratio_hour', 'solar_ratio_hour',
    'load_ratio_season', 'solar_ratio_season'
]

# Data preparation and model parameters stay the same
period_ids = df_filtered['periodID'].unique()
np.random.seed(42)
period_ids = np.random.permutation(period_ids)
fold_size = len(period_ids) // 3
folds = [period_ids[:fold_size],
         period_ids[fold_size:2*fold_size],
         period_ids[2*fold_size:]]

results = []
for fold_idx in range(3):
    test_periods = folds[fold_idx]
    train_periods = np.concatenate([folds[i] for i in range(3) if i != fold_idx])

    X_train = df_filtered[df_filtered['periodID'].isin(train_periods)][features]
    y_train = df_filtered[df_filtered['periodID'].isin(train_periods)]['target_flag']
    X_test = df_filtered[df_filtered['periodID'].isin(test_periods)][features]
    y_test = df_filtered[df_filtered['periodID'].isin(test_periods)]['target_flag']

    scaler = StandardScaler()
    X_train_scaled = scaler.fit_transform(X_train)
    X_test_scaled = scaler.transform(X_test)

    # Using our best performing parameters
    xgb_model = xgb.XGBClassifier(
        n_estimators=150,
        learning_rate=0.07,
        max_depth=5,
        min_child_weight=2,
        gamma=0.1,
        subsample=0.85,
        colsample_bytree=0.85,
        colsample_bylevel=0.85,
        reg_alpha=0.1,
        reg_lambda=1.0,
        random_state=42,
        n_jobs=-1,
        use_label_encoder=False,
        eval_metric='logloss'
    )

    lgb_model = LGBMClassifier(
        n_estimators=150,
        learning_rate=0.05,
        num_leaves=25,
        max_depth=6,
        min_child_samples=20,
        subsample=0.85,
        colsample_bytree=0.85,
        reg_alpha=0.1,
        reg_lambda=1.0,
        random_state=42,
        n_jobs=-1
    )

    # Train with early stopping
    eval_set_xgb = [(X_train_scaled, y_train)]
    eval_set_lgb = [(X_train_scaled, y_train)]

    xgb_model.fit(X_train_scaled, y_train,
                 eval_set=eval_set_xgb)

    lgb_model.fit(X_train_scaled, y_train,
                 eval_set=eval_set_lgb)

    # Predictions
    xgb_pred = xgb_model.predict_proba(X_test_scaled)[:, 1]
    roc_auc_xgb = roc_auc_score(y_test, xgb_pred)
    lgb_pred = lgb_model.predict_proba(X_test_scaled)[:, 1]
    roc_auc_lgb = roc_auc_score(y_test, lgb_pred)

    # Using our best ensemble weights
    y_pred_proba = 0.45 * xgb_pred + 0.55 * lgb_pred
    roc_auc = roc_auc_score(y_test, y_pred_proba)

    results.append({
        'fold': fold_idx + 1,
        'roc_auc': roc_auc,
        'roc_auc_xgb': roc_auc_xgb,
        'roc_auc_lgb': roc_auc_lgb,
        'test_periods': len(test_periods),
        'train_periods': len(train_periods)
    })

# Results display
results_df = pd.DataFrame(results)
print("\nResults for each fold:")
print(results_df)
print("\nAverage ROC AUC score:", results_df['roc_auc'].mean())
print("Standard deviation:", results_df['roc_auc'].std())

# Feature importance
feature_importance = pd.DataFrame({
    'feature': features,
    'xgb_importance': xgb_model.feature_importances_,
    'lgb_importance': lgb_model.feature_importances_
})
print("\nTop 10 most important features:")
print(feature_importance.sort_values('xgb_importance', ascending=False).head(10))

# Submission predictions
test_data = df[df['day_in_period'] == 4]
X_submission = test_data[features]
X_submission_scaled = scaler.transform(X_submission)

xgb_pred = xgb_model.predict_proba(X_submission_scaled)[:, 1]
lgb_pred = lgb_model.predict_proba(X_submission_scaled)[:, 1]
final_predictions = 0.45 * xgb_pred + 0.55 * lgb_pred

submission = pd.DataFrame({
    'rowID': test_data['rowID'],
    'target_flag': final_predictions
})

submission.to_csv('brh15.csv', index=False)
# Out:
# C:\Users\ajanko_adm\AppData\Local\Temp\ipykernel_32552\1706092080.py:104: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df_filtered = df_filtered.fillna(method='ffill').fillna(method='bfill')
# [0]	validation_0-logloss:0.62756
# [1]	validation_0-logloss:0.62214
# [2]	validation_0-logloss:0.61691
# [3]	validation_0-logloss:0.61230
# [4]	validation_0-logloss:0.60817
# [5]	validation_0-logloss:0.60444
# [6]	validation_0-logloss:0.60124
# [7]	validation_0-logloss:0.59833
# [8]	validation_0-logloss:0.59559
# [9]	validation_0-logloss:0.59297
# [10]	validation_0-logloss:0.59080
# [11]	validation_0-logloss:0.58871
# [12]	validation_0-logloss:0.58685
# [13]	validation_0-logloss:0.58509
# [14]	validation_0-logloss:0.58321
# [15]	validation_0-logloss:0.58131
# [16]	validation_0-logloss:0.57973
# [17]	validation_0-logloss:0.57831
# [18]	validation_0-logloss:0.57693
# [19]	validation_0-logloss:0.57579
# [20]	validation_0-logloss:0.57461
# c:\Users\ajanko_adm\AppData\Local\miniconda3\envs\machineL\Lib\site-packages\xgboost\core.py:158: UserWarning: [02:09:04] WARNING: C:\b\abs_90_bwj_86a\croot\xgboost-split_1724073762025\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [21]	validation_0-logloss:0.57351
# [22]	validation_0-logloss:0.57212
# [23]	validation_0-logloss:0.57115
# [24]	validation_0-logloss:0.57017
# [25]	validation_0-logloss:0.56932
# [26]	validation_0-logloss:0.56857
# [27]	validation_0-logloss:0.56738
# [28]	validation_0-logloss:0.56647
# [29]	validation_0-logloss:0.56557
# [30]	validation_0-logloss:0.56488
# [31]	validation_0-logloss:0.56408
# [32]	validation_0-logloss:0.56345
# [33]	validation_0-logloss:0.56267
# [34]	validation_0-logloss:0.56204
# [35]	validation_0-logloss:0.56135
# [36]	validation_0-logloss:0.55999
# [37]	validation_0-logloss:0.55939
# [38]	validation_0-logloss:0.55845
# [39]	validation_0-logloss:0.55795
# [40]	validation_0-logloss:0.55745
# [41]	validation_0-logloss:0.55674
# [42]	validation_0-logloss:0.55627
# [43]	validation_0-logloss:0.55584
# [44]	validation_0-logloss:0.55527
# [45]	validation_0-logloss:0.55425
# [46]	validation_0-logloss:0.55375
# [47]	validation_0-logloss:0.55319
# [48]	validation_0-logloss:0.55221
# [49]	validation_0-logloss:0.55176
# [50]	validation_0-logloss:0.55128
# [51]	validation_0-logloss:0.55043
# [52]	validation_0-logloss:0.55008
# [53]	validation_0-logloss:0.54940
# [54]	validation_0-logloss:0.54868
# [55]	validation_0-logloss:0.54836
# [56]	validation_0-logloss:0.54783
# [57]	validation_0-logloss:0.54738
# [58]	validation_0-logloss:0.54703
# [59]	validation_0-logloss:0.54659
# [60]	validation_0-logloss:0.54625
# [61]	validation_0-logloss:0.54583
# [62]	validation_0-logloss:0.54535
# [63]	validation_0-logloss:0.54512
# [64]	validation_0-logloss:0.54465
# [65]	validation_0-logloss:0.54423
# [66]	validation_0-logloss:0.54363
# [67]	validation_0-logloss:0.54331
# [68]	validation_0-logloss:0.54278
# [69]	validation_0-logloss:0.54257
# [70]	validation_0-logloss:0.54217
# [71]	validation_0-logloss:0.54184
# [72]	validation_0-logloss:0.54127
# [73]	validation_0-logloss:0.54090
# [74]	validation_0-logloss:0.54050
# [75]	validation_0-logloss:0.54031
# [76]	validation_0-logloss:0.53998
# [77]	validation_0-logloss:0.53959
# [78]	validation_0-logloss:0.53926
# [79]	validation_0-logloss:0.53905
# [80]	validation_0-logloss:0.53874
# [81]	validation_0-logloss:0.53826
# [82]	validation_0-logloss:0.53778
# [83]	validation_0-logloss:0.53754
# [84]	validation_0-logloss:0.53713
# [85]	validation_0-logloss:0.53686
# [86]	validation_0-logloss:0.53667
# [87]	validation_0-logloss:0.53631
# [88]	validation_0-logloss:0.53589
# [89]	validation_0-logloss:0.53574
# [90]	validation_0-logloss:0.53540
# [91]	validation_0-logloss:0.53513
# [92]	validation_0-logloss:0.53475
# [93]	validation_0-logloss:0.53423
# [94]	validation_0-logloss:0.53386
# [95]	validation_0-logloss:0.53318
# [96]	validation_0-logloss:0.53298
# [97]	validation_0-logloss:0.53271
# [98]	validation_0-logloss:0.53245
# [99]	validation_0-logloss:0.53205
# [100]	validation_0-logloss:0.53187
# [101]	validation_0-logloss:0.53171
# [102]	validation_0-logloss:0.53137
# [103]	validation_0-logloss:0.53101
# [104]	validation_0-logloss:0.53050
# [105]	validation_0-logloss:0.53028
# [106]	validation_0-logloss:0.52983
# [107]	validation_0-logloss:0.52934
# [108]	validation_0-logloss:0.52889
# [109]	validation_0-logloss:0.52859
# [110]	validation_0-logloss:0.52827
# [111]	validation_0-logloss:0.52764
# [112]	validation_0-logloss:0.52742
# [113]	validation_0-logloss:0.52723
# [114]	validation_0-logloss:0.52710
# [115]	validation_0-logloss:0.52669
# [116]	validation_0-logloss:0.52615
# [117]	validation_0-logloss:0.52563
# [118]	validation_0-logloss:0.52518
# [119]	validation_0-logloss:0.52496
# [120]	validation_0-logloss:0.52453
# [121]	validation_0-logloss:0.52428
# [122]	validation_0-logloss:0.52383
# [123]	validation_0-logloss:0.52359
# [124]	validation_0-logloss:0.52323
# [125]	validation_0-logloss:0.52278
# [126]	validation_0-logloss:0.52250
# [127]	validation_0-logloss:0.52215
# [128]	validation_0-logloss:0.52201
# [129]	validation_0-logloss:0.52174
# [130]	validation_0-logloss:0.52161
# [131]	validation_0-logloss:0.52138
# [132]	validation_0-logloss:0.52119
# [133]	validation_0-logloss:0.52106
# [134]	validation_0-logloss:0.52084
# [135]	validation_0-logloss:0.52064
# [136]	validation_0-logloss:0.52043
# [137]	validation_0-logloss:0.52007
# [138]	validation_0-logloss:0.51968
# [139]	validation_0-logloss:0.51948
# [140]	validation_0-logloss:0.51903
# [141]	validation_0-logloss:0.51889
# [142]	validation_0-logloss:0.51872
# [143]	validation_0-logloss:0.51857
# [144]	validation_0-logloss:0.51831
# [145]	validation_0-logloss:0.51808
# [146]	validation_0-logloss:0.51774
# [147]	validation_0-logloss:0.51752
# [148]	validation_0-logloss:0.51717
# [149]	validation_0-logloss:0.51655
# [LightGBM] [Info] Number of positive: 32190, number of negative: 15810
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.003062 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 11004
# [LightGBM] [Info] Number of data points in the train set: 48000, number of used features: 51
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.670625 -> initscore=0.711013
# [LightGBM] [Info] Start training from score 0.711013
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [0]	validation_0-logloss:0.63827
# [1]	validation_0-logloss:0.63266
# [2]	validation_0-logloss:0.62754
# [3]	validation_0-logloss:0.62305
# [4]	validation_0-logloss:0.61884
# [5]	validation_0-logloss:0.61488
# [6]	validation_0-logloss:0.61149
# [7]	validation_0-logloss:0.60864
# [8]	validation_0-logloss:0.60586
# [9]	validation_0-logloss:0.60356
# [10]	validation_0-logloss:0.60143
# [11]	validation_0-logloss:0.59944
# [12]	validation_0-logloss:0.59765
# [13]	validation_0-logloss:0.59579
# [14]	validation_0-logloss:0.59422
# [15]	validation_0-logloss:0.59237
# [16]	validation_0-logloss:0.59105
# [17]	validation_0-logloss:0.58961
# [18]	validation_0-logloss:0.58834
# [19]	validation_0-logloss:0.58722
# [20]	validation_0-logloss:0.58612
# [21]	validation_0-logloss:0.58514
# [22]	validation_0-logloss:0.58417
# [23]	validation_0-logloss:0.58318
# c:\Users\ajanko_adm\AppData\Local\miniconda3\envs\machineL\Lib\site-packages\xgboost\core.py:158: UserWarning: [02:09:07] WARNING: C:\b\abs_90_bwj_86a\croot\xgboost-split_1724073762025\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [24]	validation_0-logloss:0.58241
# [25]	validation_0-logloss:0.58160
# [26]	validation_0-logloss:0.58079
# [27]	validation_0-logloss:0.58005
# [28]	validation_0-logloss:0.57951
# [29]	validation_0-logloss:0.57855
# [30]	validation_0-logloss:0.57782
# [31]	validation_0-logloss:0.57662
# [32]	validation_0-logloss:0.57585
# [33]	validation_0-logloss:0.57532
# [34]	validation_0-logloss:0.57478
# [35]	validation_0-logloss:0.57396
# [36]	validation_0-logloss:0.57338
# [37]	validation_0-logloss:0.57274
# [38]	validation_0-logloss:0.57206
# [39]	validation_0-logloss:0.57151
# [40]	validation_0-logloss:0.57109
# [41]	validation_0-logloss:0.57052
# [42]	validation_0-logloss:0.56991
# [43]	validation_0-logloss:0.56885
# [44]	validation_0-logloss:0.56817
# [45]	validation_0-logloss:0.56734
# [46]	validation_0-logloss:0.56696
# [47]	validation_0-logloss:0.56587
# [48]	validation_0-logloss:0.56512
# [49]	validation_0-logloss:0.56457
# [50]	validation_0-logloss:0.56423
# [51]	validation_0-logloss:0.56376
# [52]	validation_0-logloss:0.56304
# [53]	validation_0-logloss:0.56253
# [54]	validation_0-logloss:0.56210
# [55]	validation_0-logloss:0.56177
# [56]	validation_0-logloss:0.56126
# [57]	validation_0-logloss:0.56081
# [58]	validation_0-logloss:0.55995
# [59]	validation_0-logloss:0.55930
# [60]	validation_0-logloss:0.55881
# [61]	validation_0-logloss:0.55860
# [62]	validation_0-logloss:0.55841
# [63]	validation_0-logloss:0.55800
# [64]	validation_0-logloss:0.55752
# [65]	validation_0-logloss:0.55709
# [66]	validation_0-logloss:0.55637
# [67]	validation_0-logloss:0.55598
# [68]	validation_0-logloss:0.55544
# [69]	validation_0-logloss:0.55474
# [70]	validation_0-logloss:0.55425
# [71]	validation_0-logloss:0.55383
# [72]	validation_0-logloss:0.55327
# [73]	validation_0-logloss:0.55300
# [74]	validation_0-logloss:0.55256
# [75]	validation_0-logloss:0.55207
# [76]	validation_0-logloss:0.55156
# [77]	validation_0-logloss:0.55105
# [78]	validation_0-logloss:0.55062
# [79]	validation_0-logloss:0.54997
# [80]	validation_0-logloss:0.54947
# [81]	validation_0-logloss:0.54920
# [82]	validation_0-logloss:0.54899
# [83]	validation_0-logloss:0.54877
# [84]	validation_0-logloss:0.54827
# [85]	validation_0-logloss:0.54790
# [86]	validation_0-logloss:0.54737
# [87]	validation_0-logloss:0.54682
# [88]	validation_0-logloss:0.54649
# [89]	validation_0-logloss:0.54618
# [90]	validation_0-logloss:0.54561
# [91]	validation_0-logloss:0.54537
# [92]	validation_0-logloss:0.54481
# [93]	validation_0-logloss:0.54452
# [94]	validation_0-logloss:0.54418
# [95]	validation_0-logloss:0.54404
# [96]	validation_0-logloss:0.54366
# [97]	validation_0-logloss:0.54349
# [98]	validation_0-logloss:0.54331
# [99]	validation_0-logloss:0.54288
# [100]	validation_0-logloss:0.54272
# [101]	validation_0-logloss:0.54245
# [102]	validation_0-logloss:0.54230
# [103]	validation_0-logloss:0.54187
# [104]	validation_0-logloss:0.54172
# [105]	validation_0-logloss:0.54145
# [106]	validation_0-logloss:0.54132
# [107]	validation_0-logloss:0.54081
# [108]	validation_0-logloss:0.54051
# [109]	validation_0-logloss:0.54022
# [110]	validation_0-logloss:0.53996
# [111]	validation_0-logloss:0.53944
# [112]	validation_0-logloss:0.53912
# [113]	validation_0-logloss:0.53892
# [114]	validation_0-logloss:0.53870
# [115]	validation_0-logloss:0.53839
# [116]	validation_0-logloss:0.53799
# [117]	validation_0-logloss:0.53739
# [118]	validation_0-logloss:0.53710
# [119]	validation_0-logloss:0.53665
# [120]	validation_0-logloss:0.53633
# [121]	validation_0-logloss:0.53594
# [122]	validation_0-logloss:0.53562
# [123]	validation_0-logloss:0.53547
# [124]	validation_0-logloss:0.53512
# [125]	validation_0-logloss:0.53469
# [126]	validation_0-logloss:0.53453
# [127]	validation_0-logloss:0.53428
# [128]	validation_0-logloss:0.53396
# [129]	validation_0-logloss:0.53353
# [130]	validation_0-logloss:0.53326
# [131]	validation_0-logloss:0.53309
# [132]	validation_0-logloss:0.53264
# [133]	validation_0-logloss:0.53248
# [134]	validation_0-logloss:0.53211
# [135]	validation_0-logloss:0.53198
# [136]	validation_0-logloss:0.53171
# [137]	validation_0-logloss:0.53143
# [138]	validation_0-logloss:0.53107
# [139]	validation_0-logloss:0.53090
# [140]	validation_0-logloss:0.53045
# [141]	validation_0-logloss:0.53011
# [142]	validation_0-logloss:0.52983
# [143]	validation_0-logloss:0.52948
# [144]	validation_0-logloss:0.52902
# [145]	validation_0-logloss:0.52870
# [146]	validation_0-logloss:0.52849
# [147]	validation_0-logloss:0.52808
# [148]	validation_0-logloss:0.52785
# [149]	validation_0-logloss:0.52760
# [LightGBM] [Info] Number of positive: 31397, number of negative: 16603
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.008113 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 10998
# [LightGBM] [Info] Number of data points in the train set: 48000, number of used features: 51
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.654104 -> initscore=0.637129
# [LightGBM] [Info] Start training from score 0.637129
# [0]	validation_0-logloss:0.64075
# [1]	validation_0-logloss:0.63519
# [2]	validation_0-logloss:0.63006
# [3]	validation_0-logloss:0.62559
# [4]	validation_0-logloss:0.62154
# [5]	validation_0-logloss:0.61785
# [6]	validation_0-logloss:0.61456
# [7]	validation_0-logloss:0.61159
# [8]	validation_0-logloss:0.60901
# [9]	validation_0-logloss:0.60657
# [10]	validation_0-logloss:0.60396
# [11]	validation_0-logloss:0.60165
# [12]	validation_0-logloss:0.59968
# [13]	validation_0-logloss:0.59770
# [14]	validation_0-logloss:0.59626
# c:\Users\ajanko_adm\AppData\Local\miniconda3\envs\machineL\Lib\site-packages\xgboost\core.py:158: UserWarning: [02:09:09] WARNING: C:\b\abs_90_bwj_86a\croot\xgboost-split_1724073762025\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [15]	validation_0-logloss:0.59441
# [16]	validation_0-logloss:0.59291
# [17]	validation_0-logloss:0.59154
# [18]	validation_0-logloss:0.59032
# [19]	validation_0-logloss:0.58916
# [20]	validation_0-logloss:0.58803
# [21]	validation_0-logloss:0.58663
# [22]	validation_0-logloss:0.58578
# [23]	validation_0-logloss:0.58483
# [24]	validation_0-logloss:0.58365
# [25]	validation_0-logloss:0.58273
# [26]	validation_0-logloss:0.58185
# [27]	validation_0-logloss:0.58070
# [28]	validation_0-logloss:0.57996
# [29]	validation_0-logloss:0.57921
# [30]	validation_0-logloss:0.57862
# [31]	validation_0-logloss:0.57765
# [32]	validation_0-logloss:0.57682
# [33]	validation_0-logloss:0.57611
# [34]	validation_0-logloss:0.57555
# [35]	validation_0-logloss:0.57505
# [36]	validation_0-logloss:0.57447
# [37]	validation_0-logloss:0.57381
# [38]	validation_0-logloss:0.57320
# [39]	validation_0-logloss:0.57244
# [40]	validation_0-logloss:0.57180
# [41]	validation_0-logloss:0.57127
# [42]	validation_0-logloss:0.57074
# [43]	validation_0-logloss:0.57019
# [44]	validation_0-logloss:0.56966
# [45]	validation_0-logloss:0.56897
# [46]	validation_0-logloss:0.56816
# [47]	validation_0-logloss:0.56766
# [48]	validation_0-logloss:0.56701
# [49]	validation_0-logloss:0.56599
# [50]	validation_0-logloss:0.56561
# [51]	validation_0-logloss:0.56519
# [52]	validation_0-logloss:0.56470
# [53]	validation_0-logloss:0.56446
# [54]	validation_0-logloss:0.56372
# [55]	validation_0-logloss:0.56303
# [56]	validation_0-logloss:0.56263
# [57]	validation_0-logloss:0.56180
# [58]	validation_0-logloss:0.56154
# [59]	validation_0-logloss:0.56126
# [60]	validation_0-logloss:0.56106
# [61]	validation_0-logloss:0.56055
# [62]	validation_0-logloss:0.56016
# [63]	validation_0-logloss:0.55984
# [64]	validation_0-logloss:0.55946
# [65]	validation_0-logloss:0.55893
# [66]	validation_0-logloss:0.55852
# [67]	validation_0-logloss:0.55830
# [68]	validation_0-logloss:0.55777
# [69]	validation_0-logloss:0.55701
# [70]	validation_0-logloss:0.55638
# [71]	validation_0-logloss:0.55619
# [72]	validation_0-logloss:0.55588
# [73]	validation_0-logloss:0.55548
# [74]	validation_0-logloss:0.55504
# [75]	validation_0-logloss:0.55465
# [76]	validation_0-logloss:0.55443
# [77]	validation_0-logloss:0.55393
# [78]	validation_0-logloss:0.55345
# [79]	validation_0-logloss:0.55327
# [80]	validation_0-logloss:0.55298
# [81]	validation_0-logloss:0.55262
# [82]	validation_0-logloss:0.55222
# [83]	validation_0-logloss:0.55173
# [84]	validation_0-logloss:0.55142
# [85]	validation_0-logloss:0.55118
# [86]	validation_0-logloss:0.55093
# [87]	validation_0-logloss:0.55061
# [88]	validation_0-logloss:0.55022
# [89]	validation_0-logloss:0.54996
# [90]	validation_0-logloss:0.54965
# [91]	validation_0-logloss:0.54928
# [92]	validation_0-logloss:0.54853
# [93]	validation_0-logloss:0.54826
# [94]	validation_0-logloss:0.54783
# [95]	validation_0-logloss:0.54732
# [96]	validation_0-logloss:0.54694
# [97]	validation_0-logloss:0.54665
# [98]	validation_0-logloss:0.54626
# [99]	validation_0-logloss:0.54586
# [100]	validation_0-logloss:0.54562
# [101]	validation_0-logloss:0.54522
# [102]	validation_0-logloss:0.54482
# [103]	validation_0-logloss:0.54442
# [104]	validation_0-logloss:0.54404
# [105]	validation_0-logloss:0.54354
# [106]	validation_0-logloss:0.54317
# [107]	validation_0-logloss:0.54292
# [108]	validation_0-logloss:0.54260
# [109]	validation_0-logloss:0.54243
# [110]	validation_0-logloss:0.54214
# [111]	validation_0-logloss:0.54195
# [112]	validation_0-logloss:0.54167
# [113]	validation_0-logloss:0.54144
# [114]	validation_0-logloss:0.54119
# [115]	validation_0-logloss:0.54094
# [116]	validation_0-logloss:0.54072
# [117]	validation_0-logloss:0.54038
# [118]	validation_0-logloss:0.54005
# [119]	validation_0-logloss:0.53970
# [120]	validation_0-logloss:0.53953
# [121]	validation_0-logloss:0.53914
# [122]	validation_0-logloss:0.53861
# [123]	validation_0-logloss:0.53822
# [124]	validation_0-logloss:0.53791
# [125]	validation_0-logloss:0.53756
# [126]	validation_0-logloss:0.53711
# [127]	validation_0-logloss:0.53696
# [128]	validation_0-logloss:0.53668
# [129]	validation_0-logloss:0.53654
# [130]	validation_0-logloss:0.53618
# [131]	validation_0-logloss:0.53599
# [132]	validation_0-logloss:0.53586
# [133]	validation_0-logloss:0.53563
# [134]	validation_0-logloss:0.53543
# [135]	validation_0-logloss:0.53522
# [136]	validation_0-logloss:0.53485
# [137]	validation_0-logloss:0.53464
# [138]	validation_0-logloss:0.53437
# [139]	validation_0-logloss:0.53408
# [140]	validation_0-logloss:0.53359
# [141]	validation_0-logloss:0.53321
# [142]	validation_0-logloss:0.53282
# [143]	validation_0-logloss:0.53246
# [144]	validation_0-logloss:0.53228
# [145]	validation_0-logloss:0.53178
# [146]	validation_0-logloss:0.53145
# [147]	validation_0-logloss:0.53109
# [148]	validation_0-logloss:0.53076
# [149]	validation_0-logloss:0.53053
# [LightGBM] [Info] Number of positive: 30967, number of negative: 16649
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.005156 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 10998
# [LightGBM] [Info] Number of data points in the train set: 47616, number of used features: 51
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.650349 -> initscore=0.620572
# [LightGBM] [Info] Start training from score 0.620572
#
# Results for each fold:
#    fold   roc_auc  roc_auc_xgb  roc_auc_lgb  test_periods  train_periods
# 0     1  0.678981     0.678310     0.677617            62            125
# 1     2  0.694692     0.693999     0.693320            62            125
# 2     3  0.690904     0.689458     0.690298            63            124
#
# Average ROC AUC score: 0.688192306138288
# Standard deviation: 0.008199164722127892
#
# Top 10 most important features:
#                       feature  xgb_importance  lgb_importance
# 40     target_std_season_hour        0.142391             194
# 44  target_std_season_weekday        0.034787             276
# 3                  minute_cos        0.027379             132
# 22              solar_ema_0.5        0.025938              46
# 52          load_ratio_season        0.024734              92
# 42    target_std_weekday_hour        0.024498             194
# 23              solar_ema_0.7        0.023539              23
# 2                  minute_sin        0.022965              68
# 37           load_lag_ratio_1        0.022624              53
# 38           load_lag_ratio_2        0.022588              59

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import GroupKFold
from sklearn.metrics import roc_auc_score
from sklearn.preprocessing import StandardScaler
from lightgbm import LGBMClassifier
import xgboost as xgb

# Load the data
df = pd.read_csv('public_data.csv')

def create_features(df):
    # Time-based features
    df['hour_sin'] = np.sin(2 * np.pi * df['hour']/24)
    df['hour_cos'] = np.cos(2 * np.pi * df['hour']/24)
    df['minute_sin'] = np.sin(2 * np.pi * df['minute']/60)
    df['minute_cos'] = np.cos(2 * np.pi * df['minute']/60)

    # Rolling statistics
    for window in [4, 8, 12]:
        df[f'rolling_solar_mean_{window}'] = df.groupby('periodID')['solar_becsult_dayahead'].transform(
            lambda x: x.rolling(window=window, min_periods=1).mean())
        df[f'rolling_load_mean_{window}'] = df.groupby('periodID')['rendszerterheles_terv'].transform(
            lambda x: x.rolling(window=window, min_periods=1).mean())
        df[f'rolling_solar_std_{window}'] = df.groupby('periodID')['solar_becsult_dayahead'].transform(
            lambda x: x.rolling(window=window, min_periods=1).std())
        df[f'rolling_load_std_{window}'] = df.groupby('periodID')['rendszerterheles_terv'].transform(
            lambda x: x.rolling(window=window, min_periods=1).std())

    # Enhanced EMAs and EMA-based features
    for alpha in [0.3, 0.5, 0.7]:
        # Basic EMAs
        df[f'solar_ema_{alpha}'] = df.groupby('periodID')['solar_becsult_dayahead'].transform(
            lambda x: x.ewm(alpha=alpha, adjust=False).mean())
        df[f'load_ema_{alpha}'] = df.groupby('periodID')['rendszerterheles_terv'].transform(
            lambda x: x.ewm(alpha=alpha, adjust=False).mean())

        # NEW: EMA differences and ratios
        df[f'solar_ema_diff_{alpha}'] = df['solar_becsult_dayahead'] - df[f'solar_ema_{alpha}']
        df[f'load_ema_diff_{alpha}'] = df['rendszerterheles_terv'] - df[f'load_ema_{alpha}']
        df[f'solar_ema_ratio_{alpha}'] = df['solar_becsult_dayahead'] / (df[f'solar_ema_{alpha}'] + 1)
        df[f'load_ema_ratio_{alpha}'] = df['rendszerterheles_terv'] / (df[f'load_ema_{alpha}'] + 1)

    # Lag features
    for lag in [1, 2]:
        df[f'solar_lag_{lag}'] = df.groupby('periodID')['solar_becsult_dayahead'].shift(lag)
        df[f'load_lag_{lag}'] = df.groupby('periodID')['rendszerterheles_terv'].shift(lag)
        df[f'solar_lag_diff_{lag}'] = df['solar_becsult_dayahead'] - df[f'solar_lag_{lag}']
        df[f'load_lag_diff_{lag}'] = df['rendszerterheles_terv'] - df[f'load_lag_{lag}']
        df[f'solar_lag_ratio_{lag}'] = df['solar_becsult_dayahead'] / (df[f'solar_lag_{lag}'] + 1)
        df[f'load_lag_ratio_{lag}'] = df['rendszerterheles_terv'] / (df[f'load_lag_{lag}'] + 1)

    # Target encoding with smoothing
    def smooth_target_mean(group, alpha=5):
        counts = group.size
        means = group.mean()
        global_mean = means.mean()
        return (means * counts + global_mean * alpha) / (counts + alpha)

    for group_cols in [
        ['season', 'hour'],
        ['weekday', 'hour'],
        ['season', 'weekday']
    ]:
        name = '_'.join(group_cols)
        agg = df.groupby(group_cols)['target_flag'].agg(['mean', 'std']).reset_index()
        agg['smoothed_mean'] = smooth_target_mean(agg['mean'])
        df[f'target_mean_{name}'] = df[group_cols].merge(
            agg[group_cols + ['smoothed_mean']],
            on=group_cols,
            how='left'
        )['smoothed_mean']

        if agg['std'].notna().any():
            df[f'target_std_{name}'] = df[group_cols].merge(
                agg[group_cols + ['std']],
                on=group_cols,
                how='left'
            )['std']

    # Core features and basic interactions
    df['solar_load_ratio'] = df['solar_becsult_dayahead'] / (df['rendszerterheles_terv'] + 1)
    df['weekend'] = df['weekday'].isin([5, 6]).astype(int)
    df['solar_hour'] = df['solar_becsult_dayahead'] * np.sin(2 * np.pi * df['hour']/24)
    df['load_hour'] = df['rendszerterheles_terv'] * np.sin(2 * np.pi * df['hour']/24)
    df['solar_season'] = df['solar_becsult_dayahead'] * df['season']
    df['load_season'] = df['rendszerterheles_terv'] * df['season']

    # Existing cross-features
    df['load_ratio_hour'] = df['load_lag_ratio_1'] * df['hour_sin']
    df['solar_ratio_hour'] = df['solar_lag_ratio_1'] * df['hour_sin']
    df['load_ratio_season'] = df['load_lag_ratio_1'] * df['season']
    df['solar_ratio_season'] = df['solar_lag_ratio_1'] * df['season']

    # NEW: More granular temporal interactions
    df['load_ratio_hour_season'] = df['load_lag_ratio_1'] * df['hour_sin'] * df['season']
    df['solar_ratio_hour_season'] = df['solar_lag_ratio_1'] * df['hour_sin'] * df['season']

    # NEW: EMA and time interactions
    df['load_ema_hour'] = df['load_ema_0.5'] * df['hour_sin']
    df['solar_ema_hour'] = df['solar_ema_0.5'] * df['hour_sin']

    return df

df = create_features(df)

# Filter first 4 days
df_filtered = df[df['day_in_period'] < 4]

# Fill NaN values
df_filtered = df_filtered.fillna(method='ffill').fillna(method='bfill')

# Define features including new ones
features = [
    # Base time features
    'hour_sin', 'hour_cos', 'minute_sin', 'minute_cos',
    'holyday', 'weekday', 'weekend',

    # Core predictors
    'solar_becsult_dayahead', 'rendszerterheles_terv',

    # Rolling features
    'rolling_solar_mean_4', 'rolling_solar_mean_8', 'rolling_solar_mean_12',
    'rolling_load_mean_4', 'rolling_load_mean_8', 'rolling_load_mean_12',
    'rolling_solar_std_4', 'rolling_solar_std_8', 'rolling_solar_std_12',
    'rolling_load_std_4', 'rolling_load_std_8', 'rolling_load_std_12',

    # EMAs and EMA-based features
    'solar_ema_0.3', 'solar_ema_0.5', 'solar_ema_0.7',
    'load_ema_0.3', 'load_ema_0.5', 'load_ema_0.7',
    'solar_ema_diff_0.3', 'solar_ema_diff_0.5', 'solar_ema_diff_0.7',
    'load_ema_diff_0.3', 'load_ema_diff_0.5', 'load_ema_diff_0.7',
    'solar_ema_ratio_0.3', 'solar_ema_ratio_0.5', 'solar_ema_ratio_0.7',
    'load_ema_ratio_0.3', 'load_ema_ratio_0.5', 'load_ema_ratio_0.7',

    # Lag features
    'solar_lag_1', 'solar_lag_2',
    'load_lag_1', 'load_lag_2',
    'solar_lag_diff_1', 'solar_lag_diff_2',
    'load_lag_diff_1', 'load_lag_diff_2',
    'solar_lag_ratio_1', 'solar_lag_ratio_2',
    'load_lag_ratio_1', 'load_lag_ratio_2',

    # Target encodings
    'target_mean_season_hour', 'target_std_season_hour',
    'target_mean_weekday_hour', 'target_std_weekday_hour',
    'target_mean_season_weekday', 'target_std_season_weekday',

    # Interactions
    'solar_load_ratio', 'solar_hour', 'load_hour',
    'solar_season', 'load_season',
    'load_ratio_hour', 'solar_ratio_hour',
    'load_ratio_season', 'solar_ratio_season',

    # NEW: Additional interactions
    'load_ratio_hour_season', 'solar_ratio_hour_season',
    'load_ema_hour', 'solar_ema_hour'
]

# Keep rest of the code same (data preparation, model parameters, training loop)
period_ids = df_filtered['periodID'].unique()
np.random.seed(42)
period_ids = np.random.permutation(period_ids)
fold_size = len(period_ids) // 3
folds = [period_ids[:fold_size],
         period_ids[fold_size:2*fold_size],
         period_ids[2*fold_size:]]

results = []
for fold_idx in range(3):
    test_periods = folds[fold_idx]
    train_periods = np.concatenate([folds[i] for i in range(3) if i != fold_idx])

    X_train = df_filtered[df_filtered['periodID'].isin(train_periods)][features]
    y_train = df_filtered[df_filtered['periodID'].isin(train_periods)]['target_flag']
    X_test = df_filtered[df_filtered['periodID'].isin(test_periods)][features]
    y_test = df_filtered[df_filtered['periodID'].isin(test_periods)]['target_flag']

    scaler = StandardScaler()
    X_train_scaled = scaler.fit_transform(X_train)
    X_test_scaled = scaler.transform(X_test)

    xgb_model = xgb.XGBClassifier(
        n_estimators=150,
        learning_rate=0.07,
        max_depth=5,
        min_child_weight=2,
        gamma=0.1,
        subsample=0.85,
        colsample_bytree=0.85,
        colsample_bylevel=0.85,
        reg_alpha=0.1,
        reg_lambda=1.0,
        random_state=42,
        n_jobs=-1,
        use_label_encoder=False,
        eval_metric='logloss'
    )

    lgb_model = LGBMClassifier(
        n_estimators=150,
        learning_rate=0.05,
        num_leaves=25,
        max_depth=6,
        min_child_samples=20,
        subsample=0.85,
        colsample_bytree=0.85,
        reg_alpha=0.1,
        reg_lambda=1.0,
        random_state=42,
        n_jobs=-1
    )

    eval_set_xgb = [(X_train_scaled, y_train)]
    eval_set_lgb = [(X_train_scaled, y_train)]

    xgb_model.fit(X_train_scaled, y_train,
                 eval_set=eval_set_xgb,)

    lgb_model.fit(X_train_scaled, y_train,
                 eval_set=eval_set_lgb)

    xgb_pred = xgb_model.predict_proba(X_test_scaled)[:, 1]
    roc_auc_xgb = roc_auc_score(y_test, xgb_pred)
    lgb_pred = lgb_model.predict_proba(X_test_scaled)[:, 1]
    roc_auc_lgb = roc_auc_score(y_test, lgb_pred)

    y_pred_proba = 0.45 * xgb_pred + 0.55 * lgb_pred
    roc_auc = roc_auc_score(y_test, y_pred_proba)

    results.append({
        'fold': fold_idx + 1,
        'roc_auc': roc_auc,
        'roc_auc_xgb': roc_auc_xgb,
        'roc_auc_lgb': roc_auc_lgb,
        'test_periods': len(test_periods),
        'train_periods': len(train_periods)
    })

# Results display
results_df = pd.DataFrame(results)
print("\nResults for each fold:")
print(results_df)
print("\nAverage ROC AUC score:", results_df['roc_auc'].mean())
print("Standard deviation:", results_df['roc_auc'].std())

# Feature importance
feature_importance = pd.DataFrame({
    'feature': features,
    'xgb_importance': xgb_model.feature_importances_,
    'lgb_importance': lgb_model.feature_importances_
})
print("\nTop 10 most important features:")
print(feature_importance.sort_values('xgb_importance', ascending=False).head(10))

# Submission predictions
test_data = df[df['day_in_period'] == 4]
X_submission = test_data[features]
X_submission_scaled = scaler.transform(X_submission)

xgb_pred = xgb_model.predict_proba(X_submission_scaled)[:, 1]
lgb_pred = lgb_model.predict_proba(X_submission_scaled)[:, 1]
final_predictions = 0.45 * xgb_pred + 0.55 * lgb_pred

submission = pd.DataFrame({
    'rowID': test_data['rowID'],
    'target_flag': final_predictions
})

submission.to_csv('brh16.csv', index=False)
# Out:
# C:\Users\ajanko_adm\AppData\Local\Temp\ipykernel_32552\2985078012.py:111: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df_filtered = df_filtered.fillna(method='ffill').fillna(method='bfill')
# [0]	validation_0-logloss:0.62745
# [1]	validation_0-logloss:0.62204
# [2]	validation_0-logloss:0.61681
# [3]	validation_0-logloss:0.61240
# [4]	validation_0-logloss:0.60821
# [5]	validation_0-logloss:0.60462
# [6]	validation_0-logloss:0.60139
# [7]	validation_0-logloss:0.59844
# [8]	validation_0-logloss:0.59568
# [9]	validation_0-logloss:0.59319
# [10]	validation_0-logloss:0.59107
# [11]	validation_0-logloss:0.58907
# [12]	validation_0-logloss:0.58692
# [13]	validation_0-logloss:0.58517
# [14]	validation_0-logloss:0.58357
# c:\Users\ajanko_adm\AppData\Local\miniconda3\envs\machineL\Lib\site-packages\xgboost\core.py:158: UserWarning: [02:15:12] WARNING: C:\b\abs_90_bwj_86a\croot\xgboost-split_1724073762025\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [15]	validation_0-logloss:0.58182
# [16]	validation_0-logloss:0.58001
# [17]	validation_0-logloss:0.57866
# [18]	validation_0-logloss:0.57731
# [19]	validation_0-logloss:0.57606
# [20]	validation_0-logloss:0.57494
# [21]	validation_0-logloss:0.57382
# [22]	validation_0-logloss:0.57270
# [23]	validation_0-logloss:0.57155
# [24]	validation_0-logloss:0.57072
# [25]	validation_0-logloss:0.56997
# [26]	validation_0-logloss:0.56894
# [27]	validation_0-logloss:0.56822
# [28]	validation_0-logloss:0.56750
# [29]	validation_0-logloss:0.56665
# [30]	validation_0-logloss:0.56576
# [31]	validation_0-logloss:0.56474
# [32]	validation_0-logloss:0.56393
# [33]	validation_0-logloss:0.56284
# [34]	validation_0-logloss:0.56206
# [35]	validation_0-logloss:0.56070
# [36]	validation_0-logloss:0.55958
# [37]	validation_0-logloss:0.55874
# [38]	validation_0-logloss:0.55827
# [39]	validation_0-logloss:0.55785
# [40]	validation_0-logloss:0.55736
# [41]	validation_0-logloss:0.55660
# [42]	validation_0-logloss:0.55586
# [43]	validation_0-logloss:0.55529
# [44]	validation_0-logloss:0.55465
# [45]	validation_0-logloss:0.55371
# [46]	validation_0-logloss:0.55322
# [47]	validation_0-logloss:0.55218
# [48]	validation_0-logloss:0.55147
# [49]	validation_0-logloss:0.55103
# [50]	validation_0-logloss:0.55056
# [51]	validation_0-logloss:0.54993
# [52]	validation_0-logloss:0.54902
# [53]	validation_0-logloss:0.54835
# [54]	validation_0-logloss:0.54795
# [55]	validation_0-logloss:0.54753
# [56]	validation_0-logloss:0.54692
# [57]	validation_0-logloss:0.54638
# [58]	validation_0-logloss:0.54601
# [59]	validation_0-logloss:0.54563
# [60]	validation_0-logloss:0.54508
# [61]	validation_0-logloss:0.54437
# [62]	validation_0-logloss:0.54396
# [63]	validation_0-logloss:0.54361
# [64]	validation_0-logloss:0.54344
# [65]	validation_0-logloss:0.54299
# [66]	validation_0-logloss:0.54266
# [67]	validation_0-logloss:0.54223
# [68]	validation_0-logloss:0.54189
# [69]	validation_0-logloss:0.54170
# [70]	validation_0-logloss:0.54131
# [71]	validation_0-logloss:0.54047
# [72]	validation_0-logloss:0.53989
# [73]	validation_0-logloss:0.53951
# [74]	validation_0-logloss:0.53928
# [75]	validation_0-logloss:0.53916
# [76]	validation_0-logloss:0.53882
# [77]	validation_0-logloss:0.53825
# [78]	validation_0-logloss:0.53796
# [79]	validation_0-logloss:0.53780
# [80]	validation_0-logloss:0.53737
# [81]	validation_0-logloss:0.53696
# [82]	validation_0-logloss:0.53650
# [83]	validation_0-logloss:0.53634
# [84]	validation_0-logloss:0.53605
# [85]	validation_0-logloss:0.53567
# [86]	validation_0-logloss:0.53525
# [87]	validation_0-logloss:0.53508
# [88]	validation_0-logloss:0.53475
# [89]	validation_0-logloss:0.53445
# [90]	validation_0-logloss:0.53391
# [91]	validation_0-logloss:0.53355
# [92]	validation_0-logloss:0.53319
# [93]	validation_0-logloss:0.53274
# [94]	validation_0-logloss:0.53224
# [95]	validation_0-logloss:0.53165
# [96]	validation_0-logloss:0.53114
# [97]	validation_0-logloss:0.53088
# [98]	validation_0-logloss:0.53055
# [99]	validation_0-logloss:0.53017
# [100]	validation_0-logloss:0.53000
# [101]	validation_0-logloss:0.52966
# [102]	validation_0-logloss:0.52930
# [103]	validation_0-logloss:0.52892
# [104]	validation_0-logloss:0.52874
# [105]	validation_0-logloss:0.52829
# [106]	validation_0-logloss:0.52819
# [107]	validation_0-logloss:0.52763
# [108]	validation_0-logloss:0.52721
# [109]	validation_0-logloss:0.52686
# [110]	validation_0-logloss:0.52652
# [111]	validation_0-logloss:0.52621
# [112]	validation_0-logloss:0.52606
# [113]	validation_0-logloss:0.52588
# [114]	validation_0-logloss:0.52539
# [115]	validation_0-logloss:0.52493
# [116]	validation_0-logloss:0.52449
# [117]	validation_0-logloss:0.52429
# [118]	validation_0-logloss:0.52391
# [119]	validation_0-logloss:0.52358
# [120]	validation_0-logloss:0.52322
# [121]	validation_0-logloss:0.52299
# [122]	validation_0-logloss:0.52254
# [123]	validation_0-logloss:0.52213
# [124]	validation_0-logloss:0.52194
# [125]	validation_0-logloss:0.52156
# [126]	validation_0-logloss:0.52130
# [127]	validation_0-logloss:0.52094
# [128]	validation_0-logloss:0.52068
# [129]	validation_0-logloss:0.52032
# [130]	validation_0-logloss:0.51991
# [131]	validation_0-logloss:0.51969
# [132]	validation_0-logloss:0.51934
# [133]	validation_0-logloss:0.51912
# [134]	validation_0-logloss:0.51894
# [135]	validation_0-logloss:0.51863
# [136]	validation_0-logloss:0.51843
# [137]	validation_0-logloss:0.51822
# [138]	validation_0-logloss:0.51756
# [139]	validation_0-logloss:0.51741
# [140]	validation_0-logloss:0.51730
# [141]	validation_0-logloss:0.51710
# [142]	validation_0-logloss:0.51675
# [143]	validation_0-logloss:0.51657
# [144]	validation_0-logloss:0.51618
# [145]	validation_0-logloss:0.51585
# [146]	validation_0-logloss:0.51527
# [147]	validation_0-logloss:0.51492
# [148]	validation_0-logloss:0.51438
# [149]	validation_0-logloss:0.51389
# [LightGBM] [Info] Number of positive: 32190, number of negative: 15810
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.009609 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 15084
# [LightGBM] [Info] Number of data points in the train set: 48000, number of used features: 67
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.670625 -> initscore=0.711013
# [LightGBM] [Info] Start training from score 0.711013
# [0]	validation_0-logloss:0.63834
# [1]	validation_0-logloss:0.63258
# [2]	validation_0-logloss:0.62744
# [3]	validation_0-logloss:0.62288
# [4]	validation_0-logloss:0.61872
# [5]	validation_0-logloss:0.61513
# [6]	validation_0-logloss:0.61163
# [7]	validation_0-logloss:0.60841
# [8]	validation_0-logloss:0.60571
# [9]	validation_0-logloss:0.60332
# [10]	validation_0-logloss:0.60089
# [11]	validation_0-logloss:0.59901
# [12]	validation_0-logloss:0.59696
# [13]	validation_0-logloss:0.59525
# c:\Users\ajanko_adm\AppData\Local\miniconda3\envs\machineL\Lib\site-packages\xgboost\core.py:158: UserWarning: [02:15:16] WARNING: C:\b\abs_90_bwj_86a\croot\xgboost-split_1724073762025\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [14]	validation_0-logloss:0.59359
# [15]	validation_0-logloss:0.59213
# [16]	validation_0-logloss:0.59056
# [17]	validation_0-logloss:0.58924
# [18]	validation_0-logloss:0.58779
# [19]	validation_0-logloss:0.58662
# [20]	validation_0-logloss:0.58536
# [21]	validation_0-logloss:0.58419
# [22]	validation_0-logloss:0.58313
# [23]	validation_0-logloss:0.58210
# [24]	validation_0-logloss:0.58096
# [25]	validation_0-logloss:0.58009
# [26]	validation_0-logloss:0.57916
# [27]	validation_0-logloss:0.57836
# [28]	validation_0-logloss:0.57780
# [29]	validation_0-logloss:0.57675
# [30]	validation_0-logloss:0.57578
# [31]	validation_0-logloss:0.57524
# [32]	validation_0-logloss:0.57455
# [33]	validation_0-logloss:0.57390
# [34]	validation_0-logloss:0.57334
# [35]	validation_0-logloss:0.57193
# [36]	validation_0-logloss:0.57132
# [37]	validation_0-logloss:0.57077
# [38]	validation_0-logloss:0.56996
# [39]	validation_0-logloss:0.56953
# [40]	validation_0-logloss:0.56903
# [41]	validation_0-logloss:0.56864
# [42]	validation_0-logloss:0.56753
# [43]	validation_0-logloss:0.56681
# [44]	validation_0-logloss:0.56617
# [45]	validation_0-logloss:0.56542
# [46]	validation_0-logloss:0.56490
# [47]	validation_0-logloss:0.56433
# [48]	validation_0-logloss:0.56401
# [49]	validation_0-logloss:0.56344
# [50]	validation_0-logloss:0.56310
# [51]	validation_0-logloss:0.56254
# [52]	validation_0-logloss:0.56213
# [53]	validation_0-logloss:0.56177
# [54]	validation_0-logloss:0.56103
# [55]	validation_0-logloss:0.56059
# [56]	validation_0-logloss:0.56013
# [57]	validation_0-logloss:0.55991
# [58]	validation_0-logloss:0.55930
# [59]	validation_0-logloss:0.55890
# [60]	validation_0-logloss:0.55843
# [61]	validation_0-logloss:0.55777
# [62]	validation_0-logloss:0.55700
# [63]	validation_0-logloss:0.55644
# [64]	validation_0-logloss:0.55590
# [65]	validation_0-logloss:0.55564
# [66]	validation_0-logloss:0.55514
# [67]	validation_0-logloss:0.55476
# [68]	validation_0-logloss:0.55445
# [69]	validation_0-logloss:0.55393
# [70]	validation_0-logloss:0.55349
# [71]	validation_0-logloss:0.55309
# [72]	validation_0-logloss:0.55284
# [73]	validation_0-logloss:0.55260
# [74]	validation_0-logloss:0.55218
# [75]	validation_0-logloss:0.55183
# [76]	validation_0-logloss:0.55155
# [77]	validation_0-logloss:0.55140
# [78]	validation_0-logloss:0.55118
# [79]	validation_0-logloss:0.55087
# [80]	validation_0-logloss:0.55059
# [81]	validation_0-logloss:0.55000
# [82]	validation_0-logloss:0.54978
# [83]	validation_0-logloss:0.54957
# [84]	validation_0-logloss:0.54918
# [85]	validation_0-logloss:0.54894
# [86]	validation_0-logloss:0.54844
# [87]	validation_0-logloss:0.54795
# [88]	validation_0-logloss:0.54741
# [89]	validation_0-logloss:0.54697
# [90]	validation_0-logloss:0.54665
# [91]	validation_0-logloss:0.54643
# [92]	validation_0-logloss:0.54615
# [93]	validation_0-logloss:0.54569
# [94]	validation_0-logloss:0.54530
# [95]	validation_0-logloss:0.54476
# [96]	validation_0-logloss:0.54450
# [97]	validation_0-logloss:0.54423
# [98]	validation_0-logloss:0.54391
# [99]	validation_0-logloss:0.54343
# [100]	validation_0-logloss:0.54287
# [101]	validation_0-logloss:0.54271
# [102]	validation_0-logloss:0.54229
# [103]	validation_0-logloss:0.54189
# [104]	validation_0-logloss:0.54134
# [105]	validation_0-logloss:0.54072
# [106]	validation_0-logloss:0.54014
# [107]	validation_0-logloss:0.53965
# [108]	validation_0-logloss:0.53946
# [109]	validation_0-logloss:0.53917
# [110]	validation_0-logloss:0.53876
# [111]	validation_0-logloss:0.53826
# [112]	validation_0-logloss:0.53805
# [113]	validation_0-logloss:0.53774
# [114]	validation_0-logloss:0.53754
# [115]	validation_0-logloss:0.53720
# [116]	validation_0-logloss:0.53681
# [117]	validation_0-logloss:0.53639
# [118]	validation_0-logloss:0.53612
# [119]	validation_0-logloss:0.53576
# [120]	validation_0-logloss:0.53541
# [121]	validation_0-logloss:0.53509
# [122]	validation_0-logloss:0.53478
# [123]	validation_0-logloss:0.53457
# [124]	validation_0-logloss:0.53416
# [125]	validation_0-logloss:0.53374
# [126]	validation_0-logloss:0.53353
# [127]	validation_0-logloss:0.53322
# [128]	validation_0-logloss:0.53293
# [129]	validation_0-logloss:0.53268
# [130]	validation_0-logloss:0.53237
# [131]	validation_0-logloss:0.53220
# [132]	validation_0-logloss:0.53197
# [133]	validation_0-logloss:0.53159
# [134]	validation_0-logloss:0.53144
# [135]	validation_0-logloss:0.53130
# [136]	validation_0-logloss:0.53106
# [137]	validation_0-logloss:0.53087
# [138]	validation_0-logloss:0.53050
# [139]	validation_0-logloss:0.53019
# [140]	validation_0-logloss:0.52989
# [141]	validation_0-logloss:0.52969
# [142]	validation_0-logloss:0.52933
# [143]	validation_0-logloss:0.52919
# [144]	validation_0-logloss:0.52867
# [145]	validation_0-logloss:0.52824
# [146]	validation_0-logloss:0.52802
# [147]	validation_0-logloss:0.52783
# [148]	validation_0-logloss:0.52762
# [149]	validation_0-logloss:0.52727
# [LightGBM] [Info] Number of positive: 31397, number of negative: 16603
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.006502 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 15078
# [LightGBM] [Info] Number of data points in the train set: 48000, number of used features: 67
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.654104 -> initscore=0.637129
# [LightGBM] [Info] Start training from score 0.637129
# [0]	validation_0-logloss:0.64088
# [1]	validation_0-logloss:0.63517
# [2]	validation_0-logloss:0.63010
# [3]	validation_0-logloss:0.62571
# [4]	validation_0-logloss:0.62157
# [5]	validation_0-logloss:0.61793
# [6]	validation_0-logloss:0.61461
# [7]	validation_0-logloss:0.61169
# [8]	validation_0-logloss:0.60875
# [9]	validation_0-logloss:0.60586
# [10]	validation_0-logloss:0.60354
# [11]	validation_0-logloss:0.60161
# [12]	validation_0-logloss:0.59965
# [13]	validation_0-logloss:0.59789
# [14]	validation_0-logloss:0.59638
# [15]	validation_0-logloss:0.59464
# [16]	validation_0-logloss:0.59296
# [17]	validation_0-logloss:0.59151
# [18]	validation_0-logloss:0.59033
# [19]	validation_0-logloss:0.58928
# c:\Users\ajanko_adm\AppData\Local\miniconda3\envs\machineL\Lib\site-packages\xgboost\core.py:158: UserWarning: [02:15:19] WARNING: C:\b\abs_90_bwj_86a\croot\xgboost-split_1724073762025\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [20]	validation_0-logloss:0.58760
# [21]	validation_0-logloss:0.58646
# [22]	validation_0-logloss:0.58533
# [23]	validation_0-logloss:0.58398
# [24]	validation_0-logloss:0.58300
# [25]	validation_0-logloss:0.58225
# [26]	validation_0-logloss:0.58134
# [27]	validation_0-logloss:0.58050
# [28]	validation_0-logloss:0.57954
# [29]	validation_0-logloss:0.57877
# [30]	validation_0-logloss:0.57823
# [31]	validation_0-logloss:0.57717
# [32]	validation_0-logloss:0.57663
# [33]	validation_0-logloss:0.57542
# [34]	validation_0-logloss:0.57489
# [35]	validation_0-logloss:0.57403
# [36]	validation_0-logloss:0.57344
# [37]	validation_0-logloss:0.57241
# [38]	validation_0-logloss:0.57203
# [39]	validation_0-logloss:0.57137
# [40]	validation_0-logloss:0.57081
# [41]	validation_0-logloss:0.57025
# [42]	validation_0-logloss:0.56983
# [43]	validation_0-logloss:0.56920
# [44]	validation_0-logloss:0.56866
# [45]	validation_0-logloss:0.56818
# [46]	validation_0-logloss:0.56737
# [47]	validation_0-logloss:0.56692
# [48]	validation_0-logloss:0.56643
# [49]	validation_0-logloss:0.56587
# [50]	validation_0-logloss:0.56560
# [51]	validation_0-logloss:0.56512
# [52]	validation_0-logloss:0.56450
# [53]	validation_0-logloss:0.56384
# [54]	validation_0-logloss:0.56308
# [55]	validation_0-logloss:0.56263
# [56]	validation_0-logloss:0.56219
# [57]	validation_0-logloss:0.56155
# [58]	validation_0-logloss:0.56122
# [59]	validation_0-logloss:0.56083
# [60]	validation_0-logloss:0.56060
# [61]	validation_0-logloss:0.56023
# [62]	validation_0-logloss:0.55989
# [63]	validation_0-logloss:0.55957
# [64]	validation_0-logloss:0.55941
# [65]	validation_0-logloss:0.55903
# [66]	validation_0-logloss:0.55864
# [67]	validation_0-logloss:0.55839
# [68]	validation_0-logloss:0.55787
# [69]	validation_0-logloss:0.55711
# [70]	validation_0-logloss:0.55682
# [71]	validation_0-logloss:0.55662
# [72]	validation_0-logloss:0.55628
# [73]	validation_0-logloss:0.55574
# [74]	validation_0-logloss:0.55526
# [75]	validation_0-logloss:0.55478
# [76]	validation_0-logloss:0.55440
# [77]	validation_0-logloss:0.55412
# [78]	validation_0-logloss:0.55390
# [79]	validation_0-logloss:0.55372
# [80]	validation_0-logloss:0.55347
# [81]	validation_0-logloss:0.55305
# [82]	validation_0-logloss:0.55252
# [83]	validation_0-logloss:0.55197
# [84]	validation_0-logloss:0.55147
# [85]	validation_0-logloss:0.55106
# [86]	validation_0-logloss:0.55064
# [87]	validation_0-logloss:0.55035
# [88]	validation_0-logloss:0.55013
# [89]	validation_0-logloss:0.54989
# [90]	validation_0-logloss:0.54961
# [91]	validation_0-logloss:0.54905
# [92]	validation_0-logloss:0.54853
# [93]	validation_0-logloss:0.54827
# [94]	validation_0-logloss:0.54785
# [95]	validation_0-logloss:0.54751
# [96]	validation_0-logloss:0.54725
# [97]	validation_0-logloss:0.54690
# [98]	validation_0-logloss:0.54632
# [99]	validation_0-logloss:0.54590
# [100]	validation_0-logloss:0.54564
# [101]	validation_0-logloss:0.54520
# [102]	validation_0-logloss:0.54480
# [103]	validation_0-logloss:0.54420
# [104]	validation_0-logloss:0.54384
# [105]	validation_0-logloss:0.54326
# [106]	validation_0-logloss:0.54298
# [107]	validation_0-logloss:0.54275
# [108]	validation_0-logloss:0.54238
# [109]	validation_0-logloss:0.54224
# [110]	validation_0-logloss:0.54180
# [111]	validation_0-logloss:0.54161
# [112]	validation_0-logloss:0.54140
# [113]	validation_0-logloss:0.54118
# [114]	validation_0-logloss:0.54087
# [115]	validation_0-logloss:0.54066
# [116]	validation_0-logloss:0.54053
# [117]	validation_0-logloss:0.54016
# [118]	validation_0-logloss:0.53977
# [119]	validation_0-logloss:0.53937
# [120]	validation_0-logloss:0.53919
# [121]	validation_0-logloss:0.53884
# [122]	validation_0-logloss:0.53856
# [123]	validation_0-logloss:0.53808
# [124]	validation_0-logloss:0.53775
# [125]	validation_0-logloss:0.53746
# [126]	validation_0-logloss:0.53709
# [127]	validation_0-logloss:0.53692
# [128]	validation_0-logloss:0.53670
# [129]	validation_0-logloss:0.53660
# [130]	validation_0-logloss:0.53617
# [131]	validation_0-logloss:0.53591
# [132]	validation_0-logloss:0.53576
# [133]	validation_0-logloss:0.53547
# [134]	validation_0-logloss:0.53512
# [135]	validation_0-logloss:0.53472
# [136]	validation_0-logloss:0.53448
# [137]	validation_0-logloss:0.53414
# [138]	validation_0-logloss:0.53388
# [139]	validation_0-logloss:0.53347
# [140]	validation_0-logloss:0.53331
# [141]	validation_0-logloss:0.53301
# [142]	validation_0-logloss:0.53264
# [143]	validation_0-logloss:0.53229
# [144]	validation_0-logloss:0.53196
# [145]	validation_0-logloss:0.53173
# [146]	validation_0-logloss:0.53140
# [147]	validation_0-logloss:0.53100
# [148]	validation_0-logloss:0.53079
# [149]	validation_0-logloss:0.53062
# [LightGBM] [Info] Number of positive: 30967, number of negative: 16649
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.006522 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 15078
# [LightGBM] [Info] Number of data points in the train set: 47616, number of used features: 67
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.650349 -> initscore=0.620572
# [LightGBM] [Info] Start training from score 0.620572
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
#
# Results for each fold:
#    fold   roc_auc  roc_auc_xgb  roc_auc_lgb  test_periods  train_periods
# 0     1  0.682182     0.679424     0.682377            62            125
# 1     2  0.694262     0.693369     0.693024            62            125
# 2     3  0.690809     0.689834     0.689719            63            124
#
# Average ROC AUC score: 0.6890843885729355
# Standard deviation: 0.006222081483667666
#
# Top 10 most important features:
#                       feature  xgb_importance  lgb_importance
# 52     target_std_season_hour        0.101581             188
# 56  target_std_season_weekday        0.042897             262
# 3                  minute_cos        0.022600             151
# 57           solar_load_ratio        0.020584              48
# 50           load_lag_ratio_2        0.020404              45
# 54    target_std_weekday_hour        0.020350             181
# 23              solar_ema_0.7        0.018973              16
# 49           load_lag_ratio_1        0.016988              44
# 22              solar_ema_0.5        0.016880              33
# 39                solar_lag_1        0.016682               9

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import GroupKFold
from sklearn.metrics import roc_auc_score
from sklearn.preprocessing import StandardScaler
from lightgbm import LGBMClassifier
import xgboost as xgb

# Load the data
df = pd.read_csv('public_data.csv')

def create_features(df):
    # Time-based features
    df['hour_sin'] = np.sin(2 * np.pi * df['hour']/24)
    df['hour_cos'] = np.cos(2 * np.pi * df['hour']/24)
    df['minute_sin'] = np.sin(2 * np.pi * df['minute']/60)
    df['minute_cos'] = np.cos(2 * np.pi * df['minute']/60)

    # Enhanced rolling statistics with multiple windows
    for window in [4, 8, 12]:
        # Mean
        df[f'rolling_solar_mean_{window}'] = df.groupby('periodID')['solar_becsult_dayahead'].transform(
            lambda x: x.rolling(window=window, min_periods=1).mean())
        df[f'rolling_load_mean_{window}'] = df.groupby('periodID')['rendszerterheles_terv'].transform(
            lambda x: x.rolling(window=window, min_periods=1).mean())

        # Standard deviation
        df[f'rolling_solar_std_{window}'] = df.groupby('periodID')['solar_becsult_dayahead'].transform(
            lambda x: x.rolling(window=window, min_periods=1).std())
        df[f'rolling_load_std_{window}'] = df.groupby('periodID')['rendszerterheles_terv'].transform(
            lambda x: x.rolling(window=window, min_periods=1).std())

    # Exponential moving averages
    for alpha in [0.3, 0.5, 0.7]:
        df[f'solar_ema_{alpha}'] = df.groupby('periodID')['solar_becsult_dayahead'].transform(
            lambda x: x.ewm(alpha=alpha, adjust=False).mean())
        df[f'load_ema_{alpha}'] = df.groupby('periodID')['rendszerterheles_terv'].transform(
            lambda x: x.ewm(alpha=alpha, adjust=False).mean())

    # Multiple lag features
    for lag in [1, 2]:
        # Basic lags
        df[f'solar_lag_{lag}'] = df.groupby('periodID')['solar_becsult_dayahead'].shift(lag)
        df[f'load_lag_{lag}'] = df.groupby('periodID')['rendszerterheles_terv'].shift(lag)

        # Lag differences and ratios
        df[f'solar_lag_diff_{lag}'] = df['solar_becsult_dayahead'] - df[f'solar_lag_{lag}']
        df[f'load_lag_diff_{lag}'] = df['rendszerterheles_terv'] - df[f'load_lag_{lag}']
        df[f'solar_lag_ratio_{lag}'] = df['solar_becsult_dayahead'] / (df[f'solar_lag_{lag}'] + 1)
        df[f'load_lag_ratio_{lag}'] = df['rendszerterheles_terv'] / (df[f'load_lag_{lag}'] + 1)

    # Target encoding with increased smoothing
    def smooth_target_mean(group, alpha=8):  # Increased smoothing
        counts = group.size
        means = group.mean()
        global_mean = means.mean()
        return (means * counts + global_mean * alpha) / (counts + alpha)

    for group_cols in [
        ['season', 'hour'],
        ['weekday', 'hour'],
        ['season', 'weekday']
    ]:
        name = '_'.join(group_cols)
        agg = df.groupby(group_cols)['target_flag'].agg(['mean', 'std']).reset_index()
        agg['smoothed_mean'] = smooth_target_mean(agg['mean'])
        df[f'target_mean_{name}'] = df[group_cols].merge(
            agg[group_cols + ['smoothed_mean']],
            on=group_cols,
            how='left'
        )['smoothed_mean']

        if agg['std'].notna().any():
            df[f'target_std_{name}'] = df[group_cols].merge(
                agg[group_cols + ['std']],
                on=group_cols,
                how='left'
            )['std']

    # Core features and interactions
    df['solar_load_ratio'] = df['solar_becsult_dayahead'] / (df['rendszerterheles_terv'] + 1)
    df['weekend'] = df['weekday'].isin([5, 6]).astype(int)
    df['solar_hour'] = df['solar_becsult_dayahead'] * np.sin(2 * np.pi * df['hour']/24)
    df['load_hour'] = df['rendszerterheles_terv'] * np.sin(2 * np.pi * df['hour']/24)
    df['solar_season'] = df['solar_becsult_dayahead'] * df['season']
    df['load_season'] = df['rendszerterheles_terv'] * df['season']

    # Cross-features
    df['load_ratio_hour'] = df['load_lag_ratio_1'] * df['hour_sin']
    df['solar_ratio_hour'] = df['solar_lag_ratio_1'] * df['hour_sin']
    df['load_ratio_season'] = df['load_lag_ratio_1'] * df['season']
    df['solar_ratio_season'] = df['solar_lag_ratio_1'] * df['season']

    return df

# Create initial features
df = create_features(df)
df_filtered = df[df['day_in_period'] < 4]
df_filtered = df_filtered.fillna(method='ffill').fillna(method='bfill')

# Initial feature list
initial_features = [
    'hour_sin', 'hour_cos', 'minute_sin', 'minute_cos',
    'holyday', 'weekday', 'weekend',
    'solar_becsult_dayahead', 'rendszerterheles_terv',
    'rolling_solar_mean_4', 'rolling_solar_mean_8', 'rolling_solar_mean_12',
    'rolling_load_mean_4', 'rolling_load_mean_8', 'rolling_load_mean_12',
    'rolling_solar_std_4', 'rolling_solar_std_8', 'rolling_solar_std_12',
    'rolling_load_std_4', 'rolling_load_std_8', 'rolling_load_std_12',
    'solar_ema_0.3', 'solar_ema_0.5', 'solar_ema_0.7',
    'load_ema_0.3', 'load_ema_0.5', 'load_ema_0.7',
    'solar_lag_1', 'solar_lag_2', 'load_lag_1', 'load_lag_2',
    'solar_lag_diff_1', 'solar_lag_diff_2',
    'load_lag_diff_1', 'load_lag_diff_2',
    'solar_lag_ratio_1', 'solar_lag_ratio_2',
    'load_lag_ratio_1', 'load_lag_ratio_2',
    'target_mean_season_hour', 'target_std_season_hour',
    'target_mean_weekday_hour', 'target_std_weekday_hour',
    'target_mean_season_weekday', 'target_std_season_weekday',
    'solar_load_ratio', 'solar_hour', 'load_hour',
    'solar_season', 'load_season',
    'load_ratio_hour', 'solar_ratio_hour',
    'load_ratio_season', 'solar_ratio_season'
]

# Function to get feature importance and select top features
def get_important_features(X, y, feature_names, threshold=0.01):
    # Train initial models
    xgb_init = xgb.XGBClassifier(random_state=42, n_jobs=-1)
    lgb_init = LGBMClassifier(random_state=42, n_jobs=-1)

    xgb_init.fit(X, y)
    lgb_init.fit(X, y)

    # Get feature importance
    importance_df = pd.DataFrame({
        'feature': feature_names,
        'xgb_importance': xgb_init.feature_importances_,
        'lgb_importance': lgb_init.feature_importances_
    })

    # Normalize and combine importances
    importance_df['combined_importance'] = (
        0.5 * importance_df['xgb_importance'] / importance_df['xgb_importance'].max() +
        0.5 * importance_df['lgb_importance'] / importance_df['lgb_importance'].max()
    )

    # Select features above threshold
    selected_features = importance_df[importance_df['combined_importance'] > threshold]['feature'].tolist()
    return selected_features

# Prepare data for feature selection
X_init = df_filtered[initial_features]
y_init = df_filtered['target_flag']
scaler = StandardScaler()
X_init_scaled = scaler.fit_transform(X_init)

# Get important features
selected_features = get_important_features(X_init_scaled, y_init, initial_features)

# Cross validation with selected features
period_ids = df_filtered['periodID'].unique()
np.random.seed(42)
period_ids = np.random.permutation(period_ids)
fold_size = len(period_ids) // 3
folds = [
    period_ids[:fold_size],
    period_ids[fold_size:2*fold_size],
    period_ids[2*fold_size:]
]

results = []
for fold_idx in range(3):
    test_periods = folds[fold_idx]
    train_periods = np.concatenate([folds[i] for i in range(3) if i != fold_idx])

    X_train = df_filtered[df_filtered['periodID'].isin(train_periods)][selected_features]
    y_train = df_filtered[df_filtered['periodID'].isin(train_periods)]['target_flag']
    X_test = df_filtered[df_filtered['periodID'].isin(test_periods)][selected_features]
    y_test = df_filtered[df_filtered['periodID'].isin(test_periods)]['target_flag']

    scaler = StandardScaler()
    X_train_scaled = scaler.fit_transform(X_train)
    X_test_scaled = scaler.transform(X_test)

    # Refined parameters for XGBoost
    xgb_model = xgb.XGBClassifier(
        n_estimators=180,
        learning_rate=0.065,
        max_depth=5,
        min_child_weight=3,
        gamma=0.08,
        subsample=0.9,
        colsample_bytree=0.9,
        colsample_bylevel=0.9,
        reg_alpha=0.15,
        reg_lambda=1.2,
        random_state=42,
        n_jobs=-1,
        use_label_encoder=False,
        eval_metric='logloss'
    )

    # Refined parameters for LightGBM
    lgb_model = LGBMClassifier(
        n_estimators=180,
        learning_rate=0.045,
        num_leaves=28,
        max_depth=6,
        min_child_samples=25,
        subsample=0.9,
        colsample_bytree=0.9,
        reg_alpha=0.15,
        reg_lambda=1.2,
        random_state=42,
        n_jobs=-1
    )

    eval_set_xgb = [(X_train_scaled, y_train)]
    eval_set_lgb = [(X_train_scaled, y_train)]

    xgb_model.fit(X_train_scaled, y_train,
                 eval_set=eval_set_xgb)

    lgb_model.fit(X_train_scaled, y_train,
                 eval_set=eval_set_lgb)

    xgb_pred = xgb_model.predict_proba(X_test_scaled)[:, 1]
    roc_auc_xgb = roc_auc_score(y_test, xgb_pred)
    lgb_pred = lgb_model.predict_proba(X_test_scaled)[:, 1]
    roc_auc_lgb = roc_auc_score(y_test, lgb_pred)

    y_pred_proba = 0.45 * xgb_pred + 0.55 * lgb_pred
    roc_auc = roc_auc_score(y_test, y_pred_proba)

    results.append({
        'fold': fold_idx + 1,
        'roc_auc': roc_auc,
        'roc_auc_xgb': roc_auc_xgb,
        'roc_auc_lgb': roc_auc_lgb,
        'test_periods': len(test_periods),
        'train_periods': len(train_periods)
    })

# Results display
results_df = pd.DataFrame(results)
print("\nResults for each fold:")
print(results_df)
print("\nAverage ROC AUC score:", results_df['roc_auc'].mean())
print("Standard deviation:", results_df['roc_auc'].std())
print("\nSelected features:", len(selected_features))
print("\nTop 10 most important features:")
feature_importance = pd.DataFrame({
    'feature': selected_features,
    'xgb_importance': xgb_model.feature_importances_,
    'lgb_importance': lgb_model.feature_importances_
})
print(feature_importance.sort_values('xgb_importance', ascending=False).head(10))

# Submission predictions
test_data = df[df['day_in_period'] == 4]
X_submission = test_data[selected_features]
X_submission_scaled = scaler.transform(X_submission)

xgb_pred = xgb_model.predict_proba(X_submission_scaled)[:, 1]
lgb_pred = lgb_model.predict_proba(X_submission_scaled)[:, 1]
final_predictions = 0.45 * xgb_pred + 0.55 * lgb_pred

submission = pd.DataFrame({
    'rowID': test_data['rowID'],
    'target_flag': final_predictions
})

submission.to_csv('brh17.csv', index=False)
# Out:
# C:\Users\ajanko_adm\AppData\Local\Temp\ipykernel_32552\3196046363.py:99: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df_filtered = df_filtered.fillna(method='ffill').fillna(method='bfill')
# [LightGBM] [Info] Number of positive: 47277, number of negative: 24531
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.005347 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 11004
# [LightGBM] [Info] Number of data points in the train set: 71808, number of used features: 51
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.658381 -> initscore=0.656086
# [LightGBM] [Info] Start training from score 0.656086
# [0]	validation_0-logloss:0.62778
# [1]	validation_0-logloss:0.62260
# [2]	validation_0-logloss:0.61768
# [3]	validation_0-logloss:0.61346
# [4]	validation_0-logloss:0.60963
# [5]	validation_0-logloss:0.60626
# [6]	validation_0-logloss:0.60317
# [7]	validation_0-logloss:0.60049
# [8]	validation_0-logloss:0.59795
# [9]	validation_0-logloss:0.59558
# [10]	validation_0-logloss:0.59352
# [11]	validation_0-logloss:0.59156
# [12]	validation_0-logloss:0.58954
# [13]	validation_0-logloss:0.58762
# [14]	validation_0-logloss:0.58581
# [15]	validation_0-logloss:0.58418
# [16]	validation_0-logloss:0.58265
# [17]	validation_0-logloss:0.58130
# [18]	validation_0-logloss:0.58006
# [19]	validation_0-logloss:0.57889
# c:\Users\ajanko_adm\AppData\Local\miniconda3\envs\machineL\Lib\site-packages\xgboost\core.py:158: UserWarning: [02:25:54] WARNING: C:\b\abs_90_bwj_86a\croot\xgboost-split_1724073762025\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [20]	validation_0-logloss:0.57769
# [21]	validation_0-logloss:0.57668
# [22]	validation_0-logloss:0.57549
# [23]	validation_0-logloss:0.57420
# [24]	validation_0-logloss:0.57331
# [25]	validation_0-logloss:0.57246
# [26]	validation_0-logloss:0.57167
# [27]	validation_0-logloss:0.57046
# [28]	validation_0-logloss:0.56960
# [29]	validation_0-logloss:0.56867
# [30]	validation_0-logloss:0.56796
# [31]	validation_0-logloss:0.56730
# [32]	validation_0-logloss:0.56656
# [33]	validation_0-logloss:0.56583
# [34]	validation_0-logloss:0.56525
# [35]	validation_0-logloss:0.56452
# [36]	validation_0-logloss:0.56380
# [37]	validation_0-logloss:0.56284
# [38]	validation_0-logloss:0.56227
# [39]	validation_0-logloss:0.56167
# [40]	validation_0-logloss:0.56111
# [41]	validation_0-logloss:0.56069
# [42]	validation_0-logloss:0.55997
# [43]	validation_0-logloss:0.55935
# [44]	validation_0-logloss:0.55861
# [45]	validation_0-logloss:0.55808
# [46]	validation_0-logloss:0.55726
# [47]	validation_0-logloss:0.55631
# [48]	validation_0-logloss:0.55577
# [49]	validation_0-logloss:0.55522
# [50]	validation_0-logloss:0.55476
# [51]	validation_0-logloss:0.55397
# [52]	validation_0-logloss:0.55340
# [53]	validation_0-logloss:0.55278
# [54]	validation_0-logloss:0.55228
# [55]	validation_0-logloss:0.55173
# [56]	validation_0-logloss:0.55121
# [57]	validation_0-logloss:0.55045
# [58]	validation_0-logloss:0.55009
# [59]	validation_0-logloss:0.54979
# [60]	validation_0-logloss:0.54933
# [61]	validation_0-logloss:0.54895
# [62]	validation_0-logloss:0.54866
# [63]	validation_0-logloss:0.54845
# [64]	validation_0-logloss:0.54823
# [65]	validation_0-logloss:0.54785
# [66]	validation_0-logloss:0.54737
# [67]	validation_0-logloss:0.54660
# [68]	validation_0-logloss:0.54591
# [69]	validation_0-logloss:0.54545
# [70]	validation_0-logloss:0.54504
# [71]	validation_0-logloss:0.54480
# [72]	validation_0-logloss:0.54420
# [73]	validation_0-logloss:0.54361
# [74]	validation_0-logloss:0.54307
# [75]	validation_0-logloss:0.54294
# [76]	validation_0-logloss:0.54269
# [77]	validation_0-logloss:0.54225
# [78]	validation_0-logloss:0.54195
# [79]	validation_0-logloss:0.54181
# [80]	validation_0-logloss:0.54137
# [81]	validation_0-logloss:0.54086
# [82]	validation_0-logloss:0.54033
# [83]	validation_0-logloss:0.53991
# [84]	validation_0-logloss:0.53962
# [85]	validation_0-logloss:0.53928
# [86]	validation_0-logloss:0.53889
# [87]	validation_0-logloss:0.53858
# [88]	validation_0-logloss:0.53846
# [89]	validation_0-logloss:0.53830
# [90]	validation_0-logloss:0.53792
# [91]	validation_0-logloss:0.53770
# [92]	validation_0-logloss:0.53738
# [93]	validation_0-logloss:0.53713
# [94]	validation_0-logloss:0.53689
# [95]	validation_0-logloss:0.53665
# [96]	validation_0-logloss:0.53654
# [97]	validation_0-logloss:0.53616
# [98]	validation_0-logloss:0.53580
# [99]	validation_0-logloss:0.53546
# [100]	validation_0-logloss:0.53531
# [101]	validation_0-logloss:0.53513
# [102]	validation_0-logloss:0.53463
# [103]	validation_0-logloss:0.53423
# [104]	validation_0-logloss:0.53399
# [105]	validation_0-logloss:0.53377
# [106]	validation_0-logloss:0.53337
# [107]	validation_0-logloss:0.53312
# [108]	validation_0-logloss:0.53286
# [109]	validation_0-logloss:0.53268
# [110]	validation_0-logloss:0.53239
# [111]	validation_0-logloss:0.53199
# [112]	validation_0-logloss:0.53185
# [113]	validation_0-logloss:0.53165
# [114]	validation_0-logloss:0.53141
# [115]	validation_0-logloss:0.53095
# [116]	validation_0-logloss:0.53044
# [117]	validation_0-logloss:0.52987
# [118]	validation_0-logloss:0.52940
# [119]	validation_0-logloss:0.52924
# [120]	validation_0-logloss:0.52898
# [121]	validation_0-logloss:0.52874
# [122]	validation_0-logloss:0.52854
# [123]	validation_0-logloss:0.52841
# [124]	validation_0-logloss:0.52799
# [125]	validation_0-logloss:0.52775
# [126]	validation_0-logloss:0.52760
# [127]	validation_0-logloss:0.52735
# [128]	validation_0-logloss:0.52699
# [129]	validation_0-logloss:0.52664
# [130]	validation_0-logloss:0.52624
# [131]	validation_0-logloss:0.52595
# [132]	validation_0-logloss:0.52547
# [133]	validation_0-logloss:0.52528
# [134]	validation_0-logloss:0.52511
# [135]	validation_0-logloss:0.52484
# [136]	validation_0-logloss:0.52474
# [137]	validation_0-logloss:0.52458
# [138]	validation_0-logloss:0.52431
# [139]	validation_0-logloss:0.52421
# [140]	validation_0-logloss:0.52405
# [141]	validation_0-logloss:0.52385
# [142]	validation_0-logloss:0.52352
# [143]	validation_0-logloss:0.52338
# [144]	validation_0-logloss:0.52299
# [145]	validation_0-logloss:0.52270
# [146]	validation_0-logloss:0.52254
# [147]	validation_0-logloss:0.52238
# [148]	validation_0-logloss:0.52204
# [149]	validation_0-logloss:0.52171
# [150]	validation_0-logloss:0.52142
# [151]	validation_0-logloss:0.52110
# [152]	validation_0-logloss:0.52082
# [153]	validation_0-logloss:0.52063
# [154]	validation_0-logloss:0.52029
# [155]	validation_0-logloss:0.52007
# [156]	validation_0-logloss:0.51985
# [157]	validation_0-logloss:0.51966
# [158]	validation_0-logloss:0.51935
# [159]	validation_0-logloss:0.51904
# [160]	validation_0-logloss:0.51888
# [161]	validation_0-logloss:0.51872
# [162]	validation_0-logloss:0.51828
# [163]	validation_0-logloss:0.51795
# [164]	validation_0-logloss:0.51766
# [165]	validation_0-logloss:0.51747
# [166]	validation_0-logloss:0.51721
# [167]	validation_0-logloss:0.51698
# [168]	validation_0-logloss:0.51662
# [169]	validation_0-logloss:0.51637
# [170]	validation_0-logloss:0.51611
# [171]	validation_0-logloss:0.51583
# [172]	validation_0-logloss:0.51567
# [173]	validation_0-logloss:0.51541
# [174]	validation_0-logloss:0.51519
# [175]	validation_0-logloss:0.51497
# [176]	validation_0-logloss:0.51473
# [177]	validation_0-logloss:0.51438
# [178]	validation_0-logloss:0.51425
# [179]	validation_0-logloss:0.51413
# [LightGBM] [Info] Number of positive: 32190, number of negative: 15810
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.006364 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 11001
# [LightGBM] [Info] Number of data points in the train set: 48000, number of used features: 50
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.670625 -> initscore=0.711013
# [LightGBM] [Info] Start training from score 0.711013
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [0]	validation_0-logloss:0.63872
# [1]	validation_0-logloss:0.63336
# [2]	validation_0-logloss:0.62856
# [3]	validation_0-logloss:0.62415
# [4]	validation_0-logloss:0.62011
# [5]	validation_0-logloss:0.61661
# [6]	validation_0-logloss:0.61342
# [7]	validation_0-logloss:0.61030
# [8]	validation_0-logloss:0.60762
# [9]	validation_0-logloss:0.60527
# [10]	validation_0-logloss:0.60317
# [11]	validation_0-logloss:0.60118
# [12]	validation_0-logloss:0.59920
# [13]	validation_0-logloss:0.59745
# [14]	validation_0-logloss:0.59591
# [15]	validation_0-logloss:0.59417
# [16]	validation_0-logloss:0.59252
# [17]	validation_0-logloss:0.59122
# [18]	validation_0-logloss:0.59010
# [19]	validation_0-logloss:0.58898
# [20]	validation_0-logloss:0.58801
# c:\Users\ajanko_adm\AppData\Local\miniconda3\envs\machineL\Lib\site-packages\xgboost\core.py:158: UserWarning: [02:25:57] WARNING: C:\b\abs_90_bwj_86a\croot\xgboost-split_1724073762025\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [21]	validation_0-logloss:0.58697
# [22]	validation_0-logloss:0.58590
# [23]	validation_0-logloss:0.58464
# [24]	validation_0-logloss:0.58376
# [25]	validation_0-logloss:0.58297
# [26]	validation_0-logloss:0.58204
# [27]	validation_0-logloss:0.58124
# [28]	validation_0-logloss:0.58049
# [29]	validation_0-logloss:0.57953
# [30]	validation_0-logloss:0.57876
# [31]	validation_0-logloss:0.57806
# [32]	validation_0-logloss:0.57747
# [33]	validation_0-logloss:0.57646
# [34]	validation_0-logloss:0.57602
# [35]	validation_0-logloss:0.57549
# [36]	validation_0-logloss:0.57471
# [37]	validation_0-logloss:0.57413
# [38]	validation_0-logloss:0.57369
# [39]	validation_0-logloss:0.57296
# [40]	validation_0-logloss:0.57240
# [41]	validation_0-logloss:0.57179
# [42]	validation_0-logloss:0.57088
# [43]	validation_0-logloss:0.57043
# [44]	validation_0-logloss:0.56940
# [45]	validation_0-logloss:0.56883
# [46]	validation_0-logloss:0.56767
# [47]	validation_0-logloss:0.56703
# [48]	validation_0-logloss:0.56646
# [49]	validation_0-logloss:0.56586
# [50]	validation_0-logloss:0.56554
# [51]	validation_0-logloss:0.56518
# [52]	validation_0-logloss:0.56436
# [53]	validation_0-logloss:0.56375
# [54]	validation_0-logloss:0.56323
# [55]	validation_0-logloss:0.56279
# [56]	validation_0-logloss:0.56239
# [57]	validation_0-logloss:0.56205
# [58]	validation_0-logloss:0.56155
# [59]	validation_0-logloss:0.56130
# [60]	validation_0-logloss:0.56058
# [61]	validation_0-logloss:0.56015
# [62]	validation_0-logloss:0.55996
# [63]	validation_0-logloss:0.55937
# [64]	validation_0-logloss:0.55907
# [65]	validation_0-logloss:0.55860
# [66]	validation_0-logloss:0.55794
# [67]	validation_0-logloss:0.55708
# [68]	validation_0-logloss:0.55679
# [69]	validation_0-logloss:0.55620
# [70]	validation_0-logloss:0.55568
# [71]	validation_0-logloss:0.55535
# [72]	validation_0-logloss:0.55495
# [73]	validation_0-logloss:0.55466
# [74]	validation_0-logloss:0.55394
# [75]	validation_0-logloss:0.55353
# [76]	validation_0-logloss:0.55330
# [77]	validation_0-logloss:0.55303
# [78]	validation_0-logloss:0.55279
# [79]	validation_0-logloss:0.55261
# [80]	validation_0-logloss:0.55232
# [81]	validation_0-logloss:0.55209
# [82]	validation_0-logloss:0.55197
# [83]	validation_0-logloss:0.55151
# [84]	validation_0-logloss:0.55122
# [85]	validation_0-logloss:0.55097
# [86]	validation_0-logloss:0.55057
# [87]	validation_0-logloss:0.55017
# [88]	validation_0-logloss:0.54972
# [89]	validation_0-logloss:0.54943
# [90]	validation_0-logloss:0.54915
# [91]	validation_0-logloss:0.54891
# [92]	validation_0-logloss:0.54832
# [93]	validation_0-logloss:0.54810
# [94]	validation_0-logloss:0.54773
# [95]	validation_0-logloss:0.54707
# [96]	validation_0-logloss:0.54660
# [97]	validation_0-logloss:0.54644
# [98]	validation_0-logloss:0.54598
# [99]	validation_0-logloss:0.54568
# [100]	validation_0-logloss:0.54549
# [101]	validation_0-logloss:0.54513
# [102]	validation_0-logloss:0.54485
# [103]	validation_0-logloss:0.54462
# [104]	validation_0-logloss:0.54417
# [105]	validation_0-logloss:0.54388
# [106]	validation_0-logloss:0.54370
# [107]	validation_0-logloss:0.54327
# [108]	validation_0-logloss:0.54288
# [109]	validation_0-logloss:0.54251
# [110]	validation_0-logloss:0.54229
# [111]	validation_0-logloss:0.54187
# [112]	validation_0-logloss:0.54163
# [113]	validation_0-logloss:0.54132
# [114]	validation_0-logloss:0.54104
# [115]	validation_0-logloss:0.54076
# [116]	validation_0-logloss:0.54047
# [117]	validation_0-logloss:0.54022
# [118]	validation_0-logloss:0.54008
# [119]	validation_0-logloss:0.53983
# [120]	validation_0-logloss:0.53940
# [121]	validation_0-logloss:0.53927
# [122]	validation_0-logloss:0.53913
# [123]	validation_0-logloss:0.53870
# [124]	validation_0-logloss:0.53850
# [125]	validation_0-logloss:0.53832
# [126]	validation_0-logloss:0.53818
# [127]	validation_0-logloss:0.53804
# [128]	validation_0-logloss:0.53771
# [129]	validation_0-logloss:0.53763
# [130]	validation_0-logloss:0.53739
# [131]	validation_0-logloss:0.53721
# [132]	validation_0-logloss:0.53709
# [133]	validation_0-logloss:0.53671
# [134]	validation_0-logloss:0.53628
# [135]	validation_0-logloss:0.53615
# [136]	validation_0-logloss:0.53593
# [137]	validation_0-logloss:0.53585
# [138]	validation_0-logloss:0.53554
# [139]	validation_0-logloss:0.53518
# [140]	validation_0-logloss:0.53492
# [141]	validation_0-logloss:0.53470
# [142]	validation_0-logloss:0.53439
# [143]	validation_0-logloss:0.53415
# [144]	validation_0-logloss:0.53382
# [145]	validation_0-logloss:0.53344
# [146]	validation_0-logloss:0.53315
# [147]	validation_0-logloss:0.53287
# [148]	validation_0-logloss:0.53267
# [149]	validation_0-logloss:0.53229
# [150]	validation_0-logloss:0.53197
# [151]	validation_0-logloss:0.53163
# [152]	validation_0-logloss:0.53132
# [153]	validation_0-logloss:0.53114
# [154]	validation_0-logloss:0.53100
# [155]	validation_0-logloss:0.53071
# [156]	validation_0-logloss:0.53041
# [157]	validation_0-logloss:0.53017
# [158]	validation_0-logloss:0.52972
# [159]	validation_0-logloss:0.52937
# [160]	validation_0-logloss:0.52912
# [161]	validation_0-logloss:0.52873
# [162]	validation_0-logloss:0.52845
# [163]	validation_0-logloss:0.52817
# [164]	validation_0-logloss:0.52789
# [165]	validation_0-logloss:0.52759
# [166]	validation_0-logloss:0.52741
# [167]	validation_0-logloss:0.52705
# [168]	validation_0-logloss:0.52684
# [169]	validation_0-logloss:0.52672
# [170]	validation_0-logloss:0.52654
# [171]	validation_0-logloss:0.52632
# [172]	validation_0-logloss:0.52606
# [173]	validation_0-logloss:0.52590
# [174]	validation_0-logloss:0.52557
# [175]	validation_0-logloss:0.52537
# [176]	validation_0-logloss:0.52520
# [177]	validation_0-logloss:0.52490
# [178]	validation_0-logloss:0.52476
# [179]	validation_0-logloss:0.52467
# [LightGBM] [Info] Number of positive: 31397, number of negative: 16603
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.006309 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 10995
# [LightGBM] [Info] Number of data points in the train set: 48000, number of used features: 50
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.654104 -> initscore=0.637129
# [LightGBM] [Info] Start training from score 0.637129
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [0]	validation_0-logloss:0.64121
# [1]	validation_0-logloss:0.63597
# [2]	validation_0-logloss:0.63112
# [3]	validation_0-logloss:0.62692
# [4]	validation_0-logloss:0.62308
# [5]	validation_0-logloss:0.61964
# [6]	validation_0-logloss:0.61636
# [7]	validation_0-logloss:0.61347
# [8]	validation_0-logloss:0.61078
# [9]	validation_0-logloss:0.60839
# [10]	validation_0-logloss:0.60611
# [11]	validation_0-logloss:0.60404
# [12]	validation_0-logloss:0.60220
# [13]	validation_0-logloss:0.60035
# [14]	validation_0-logloss:0.59871
# [15]	validation_0-logloss:0.59675
# [16]	validation_0-logloss:0.59534
# [17]	validation_0-logloss:0.59415
# [18]	validation_0-logloss:0.59299
# [19]	validation_0-logloss:0.59201
# [20]	validation_0-logloss:0.59071
# [21]	validation_0-logloss:0.58914
# c:\Users\ajanko_adm\AppData\Local\miniconda3\envs\machineL\Lib\site-packages\xgboost\core.py:158: UserWarning: [02:26:00] WARNING: C:\b\abs_90_bwj_86a\croot\xgboost-split_1724073762025\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [22]	validation_0-logloss:0.58809
# [23]	validation_0-logloss:0.58725
# [24]	validation_0-logloss:0.58636
# [25]	validation_0-logloss:0.58516
# [26]	validation_0-logloss:0.58396
# [27]	validation_0-logloss:0.58307
# [28]	validation_0-logloss:0.58187
# [29]	validation_0-logloss:0.58101
# [30]	validation_0-logloss:0.57990
# [31]	validation_0-logloss:0.57926
# [32]	validation_0-logloss:0.57871
# [33]	validation_0-logloss:0.57819
# [34]	validation_0-logloss:0.57754
# [35]	validation_0-logloss:0.57700
# [36]	validation_0-logloss:0.57635
# [37]	validation_0-logloss:0.57570
# [38]	validation_0-logloss:0.57519
# [39]	validation_0-logloss:0.57463
# [40]	validation_0-logloss:0.57408
# [41]	validation_0-logloss:0.57352
# [42]	validation_0-logloss:0.57305
# [43]	validation_0-logloss:0.57263
# [44]	validation_0-logloss:0.57197
# [45]	validation_0-logloss:0.57153
# [46]	validation_0-logloss:0.57116
# [47]	validation_0-logloss:0.57059
# [48]	validation_0-logloss:0.56999
# [49]	validation_0-logloss:0.56928
# [50]	validation_0-logloss:0.56837
# [51]	validation_0-logloss:0.56804
# [52]	validation_0-logloss:0.56744
# [53]	validation_0-logloss:0.56709
# [54]	validation_0-logloss:0.56621
# [55]	validation_0-logloss:0.56579
# [56]	validation_0-logloss:0.56503
# [57]	validation_0-logloss:0.56462
# [58]	validation_0-logloss:0.56434
# [59]	validation_0-logloss:0.56413
# [60]	validation_0-logloss:0.56399
# [61]	validation_0-logloss:0.56348
# [62]	validation_0-logloss:0.56307
# [63]	validation_0-logloss:0.56279
# [64]	validation_0-logloss:0.56223
# [65]	validation_0-logloss:0.56185
# [66]	validation_0-logloss:0.56144
# [67]	validation_0-logloss:0.56109
# [68]	validation_0-logloss:0.56044
# [69]	validation_0-logloss:0.55988
# [70]	validation_0-logloss:0.55959
# [71]	validation_0-logloss:0.55929
# [72]	validation_0-logloss:0.55902
# [73]	validation_0-logloss:0.55871
# [74]	validation_0-logloss:0.55812
# [75]	validation_0-logloss:0.55750
# [76]	validation_0-logloss:0.55713
# [77]	validation_0-logloss:0.55671
# [78]	validation_0-logloss:0.55638
# [79]	validation_0-logloss:0.55611
# [80]	validation_0-logloss:0.55578
# [81]	validation_0-logloss:0.55504
# [82]	validation_0-logloss:0.55467
# [83]	validation_0-logloss:0.55446
# [84]	validation_0-logloss:0.55405
# [85]	validation_0-logloss:0.55370
# [86]	validation_0-logloss:0.55329
# [87]	validation_0-logloss:0.55279
# [88]	validation_0-logloss:0.55248
# [89]	validation_0-logloss:0.55198
# [90]	validation_0-logloss:0.55172
# [91]	validation_0-logloss:0.55147
# [92]	validation_0-logloss:0.55097
# [93]	validation_0-logloss:0.55074
# [94]	validation_0-logloss:0.55021
# [95]	validation_0-logloss:0.54997
# [96]	validation_0-logloss:0.54963
# [97]	validation_0-logloss:0.54931
# [98]	validation_0-logloss:0.54909
# [99]	validation_0-logloss:0.54876
# [100]	validation_0-logloss:0.54857
# [101]	validation_0-logloss:0.54827
# [102]	validation_0-logloss:0.54800
# [103]	validation_0-logloss:0.54765
# [104]	validation_0-logloss:0.54725
# [105]	validation_0-logloss:0.54708
# [106]	validation_0-logloss:0.54679
# [107]	validation_0-logloss:0.54636
# [108]	validation_0-logloss:0.54594
# [109]	validation_0-logloss:0.54581
# [110]	validation_0-logloss:0.54534
# [111]	validation_0-logloss:0.54515
# [112]	validation_0-logloss:0.54478
# [113]	validation_0-logloss:0.54452
# [114]	validation_0-logloss:0.54415
# [115]	validation_0-logloss:0.54393
# [116]	validation_0-logloss:0.54378
# [117]	validation_0-logloss:0.54365
# [118]	validation_0-logloss:0.54330
# [119]	validation_0-logloss:0.54292
# [120]	validation_0-logloss:0.54255
# [121]	validation_0-logloss:0.54242
# [122]	validation_0-logloss:0.54206
# [123]	validation_0-logloss:0.54166
# [124]	validation_0-logloss:0.54136
# [125]	validation_0-logloss:0.54097
# [126]	validation_0-logloss:0.54060
# [127]	validation_0-logloss:0.54047
# [128]	validation_0-logloss:0.54004
# [129]	validation_0-logloss:0.53978
# [130]	validation_0-logloss:0.53957
# [131]	validation_0-logloss:0.53927
# [132]	validation_0-logloss:0.53910
# [133]	validation_0-logloss:0.53895
# [134]	validation_0-logloss:0.53879
# [135]	validation_0-logloss:0.53842
# [136]	validation_0-logloss:0.53797
# [137]	validation_0-logloss:0.53763
# [138]	validation_0-logloss:0.53738
# [139]	validation_0-logloss:0.53707
# [140]	validation_0-logloss:0.53683
# [141]	validation_0-logloss:0.53661
# [142]	validation_0-logloss:0.53636
# [143]	validation_0-logloss:0.53611
# [144]	validation_0-logloss:0.53575
# [145]	validation_0-logloss:0.53557
# [146]	validation_0-logloss:0.53521
# [147]	validation_0-logloss:0.53494
# [148]	validation_0-logloss:0.53454
# [149]	validation_0-logloss:0.53433
# [150]	validation_0-logloss:0.53412
# [151]	validation_0-logloss:0.53386
# [152]	validation_0-logloss:0.53351
# [153]	validation_0-logloss:0.53324
# [154]	validation_0-logloss:0.53303
# [155]	validation_0-logloss:0.53281
# [156]	validation_0-logloss:0.53248
# [157]	validation_0-logloss:0.53229
# [158]	validation_0-logloss:0.53208
# [159]	validation_0-logloss:0.53181
# [160]	validation_0-logloss:0.53147
# [161]	validation_0-logloss:0.53119
# [162]	validation_0-logloss:0.53097
# [163]	validation_0-logloss:0.53068
# [164]	validation_0-logloss:0.53048
# [165]	validation_0-logloss:0.53029
# [166]	validation_0-logloss:0.53000
# [167]	validation_0-logloss:0.52987
# [168]	validation_0-logloss:0.52963
# [169]	validation_0-logloss:0.52929
# [170]	validation_0-logloss:0.52903
# [171]	validation_0-logloss:0.52885
# [172]	validation_0-logloss:0.52866
# [173]	validation_0-logloss:0.52837
# [174]	validation_0-logloss:0.52802
# [175]	validation_0-logloss:0.52774
# [176]	validation_0-logloss:0.52748
# [177]	validation_0-logloss:0.52726
# [178]	validation_0-logloss:0.52686
# [179]	validation_0-logloss:0.52656
# [LightGBM] [Info] Number of positive: 30967, number of negative: 16649
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.004979 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 10995
# [LightGBM] [Info] Number of data points in the train set: 47616, number of used features: 50
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.650349 -> initscore=0.620572
# [LightGBM] [Info] Start training from score 0.620572
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
#
# Results for each fold:
#    fold   roc_auc  roc_auc_xgb  roc_auc_lgb  test_periods  train_periods
# 0     1  0.678615     0.677012     0.678210            62            125
# 1     2  0.692991     0.690755     0.693174            62            125
# 2     3  0.689994     0.688118     0.689864            63            124
#
# Average ROC AUC score: 0.6871999643028835
# Standard deviation: 0.007584419239113933
#
# Selected features: 50
#
# Top 10 most important features:
#                       feature  xgb_importance  lgb_importance
# 38     target_std_season_hour        0.131810             236
# 40  target_std_season_weekday        0.045391             356
# 37           load_lag_ratio_2        0.031728              91
# 3                  minute_cos        0.028002             210
# 36           load_lag_ratio_1        0.027487              85
# 39    target_std_weekday_hour        0.024032             235
# 2                  minute_sin        0.023781              91
# 41           solar_load_ratio        0.022272              62
# 23               load_ema_0.3        0.021889              65
# 7       rendszerterheles_terv        0.021027             117
